# %%
import random
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import torch
import torch.optim as optim
import torch.nn as nn
from torch.utils.data import Subset
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.utils import make_grid 
from torch.utils.tensorboard import SummaryWriter
from torchvision.models import efficientnet_b0, EfficientNet_B0_Weights
from sklearn.model_selection import train_test_split

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
writer = SummaryWriter()

# %%
# Define transformations
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(30),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),    
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

val_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(), 
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])



# Load datasets from disk with transforms applied
train_data = datasets.INaturalist(root='data/train_mini', version="2021_train_mini", transform=train_transform, download=False)
validation_data = datasets.INaturalist(root='data/validation', version="2021_valid", transform=val_transform, download=False)

# Create DataLoaders
train_loader = DataLoader(train_data, batch_size=128, shuffle=True, num_workers=4)
val_loader = DataLoader(validation_data, batch_size=128, shuffle=True, num_workers=4)

print(f"Training samples: {len(train_data)}")
print(f"Validation samples: {len(validation_data)}")
# Out:
# Training samples: 500000
# Validation samples: 100000

# %%
cat_list = [int(cat[1:5]) for cat in train_data.all_categories if "Animalia_Chordata_Aves" in cat]
# get corresponding labels

# %%
bird_indices = []
with open('bird_indices.txt', 'r') as f:
    for line in f:
        bird_indices.append(int(line[0:-1]))

bird_test_indices = []
with open('bird_val_indices.txt', 'r') as f:
    for line in f:
        bird_test_indices.append(int(line[0:-1]))

# %%
# Find all indices where the target (label) corresponds to birds
# Create a subset dataset containing only birds
train_data_birds = Subset(train_data, bird_indices)

label_index_map = {}
index_list = [] 
label_list = []

# for i, (_, label) in enumerate(train_data_birds):
#     index_list.append(i)
#     label_list.append(label)
# # now, for each label, randomly select 20% of indices, these will become the val set. 
# index_list_train, index_list_val, labels_train, labels_val = train_test_split(
# index_list, label_list, test_size=0.2, random_state=42, stratify=label_list)

# %%
def read_list_from_file(file_name):
    output_list = []
    with open(file_name, 'r') as f:
        for line in f:
            output_list.append(int(line[0:-1]))
    return output_list

index_list_train = read_list_from_file("index_list_train.csv") 
index_list_val = read_list_from_file("index_list_val.csv") 
labels_train = read_list_from_file("labels_train.csv") 
labels_val = read_list_from_file("labels_val.csv")

# %%
val_data_birds = Subset(train_data_birds, index_list_val)
train_data_birds = Subset(train_data_birds, index_list_train)

# %%
# Create a DataLoader for the filtered dataset
train_loader_birds = DataLoader(train_data_birds, batch_size=32, shuffle=True, num_workers=4)
val_loader_birds = DataLoader(val_data_birds, batch_size=32, shuffle=True, num_workers=4)

# use validation set from problem as the unseen test set
test_data_birds = Subset(validation_data, bird_test_indices)
test_loader_birds = DataLoader(test_data_birds, batch_size=32, shuffle=True, num_workers=4)

print(f"Filtered train dataset contains {len(train_data_birds)} bird images.")
print(f"Filtered val dataset contains {len(val_data_birds)} bird images.")
print(f"Filtered test dataset contains {len(test_data_birds)} bird images.")
# Out:
# Filtered train dataset contains 59440 bird images.
# Filtered val dataset contains 14860 bird images.
# Filtered test dataset contains 14860 bird images.

# %%
# functions to show an image
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# get some random training images
dataiter = iter(train_loader_birds)
images, labels = next(dataiter)

# show images
imshow(make_grid(images))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.558952..1.82].

# %%
n_classes = len(cat_list)

# %%
def remap_labels(labels):
    return (labels - 3111).long()  


def log_metrics_tensor_board(data_type, accuracy, top_5_accuracy, loss, epoch ):
    writer.add_scalar(f"Loss -  {data_type}", loss, epoch)
    writer.add_scalar(f"Accuracy -  {data_type}", 100 * accuracy, epoch)
    writer.add_scalar(f"Top 5 Accuracy - {data_type}", 100 * top_5_accuracy, epoch)
    return


def save_model(model, criterion, optimizer,  epoch, model_name):
    torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'loss': criterion,
                }, f"runs/model_{model_name}.pth")
    return


def run_epoch(model, loader, criterion, optimizer=None, epoch=0, mode="train"):
    is_train = mode == "train"
    model.train() if is_train else model.eval()

    running_loss = 0.0
    correct = 0
    top_5_correct = 0
    total = 0

    with torch.set_grad_enabled(is_train):  # Only compute gradients during training
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            labels = remap_labels(labels).to(device)

            outputs = model(images)  # Forward pass
            loss = criterion(outputs, labels)  # Compute loss

            if is_train:
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

            running_loss += loss.item()
            _, predicted = outputs.max(1)
            # count total correct predicitions in batch
            correct += (predicted == labels).sum().item()
            total += labels.size(0)
            # count total matches of label in top 5 class predictions 
            _, top_5_predicted = outputs.topk(5, dim=1)
            top_5_correct += torch.isin(labels, top_5_predicted).sum().item()

    avg_loss = running_loss / len(loader)
    accuracy = correct / total
    top_5_accuracy = top_5_correct / total
    log_metrics_tensor_board(mode, accuracy, top_5_accuracy, avg_loss, epoch)

    print(f"{mode.capitalize()} Accuracy: {100 * accuracy:.2f}%")
    print(f"Top 5 {mode.capitalize()} Accuracy: {100 * top_5_accuracy:.2f}%")
    print(f"Epoch {epoch+1} - {mode.capitalize()} Loss: {avg_loss:.4f}")
    return avg_loss, accuracy


def train_model(model, model_name, train_loader, val_loader, criterion, optimizer, epochs=5, early_stop_limit=5):
    best_val_loss = float('inf')
    early_stop_count = 0
    # lists to track of loss and accuracy metrics
    train_loss_list, val_loss_list = [], []
    train_acc_list, val_acc_list = [], []

    for epoch in range(epochs):
        train_loss, train_acc = run_epoch(model, train_loader, criterion, optimizer, epoch, mode="train")
        # if no val loader, evaluate stopping based on train metrics (e.g. when training on validation after training on train before evaluating on test)
        if val_loader is None:
            val_loss, val_acc = train_loss, train_acc
        else:
            val_loss, val_acc = run_epoch(model, val_loader, criterion, None, epoch, mode="validation")
        # store metrics
        train_loss_list.append(train_loss)
        val_loss_list.append(val_loss)
        train_acc_list.append(train_acc)
        val_acc_list.append(val_acc)
        # early stopping
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            early_stop_count = 0
            # save best model so far
            save_model(model, criterion, optimizer,  epoch, model_name)
        else:
            early_stop_count += 1
        if early_stop_count == early_stop_limit:
            break
    eval_metrics = {
            "train_loss": train_loss_list,
            "val_loss": val_loss_list,
            "train_acc": train_acc_list,
            "val_acc": val_acc_list
        }
    return eval_metrics

# %%
# efficient net model 
weights = EfficientNet_B0_Weights.DEFAULT
pretrained_model = efficientnet_b0(weights=weights)

for param in pretrained_model.parameters():
    param.requires_grad = True  # Enable/Disable fine tune training on all layers

pretrained_model.classifier = nn.Sequential(
            nn.Linear(pretrained_model.classifier[1].in_features, 2048), 
            nn.BatchNorm1d(2048),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(2048, n_classes)  # Final output layer
)

pretrained_model.to(device)

criterion =  nn.CrossEntropyLoss().to(device)
optimizer = optim.Adam(pretrained_model.parameters(), lr=0.0001, weight_decay=1e-3)


# Train the model
eval_metrics = train_model(pretrained_model, "efficientnet_b0", train_loader_birds, val_loader_birds, criterion, optimizer, epochs=100, early_stop_limit=3)
# Out:
# Train Accuracy: 3.50%
# Top 5 Train Accuracy: 15.96%
# Epoch 1 - Train Loss: 6.2197
# Validation Accuracy: 12.32%
# Top 5 Validation Accuracy: 34.62%
# Epoch 1 - Validation Loss: 4.8165
# Train Accuracy: 13.86%
# Top 5 Train Accuracy: 37.68%
# Epoch 2 - Train Loss: 4.6178
# Validation Accuracy: 21.47%
# Top 5 Validation Accuracy: 49.51%
# Epoch 2 - Validation Loss: 3.9720
# Train Accuracy: 23.09%
# Top 5 Train Accuracy: 51.21%
# Epoch 3 - Train Loss: 3.8963
# Validation Accuracy: 26.99%
# Top 5 Validation Accuracy: 56.20%
# Epoch 3 - Validation Loss: 3.5848
# Train Accuracy: 29.77%
# Top 5 Train Accuracy: 58.99%
# Epoch 4 - Train Loss: 3.4573
# Validation Accuracy: 31.04%
# Top 5 Validation Accuracy: 60.08%
# Epoch 4 - Validation Loss: 3.3227
# Train Accuracy: 35.13%
# Top 5 Train Accuracy: 64.33%
# Epoch 5 - Train Loss: 3.1365
# Validation Accuracy: 33.34%
# Top 5 Validation Accuracy: 62.79%
# Epoch 5 - Validation Loss: 3.1507
# Train Accuracy: 39.14%
# Top 5 Train Accuracy: 68.30%
# Epoch 6 - Train Loss: 2.9116
# Validation Accuracy: 35.43%
# Top 5 Validation Accuracy: 64.39%
# Epoch 6 - Validation Loss: 3.0496
# Train Accuracy: 42.88%
# Top 5 Train Accuracy: 71.09%
# Epoch 7 - Train Loss: 2.7273
# Validation Accuracy: 36.57%
# Top 5 Validation Accuracy: 65.69%
# Epoch 7 - Validation Loss: 2.9833
# Train Accuracy: 44.82%
# Top 5 Train Accuracy: 73.13%
# Epoch 8 - Train Loss: 2.6022
# Validation Accuracy: 37.64%
# Top 5 Validation Accuracy: 66.16%
# Epoch 8 - Validation Loss: 2.9300
# Train Accuracy: 47.23%
# Top 5 Train Accuracy: 74.90%
# Epoch 9 - Train Loss: 2.4862
# Validation Accuracy: 38.01%
# Top 5 Validation Accuracy: 66.19%
# Epoch 9 - Validation Loss: 2.9075
# Train Accuracy: 48.95%
# Top 5 Train Accuracy: 76.30%
# Epoch 10 - Train Loss: 2.3944
# Validation Accuracy: 38.91%
# Top 5 Validation Accuracy: 67.07%
# Epoch 10 - Validation Loss: 2.8788
# Train Accuracy: 50.40%
# Top 5 Train Accuracy: 77.66%
# Epoch 11 - Train Loss: 2.3187
# Validation Accuracy: 38.93%
# Top 5 Validation Accuracy: 67.44%
# Epoch 11 - Validation Loss: 2.8680
# Train Accuracy: 51.65%
# Top 5 Train Accuracy: 78.61%
# Epoch 12 - Train Loss: 2.2488
# Validation Accuracy: 39.30%
# Top 5 Validation Accuracy: 67.11%
# Epoch 12 - Validation Loss: 2.8479
# Train Accuracy: 53.11%
# Top 5 Train Accuracy: 79.61%
# Epoch 13 - Train Loss: 2.1869
# Validation Accuracy: 39.82%
# Top 5 Validation Accuracy: 68.01%
# Epoch 13 - Validation Loss: 2.8259
# Train Accuracy: 53.99%
# Top 5 Train Accuracy: 80.43%
# Epoch 14 - Train Loss: 2.1368
# Validation Accuracy: 39.16%
# Top 5 Validation Accuracy: 67.46%
# Epoch 14 - Validation Loss: 2.8505
# Train Accuracy: 54.87%
# Top 5 Train Accuracy: 80.93%
# Epoch 15 - Train Loss: 2.0908
# Validation Accuracy: 40.15%
# Top 5 Validation Accuracy: 67.96%
# Epoch 15 - Validation Loss: 2.8204
# Train Accuracy: 55.64%
# Top 5 Train Accuracy: 81.53%
# Epoch 16 - Train Loss: 2.0525
# Validation Accuracy: 39.98%
# Top 5 Validation Accuracy: 67.62%
# Epoch 16 - Validation Loss: 2.8346
# Train Accuracy: 56.56%
# Top 5 Train Accuracy: 82.26%
# Epoch 17 - Train Loss: 2.0098
# Validation Accuracy: 39.70%
# Top 5 Validation Accuracy: 67.67%
# Epoch 17 - Validation Loss: 2.8452
# Train Accuracy: 57.17%
# Top 5 Train Accuracy: 82.75%
# Epoch 18 - Train Loss: 1.9758
# Validation Accuracy: 40.08%
# Top 5 Validation Accuracy: 67.54%
# Epoch 18 - Validation Loss: 2.8345

# %%
def create_eval_plots(eval_metrics, model_name):
    # Convert eval_metrics to a DataFrame and add an 'epoch' column
    plot_df = pd.DataFrame.from_dict(eval_metrics)
    plot_df["epoch"] = plot_df.index + 1

    # Loss Plot 
    fig, ax = plt.subplots(figsize=(10, 8))
    
    ax.plot(plot_df["epoch"], plot_df["train_loss"], label="Training Loss",
            color="darkblue", linewidth=2)
    ax.plot(plot_df["epoch"], plot_df["val_loss"], label="Validation Loss",
            color="darkgreen", linewidth=2)
    
    # styling
    ax.set_xlabel("Epoch", fontsize=14)
    ax.set_ylabel("Loss", fontsize=14)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.grid(axis="y", alpha=0.7)
    ax.grid(axis="x", visible=False)
    ax.legend(fontsize=12)
    # save plot
    fig.savefig(f"outputs/loss_{model_name}.png", bbox_inches="tight")
    
    # Accuracy Plot
    fig, ax = plt.subplots(figsize=(10, 8))
    
    # Scale accuracy values to percentages
    plot_df["train_acc"] *= 100
    plot_df["val_acc"] *= 100
    
    # Plot training and validation accuracies
    ax.plot(plot_df["epoch"], plot_df["train_acc"], label="Training Accuracy",
            color="darkblue", linewidth=2)
    ax.plot(plot_df["epoch"], plot_df["val_acc"], label="Validation Accuracy",
            color="darkgreen", linewidth=2)
    
    # styling
    ax.set_xlabel("Epoch", fontsize=14)
    ax.set_ylabel("Accuracy (%)", fontsize=14)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.grid(axis="y", alpha=0.7)
    ax.grid(axis="x", visible=False)
    ax.legend(fontsize=12)
    # save plot
    fig.savefig(f"outputs/accuracy_{model_name}.png", bbox_inches="tight")
    plt.close("all")
    return

create_eval_plots(eval_metrics, "efficientnet_b0_freeze_weights")

# %%
# Load the checkpoint
checkpoint = torch.load(f"runs/model_efficientnet_b0.pth", weights_only=False)

# turn to function def rebuild model
# Load the pretrained EfficientNet model
trained_model = efficientnet_b0(pretrained=False) 

trained_model.classifier = nn.Sequential(
            nn.Linear(trained_model.classifier[1].in_features, 2048), 
            nn.BatchNorm1d(2048),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(2048, n_classes)  # Final output layer
)

for param in trained_model.parameters():
    param.requires_grad = True  # Enable fine tune training on all layers

trained_model.to(device)

# Define optimizer
optimizer = torch.optim.Adam(trained_model.parameters(), lr=0.0001, weight_decay=1e-3) # Use the same optimizer as before
# Load model and optimizer states
trained_model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

train_model(trained_model, "efficientnet_b0_final", val_loader_birds, None, criterion, optimizer, epochs=5, early_stop_limit=2)
# Out:
# c:\Users\Sean\.conda\envs\inat\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Sean\.conda\envs\inat\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Train Accuracy: 32.62%
# Top 5 Train Accuracy: 60.57%
# Epoch 1 - Train Loss: 3.3010
# Train Accuracy: 39.70%
# Top 5 Train Accuracy: 67.95%
# Epoch 2 - Train Loss: 2.8453
# Train Accuracy: 45.34%
# Top 5 Train Accuracy: 73.26%
# Epoch 3 - Train Loss: 2.5569
# Train Accuracy: 50.15%
# Top 5 Train Accuracy: 77.78%
# Epoch 4 - Train Loss: 2.3138
# Train Accuracy: 55.37%
# Top 5 Train Accuracy: 81.00%
# Epoch 5 - Train Loss: 2.1250
# {'train_loss': [3.300986986775552,
#   2.8453138866732197,
#   2.5569014439018822,
#   2.3137537510164323,
#   2.1250183730997065],
#  'val_loss': [3.300986986775552,
#   2.8453138866732197,
#   2.5569014439018822,
#   2.3137537510164323,
#   2.1250183730997065],
#  'train_acc': [0.3262449528936743,
#   0.39697173620457604,
#   0.4533647375504711,
#   0.5015477792732167,
#   0.5537012113055182],
#  'val_acc': [0.3262449528936743,
#   0.39697173620457604,
#   0.4533647375504711,
#   0.5015477792732167,
#   0.5537012113055182]}

# %%
# evaluate on test
val_loss, val_acc = run_epoch(trained_model, test_loader_birds, criterion, None, epoch=0, mode="validation")
# Out:
# Validation Accuracy: 41.81%
# Top 5 Validation Accuracy: 70.06%
# Epoch 1 - Validation Loss: 2.6836

# %%
save_model(trained_model, criterion, optimizer, epoch=18, model_name="efficientnet_b0_full_train")

# %%
bird_classes = [cat for cat in train_data.all_categories if "Animalia_Chordata_Aves" in cat]

# %%
# prepare to count predictions for each class
correct_pred = {classname: 0 for classname in bird_classes}
total_pred = {classname: 0 for classname in bird_classes}

# again no gradients needed
with torch.no_grad():
    for data in test_loader_birds:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        labels = remap_labels(labels).to(device)
        outputs = trained_model(images)
        _, predictions = torch.max(outputs, 1)
        # collect the correct predictions for each class
        for label, prediction in zip(labels, predictions):
            if label == prediction:
                correct_pred[bird_classes[label]] += 1
            total_pred[bird_classes[label]] += 1
# turn into dataframe and sort by smallest success classes
# then create confusion matrix for all classes - find the biggest misses


# print accuracy for each class
for classname, correct_count in correct_pred.items():
    accuracy = 100 * float(correct_count) / total_pred[classname]
    print(f'Accuracy for class: {classname:5s} is {accuracy:.1f} %')
# Out:
# Accuracy for class: 03111_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_badius is 60.0 %
# Accuracy for class: 03112_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_cooperii is 0.0 %
# Accuracy for class: 03113_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_gentilis is 0.0 %
# Accuracy for class: 03114_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_nisus is 0.0 %
# Accuracy for class: 03115_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_striatus is 10.0 %
# Accuracy for class: 03116_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_trivirgatus is 10.0 %
# Accuracy for class: 03117_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aegypius_monachus is 60.0 %
# Accuracy for class: 03118_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_audax is 0.0 %
# Accuracy for class: 03119_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_chrysaetos is 0.0 %
# Accuracy for class: 03120_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_heliaca is 0.0 %
# Accuracy for class: 03121_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_nipalensis is 50.0 %
# Accuracy for class: 03122_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_rapax is 30.0 %
# Accuracy for class: 03123_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Busarellus_nigricollis is 70.0 %
# Accuracy for class: 03124_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_albonotatus is 30.0 %
# Accuracy for class: 03125_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_brachyurus is 20.0 %
# Accuracy for class: 03126_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_buteo is 0.0 %
# Accuracy for class: 03127_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_jamaicensis is 20.0 %
# Accuracy for class: 03128_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_lagopus is 10.0 %
# Accuracy for class: 03129_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_lineatus is 10.0 %
# Accuracy for class: 03130_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_plagiatus is 50.0 %
# Accuracy for class: 03131_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_platypterus is 20.0 %
# Accuracy for class: 03132_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_regalis is 30.0 %
# Accuracy for class: 03133_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_rufinus is 10.0 %
# Accuracy for class: 03134_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_rufofuscus is 10.0 %
# Accuracy for class: 03135_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_swainsoni is 0.0 %
# Accuracy for class: 03136_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteogallus_anthracinus is 0.0 %
# Accuracy for class: 03137_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteogallus_meridionalis is 50.0 %
# Accuracy for class: 03138_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteogallus_urubitinga is 20.0 %
# Accuracy for class: 03139_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Chondrohierax_uncinatus is 30.0 %
# Accuracy for class: 03140_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circaetus_cinereus is 60.0 %
# Accuracy for class: 03141_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circaetus_gallicus is 40.0 %
# Accuracy for class: 03142_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circus_aeruginosus is 10.0 %
# Accuracy for class: 03143_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circus_approximans is 0.0 %
# Accuracy for class: 03144_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circus_cyaneus is 0.0 %
# Accuracy for class: 03145_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circus_hudsonius is 10.0 %
# Accuracy for class: 03146_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circus_macrourus is 0.0 %
# Accuracy for class: 03147_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circus_pygargus is 20.0 %
# Accuracy for class: 03148_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Clanga_clanga is 20.0 %
# Accuracy for class: 03149_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Elanoides_forficatus is 90.0 %
# Accuracy for class: 03150_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Elanus_axillaris is 10.0 %
# Accuracy for class: 03151_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Elanus_caeruleus is 10.0 %
# Accuracy for class: 03152_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Elanus_leucurus is 50.0 %
# Accuracy for class: 03153_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Geranoaetus_albicaudatus is 0.0 %
# Accuracy for class: 03154_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Geranoaetus_melanoleucus is 30.0 %
# Accuracy for class: 03155_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Geranoaetus_polyosoma is 20.0 %
# Accuracy for class: 03156_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Geranospiza_caerulescens is 40.0 %
# Accuracy for class: 03157_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Gypaetus_barbatus is 20.0 %
# Accuracy for class: 03158_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Gyps_africanus is 20.0 %
# Accuracy for class: 03159_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Gyps_fulvus is 40.0 %
# Accuracy for class: 03160_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Haliaeetus_albicilla is 40.0 %
# Accuracy for class: 03161_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Haliaeetus_leucocephalus is 10.0 %
# Accuracy for class: 03162_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Haliaeetus_leucogaster is 20.0 %
# Accuracy for class: 03163_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Haliaeetus_vocifer is 40.0 %
# Accuracy for class: 03164_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Haliastur_indus is 70.0 %
# Accuracy for class: 03165_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Haliastur_sphenurus is 10.0 %
# Accuracy for class: 03166_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Hieraaetus_pennatus is 50.0 %
# Accuracy for class: 03167_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Ictinia_mississippiensis is 0.0 %
# Accuracy for class: 03168_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Ictinia_plumbea is 50.0 %
# Accuracy for class: 03169_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Lophaetus_occipitalis is 60.0 %
# Accuracy for class: 03170_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Melierax_canorus is 50.0 %
# Accuracy for class: 03171_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Milvus_migrans is 0.0 %
# Accuracy for class: 03172_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Milvus_milvus is 20.0 %
# Accuracy for class: 03173_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Necrosyrtes_monachus is 30.0 %
# Accuracy for class: 03174_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Neophron_percnopterus is 50.0 %
# Accuracy for class: 03175_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Nisaetus_cirrhatus is 50.0 %
# Accuracy for class: 03176_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Parabuteo_unicinctus is 20.0 %
# Accuracy for class: 03177_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Pernis_apivorus is 20.0 %
# Accuracy for class: 03178_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Pernis_ptilorhynchus is 30.0 %
# Accuracy for class: 03179_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Polemaetus_bellicosus is 30.0 %
# Accuracy for class: 03180_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Polyboroides_typus is 30.0 %
# Accuracy for class: 03181_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Rostrhamus_sociabilis is 0.0 %
# Accuracy for class: 03182_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Rupornis_magnirostris is 40.0 %
# Accuracy for class: 03183_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Spilornis_cheela is 50.0 %
# Accuracy for class: 03184_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Terathopius_ecaudatus is 50.0 %
# Accuracy for class: 03185_Animalia_Chordata_Aves_Accipitriformes_Pandionidae_Pandion_haliaetus is 20.0 %
# Accuracy for class: 03186_Animalia_Chordata_Aves_Accipitriformes_Sagittariidae_Sagittarius_serpentarius is 50.0 %
# Accuracy for class: 03187_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aix_galericulata is 30.0 %
# Accuracy for class: 03188_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aix_sponsa is 40.0 %
# Accuracy for class: 03189_Animalia_Chordata_Aves_Anseriformes_Anatidae_Alopochen_aegyptiaca is 20.0 %
# Accuracy for class: 03190_Animalia_Chordata_Aves_Anseriformes_Anatidae_Amazonetta_brasiliensis is 40.0 %
# Accuracy for class: 03191_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_acuta is 50.0 %
# Accuracy for class: 03192_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_bahamensis is 70.0 %
# Accuracy for class: 03193_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_castanea is 60.0 %
# Accuracy for class: 03194_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_crecca is 40.0 %
# Accuracy for class: 03195_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_diazi is 20.0 %
# Accuracy for class: 03196_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_erythrorhyncha is 80.0 %
# Accuracy for class: 03197_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_flavirostris is 50.0 %
# Accuracy for class: 03198_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_fulvigula is 50.0 %
# Accuracy for class: 03199_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_georgica is 40.0 %
# Accuracy for class: 03200_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_gracilis is 60.0 %
# Accuracy for class: 03201_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_platyrhynchos is 30.0 %
# Accuracy for class: 03202_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_poecilorhyncha is 30.0 %
# Accuracy for class: 03203_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_rubripes is 20.0 %
# Accuracy for class: 03204_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_superciliosa is 50.0 %
# Accuracy for class: 03205_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_undulata is 50.0 %
# Accuracy for class: 03206_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_zonorhyncha is 50.0 %
# Accuracy for class: 03207_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_albifrons is 30.0 %
# Accuracy for class: 03208_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_anser is 30.0 %
# Accuracy for class: 03209_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_brachyrhynchus is 50.0 %
# Accuracy for class: 03210_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_caerulescens is 10.0 %
# Accuracy for class: 03211_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_cygnoides is 60.0 %
# Accuracy for class: 03212_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_fabalis is 10.0 %
# Accuracy for class: 03213_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_indicus is 70.0 %
# Accuracy for class: 03214_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_rossii is 60.0 %
# Accuracy for class: 03215_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_affinis is 30.0 %
# Accuracy for class: 03216_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_americana is 40.0 %
# Accuracy for class: 03217_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_australis is 60.0 %
# Accuracy for class: 03218_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_collaris is 50.0 %
# Accuracy for class: 03219_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_ferina is 0.0 %
# Accuracy for class: 03220_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_fuligula is 10.0 %
# Accuracy for class: 03221_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_marila is 0.0 %
# Accuracy for class: 03222_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_novaeseelandiae is 60.0 %
# Accuracy for class: 03223_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_nyroca is 30.0 %
# Accuracy for class: 03224_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_valisineria is 70.0 %
# Accuracy for class: 03225_Animalia_Chordata_Aves_Anseriformes_Anatidae_Branta_bernicla is 50.0 %
# Accuracy for class: 03226_Animalia_Chordata_Aves_Anseriformes_Anatidae_Branta_canadensis is 30.0 %
# Accuracy for class: 03227_Animalia_Chordata_Aves_Anseriformes_Anatidae_Branta_hutchinsii is 50.0 %
# Accuracy for class: 03228_Animalia_Chordata_Aves_Anseriformes_Anatidae_Branta_leucopsis is 70.0 %
# Accuracy for class: 03229_Animalia_Chordata_Aves_Anseriformes_Anatidae_Branta_sandvicensis is 60.0 %
# Accuracy for class: 03230_Animalia_Chordata_Aves_Anseriformes_Anatidae_Bucephala_albeola is 60.0 %
# Accuracy for class: 03231_Animalia_Chordata_Aves_Anseriformes_Anatidae_Bucephala_clangula is 10.0 %
# Accuracy for class: 03232_Animalia_Chordata_Aves_Anseriformes_Anatidae_Bucephala_islandica is 90.0 %
# Accuracy for class: 03233_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cairina_moschata is 40.0 %
# Accuracy for class: 03234_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cereopsis_novaehollandiae is 70.0 %
# Accuracy for class: 03235_Animalia_Chordata_Aves_Anseriformes_Anatidae_Chenonetta_jubata is 90.0 %
# Accuracy for class: 03236_Animalia_Chordata_Aves_Anseriformes_Anatidae_Chloephaga_picta is 40.0 %
# Accuracy for class: 03237_Animalia_Chordata_Aves_Anseriformes_Anatidae_Clangula_hyemalis is 40.0 %
# Accuracy for class: 03238_Animalia_Chordata_Aves_Anseriformes_Anatidae_Coscoroba_coscoroba is 60.0 %
# Accuracy for class: 03239_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cygnus_atratus is 60.0 %
# Accuracy for class: 03240_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cygnus_buccinator is 40.0 %
# Accuracy for class: 03241_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cygnus_columbianus is 30.0 %
# Accuracy for class: 03242_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cygnus_cygnus is 40.0 %
# Accuracy for class: 03243_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cygnus_melancoryphus is 80.0 %
# Accuracy for class: 03244_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cygnus_olor is 40.0 %
# Accuracy for class: 03245_Animalia_Chordata_Aves_Anseriformes_Anatidae_Dendrocygna_autumnalis is 50.0 %
# Accuracy for class: 03246_Animalia_Chordata_Aves_Anseriformes_Anatidae_Dendrocygna_bicolor is 50.0 %
# Accuracy for class: 03247_Animalia_Chordata_Aves_Anseriformes_Anatidae_Dendrocygna_javanica is 50.0 %
# Accuracy for class: 03248_Animalia_Chordata_Aves_Anseriformes_Anatidae_Dendrocygna_viduata is 50.0 %
# Accuracy for class: 03249_Animalia_Chordata_Aves_Anseriformes_Anatidae_Histrionicus_histrionicus is 60.0 %
# Accuracy for class: 03250_Animalia_Chordata_Aves_Anseriformes_Anatidae_Lophodytes_cucullatus is 20.0 %
# Accuracy for class: 03251_Animalia_Chordata_Aves_Anseriformes_Anatidae_Lophonetta_specularioides is 80.0 %
# Accuracy for class: 03252_Animalia_Chordata_Aves_Anseriformes_Anatidae_Malacorhynchus_membranaceus is 70.0 %
# Accuracy for class: 03253_Animalia_Chordata_Aves_Anseriformes_Anatidae_Mareca_americana is 30.0 %
# Accuracy for class: 03254_Animalia_Chordata_Aves_Anseriformes_Anatidae_Mareca_penelope is 60.0 %
# Accuracy for class: 03255_Animalia_Chordata_Aves_Anseriformes_Anatidae_Mareca_strepera is 30.0 %
# Accuracy for class: 03256_Animalia_Chordata_Aves_Anseriformes_Anatidae_Melanitta_americana is 30.0 %
# Accuracy for class: 03257_Animalia_Chordata_Aves_Anseriformes_Anatidae_Melanitta_deglandi is 30.0 %
# Accuracy for class: 03258_Animalia_Chordata_Aves_Anseriformes_Anatidae_Melanitta_perspicillata is 50.0 %
# Accuracy for class: 03259_Animalia_Chordata_Aves_Anseriformes_Anatidae_Mergellus_albellus is 0.0 %
# Accuracy for class: 03260_Animalia_Chordata_Aves_Anseriformes_Anatidae_Mergus_merganser is 40.0 %
# Accuracy for class: 03261_Animalia_Chordata_Aves_Anseriformes_Anatidae_Mergus_serrator is 30.0 %
# Accuracy for class: 03262_Animalia_Chordata_Aves_Anseriformes_Anatidae_Netta_peposaca is 60.0 %
# Accuracy for class: 03263_Animalia_Chordata_Aves_Anseriformes_Anatidae_Netta_rufina is 50.0 %
# Accuracy for class: 03264_Animalia_Chordata_Aves_Anseriformes_Anatidae_Oxyura_jamaicensis is 50.0 %
# Accuracy for class: 03265_Animalia_Chordata_Aves_Anseriformes_Anatidae_Plectropterus_gambensis is 20.0 %
# Accuracy for class: 03266_Animalia_Chordata_Aves_Anseriformes_Anatidae_Sarkidiornis_melanotos is 60.0 %
# Accuracy for class: 03267_Animalia_Chordata_Aves_Anseriformes_Anatidae_Somateria_mollissima is 30.0 %
# Accuracy for class: 03268_Animalia_Chordata_Aves_Anseriformes_Anatidae_Spatula_clypeata is 70.0 %
# Accuracy for class: 03269_Animalia_Chordata_Aves_Anseriformes_Anatidae_Spatula_cyanoptera is 80.0 %
# Accuracy for class: 03270_Animalia_Chordata_Aves_Anseriformes_Anatidae_Spatula_discors is 10.0 %
# Accuracy for class: 03271_Animalia_Chordata_Aves_Anseriformes_Anatidae_Spatula_querquedula is 20.0 %
# Accuracy for class: 03272_Animalia_Chordata_Aves_Anseriformes_Anatidae_Spatula_rhynchotis is 60.0 %
# Accuracy for class: 03273_Animalia_Chordata_Aves_Anseriformes_Anatidae_Tadorna_ferruginea is 60.0 %
# Accuracy for class: 03274_Animalia_Chordata_Aves_Anseriformes_Anatidae_Tadorna_tadorna is 20.0 %
# Accuracy for class: 03275_Animalia_Chordata_Aves_Anseriformes_Anatidae_Tadorna_tadornoides is 60.0 %
# Accuracy for class: 03276_Animalia_Chordata_Aves_Anseriformes_Anatidae_Tadorna_variegata is 30.0 %
# Accuracy for class: 03277_Animalia_Chordata_Aves_Anseriformes_Anhimidae_Chauna_torquata is 70.0 %
# Accuracy for class: 03278_Animalia_Chordata_Aves_Anseriformes_Anseranatidae_Anseranas_semipalmata is 50.0 %
# Accuracy for class: 03279_Animalia_Chordata_Aves_Bucerotiformes_Bucerotidae_Anthracoceros_albirostris is 70.0 %
# Accuracy for class: 03280_Animalia_Chordata_Aves_Bucerotiformes_Bucerotidae_Lophoceros_alboterminatus is 70.0 %
# Accuracy for class: 03281_Animalia_Chordata_Aves_Bucerotiformes_Bucerotidae_Lophoceros_nasutus is 60.0 %
# Accuracy for class: 03282_Animalia_Chordata_Aves_Bucerotiformes_Bucerotidae_Tockus_leucomelas is 90.0 %
# Accuracy for class: 03283_Animalia_Chordata_Aves_Bucerotiformes_Bucorvidae_Bucorvus_leadbeateri is 70.0 %
# Accuracy for class: 03284_Animalia_Chordata_Aves_Bucerotiformes_Phoeniculidae_Phoeniculus_purpureus is 80.0 %
# Accuracy for class: 03285_Animalia_Chordata_Aves_Bucerotiformes_Upupidae_Upupa_epops is 60.0 %
# Accuracy for class: 03286_Animalia_Chordata_Aves_Caprimulgiformes_Apodidae_Aeronautes_saxatalis is 60.0 %
# Accuracy for class: 03287_Animalia_Chordata_Aves_Caprimulgiformes_Apodidae_Apus_apus is 20.0 %
# Accuracy for class: 03288_Animalia_Chordata_Aves_Caprimulgiformes_Apodidae_Chaetura_pelagica is 0.0 %
# Accuracy for class: 03289_Animalia_Chordata_Aves_Caprimulgiformes_Apodidae_Chaetura_vauxi is 20.0 %
# Accuracy for class: 03290_Animalia_Chordata_Aves_Caprimulgiformes_Caprimulgidae_Caprimulgus_europaeus is 20.0 %
# Accuracy for class: 03291_Animalia_Chordata_Aves_Caprimulgiformes_Caprimulgidae_Chordeiles_acutipennis is 0.0 %
# Accuracy for class: 03292_Animalia_Chordata_Aves_Caprimulgiformes_Caprimulgidae_Chordeiles_minor is 50.0 %
# Accuracy for class: 03293_Animalia_Chordata_Aves_Caprimulgiformes_Caprimulgidae_Nyctidromus_albicollis is 60.0 %
# Accuracy for class: 03294_Animalia_Chordata_Aves_Caprimulgiformes_Caprimulgidae_Phalaenoptilus_nuttallii is 100.0 %
# Accuracy for class: 03295_Animalia_Chordata_Aves_Caprimulgiformes_Nyctibiidae_Nyctibius_griseus is 40.0 %
# Accuracy for class: 03296_Animalia_Chordata_Aves_Caprimulgiformes_Nyctibiidae_Nyctibius_jamaicensis is 30.0 %
# Accuracy for class: 03297_Animalia_Chordata_Aves_Caprimulgiformes_Podargidae_Podargus_strigoides is 70.0 %
# Accuracy for class: 03298_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Amazilia_beryllina is 0.0 %
# Accuracy for class: 03299_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Amazilia_cyanocephala is 50.0 %
# Accuracy for class: 03300_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Amazilia_rutila is 60.0 %
# Accuracy for class: 03301_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Amazilia_tzacatl is 40.0 %
# Accuracy for class: 03302_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Amazilia_violiceps is 80.0 %
# Accuracy for class: 03303_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Amazilia_yucatanensis is 50.0 %
# Accuracy for class: 03304_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Anthracothorax_nigricollis is 40.0 %
# Accuracy for class: 03305_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Anthracothorax_prevostii is 20.0 %
# Accuracy for class: 03306_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Archilochus_alexandri is 50.0 %
# Accuracy for class: 03307_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Archilochus_colubris is 0.0 %
# Accuracy for class: 03308_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Boissonneaua_flavescens is 60.0 %
# Accuracy for class: 03309_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Calothorax_lucifer is 30.0 %
# Accuracy for class: 03310_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Calypte_anna is 0.0 %
# Accuracy for class: 03311_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Calypte_costae is 0.0 %
# Accuracy for class: 03312_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Campylopterus_hemileucurus is 40.0 %
# Accuracy for class: 03313_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Chlorostilbon_canivetii is 0.0 %
# Accuracy for class: 03314_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Chlorostilbon_lucidus is 50.0 %
# Accuracy for class: 03315_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Colibri_coruscans is 0.0 %
# Accuracy for class: 03316_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Colibri_cyanotus is 70.0 %
# Accuracy for class: 03317_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Cynanthus_latirostris is 0.0 %
# Accuracy for class: 03318_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Eugenes_fulgens is 40.0 %
# Accuracy for class: 03319_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Eupetomena_macroura is 30.0 %
# Accuracy for class: 03320_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Florisuga_mellivora is 80.0 %
# Accuracy for class: 03321_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Heliodoxa_jacula is 60.0 %
# Accuracy for class: 03322_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Hylocharis_leucotis is 30.0 %
# Accuracy for class: 03323_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Lampornis_clemenciae is 60.0 %
# Accuracy for class: 03324_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Ocreatus_underwoodii is 50.0 %
# Accuracy for class: 03325_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Selasphorus_calliope is 20.0 %
# Accuracy for class: 03326_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Selasphorus_platycercus is 0.0 %
# Accuracy for class: 03327_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Selasphorus_rufus is 30.0 %
# Accuracy for class: 03328_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Selasphorus_sasin is 40.0 %
# Accuracy for class: 03329_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Thalurania_colombica is 70.0 %
# Accuracy for class: 03330_Animalia_Chordata_Aves_Casuariiformes_Casuariidae_Dromaius_novaehollandiae is 70.0 %
# Accuracy for class: 03331_Animalia_Chordata_Aves_Cathartiformes_Cathartidae_Cathartes_aura is 30.0 %
# Accuracy for class: 03332_Animalia_Chordata_Aves_Cathartiformes_Cathartidae_Cathartes_burrovianus is 50.0 %
# Accuracy for class: 03333_Animalia_Chordata_Aves_Cathartiformes_Cathartidae_Coragyps_atratus is 20.0 %
# Accuracy for class: 03334_Animalia_Chordata_Aves_Cathartiformes_Cathartidae_Gymnogyps_californianus is 30.0 %
# Accuracy for class: 03335_Animalia_Chordata_Aves_Cathartiformes_Cathartidae_Sarcoramphus_papa is 60.0 %
# Accuracy for class: 03336_Animalia_Chordata_Aves_Cathartiformes_Cathartidae_Vultur_gryphus is 50.0 %
# Accuracy for class: 03337_Animalia_Chordata_Aves_Charadriiformes_Alcidae_Alca_torda is 20.0 %
# Accuracy for class: 03338_Animalia_Chordata_Aves_Charadriiformes_Alcidae_Brachyramphus_marmoratus is 30.0 %
# Accuracy for class: 03339_Animalia_Chordata_Aves_Charadriiformes_Alcidae_Cepphus_columba is 10.0 %
# Accuracy for class: 03340_Animalia_Chordata_Aves_Charadriiformes_Alcidae_Cepphus_grylle is 20.0 %
# Accuracy for class: 03341_Animalia_Chordata_Aves_Charadriiformes_Alcidae_Cerorhinca_monocerata is 30.0 %
# Accuracy for class: 03342_Animalia_Chordata_Aves_Charadriiformes_Alcidae_Fratercula_arctica is 50.0 %
# Accuracy for class: 03343_Animalia_Chordata_Aves_Charadriiformes_Alcidae_Uria_aalge is 10.0 %
# Accuracy for class: 03344_Animalia_Chordata_Aves_Charadriiformes_Burhinidae_Burhinus_bistriatus is 80.0 %
# Accuracy for class: 03345_Animalia_Chordata_Aves_Charadriiformes_Burhinidae_Burhinus_capensis is 80.0 %
# Accuracy for class: 03346_Animalia_Chordata_Aves_Charadriiformes_Burhinidae_Burhinus_grallarius is 60.0 %
# Accuracy for class: 03347_Animalia_Chordata_Aves_Charadriiformes_Burhinidae_Burhinus_vermiculatus is 70.0 %
# Accuracy for class: 03348_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_alexandrinus is 70.0 %
# Accuracy for class: 03349_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_bicinctus is 40.0 %
# Accuracy for class: 03350_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_collaris is 30.0 %
# Accuracy for class: 03351_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_dubius is 50.0 %
# Accuracy for class: 03352_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_hiaticula is 60.0 %
# Accuracy for class: 03353_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_leschenaultii is 20.0 %
# Accuracy for class: 03354_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_marginatus is 20.0 %
# Accuracy for class: 03355_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_melodus is 50.0 %
# Accuracy for class: 03356_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_mongolus is 30.0 %
# Accuracy for class: 03357_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_nivosus is 30.0 %
# Accuracy for class: 03358_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_obscurus is 50.0 %
# Accuracy for class: 03359_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_pecuarius is 60.0 %
# Accuracy for class: 03360_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_ruficapillus is 50.0 %
# Accuracy for class: 03361_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_semipalmatus is 10.0 %
# Accuracy for class: 03362_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_tricollaris is 80.0 %
# Accuracy for class: 03363_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_vociferus is 30.0 %
# Accuracy for class: 03364_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_wilsonia is 70.0 %
# Accuracy for class: 03365_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Elseyornis_melanops is 90.0 %
# Accuracy for class: 03366_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Pluvialis_apricaria is 10.0 %
# Accuracy for class: 03367_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Pluvialis_dominica is 30.0 %
# Accuracy for class: 03368_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Pluvialis_fulva is 0.0 %
# Accuracy for class: 03369_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Pluvialis_squatarola is 30.0 %
# Accuracy for class: 03370_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_armatus is 70.0 %
# Accuracy for class: 03371_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_chilensis is 80.0 %
# Accuracy for class: 03372_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_coronatus is 70.0 %
# Accuracy for class: 03373_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_indicus is 70.0 %
# Accuracy for class: 03374_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_miles is 60.0 %
# Accuracy for class: 03375_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_senegallus is 80.0 %
# Accuracy for class: 03376_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_spinosus is 60.0 %
# Accuracy for class: 03377_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_vanellus is 10.0 %
# Accuracy for class: 03378_Animalia_Chordata_Aves_Charadriiformes_Glareolidae_Glareola_pratincola is 70.0 %
# Accuracy for class: 03379_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_bachmani is 30.0 %
# Accuracy for class: 03380_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_finschi is 30.0 %
# Accuracy for class: 03381_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_fuliginosus is 30.0 %
# Accuracy for class: 03382_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_longirostris is 20.0 %
# Accuracy for class: 03383_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_moquini is 30.0 %
# Accuracy for class: 03384_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_ostralegus is 10.0 %
# Accuracy for class: 03385_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_palliatus is 30.0 %
# Accuracy for class: 03386_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_unicolor is 30.0 %
# Accuracy for class: 03387_Animalia_Chordata_Aves_Charadriiformes_Jacanidae_Actophilornis_africanus is 90.0 %
# Accuracy for class: 03388_Animalia_Chordata_Aves_Charadriiformes_Jacanidae_Hydrophasianus_chirurgus is 70.0 %
# Accuracy for class: 03389_Animalia_Chordata_Aves_Charadriiformes_Jacanidae_Irediparra_gallinacea is 90.0 %
# Accuracy for class: 03390_Animalia_Chordata_Aves_Charadriiformes_Jacanidae_Jacana_jacana is 80.0 %
# Accuracy for class: 03391_Animalia_Chordata_Aves_Charadriiformes_Jacanidae_Jacana_spinosa is 60.0 %
# Accuracy for class: 03392_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chlidonias_hybrida is 30.0 %
# Accuracy for class: 03393_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chlidonias_leucopterus is 30.0 %
# Accuracy for class: 03394_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chlidonias_niger is 20.0 %
# Accuracy for class: 03395_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_bulleri is 60.0 %
# Accuracy for class: 03396_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_cirrocephalus is 70.0 %
# Accuracy for class: 03397_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_genei is 30.0 %
# Accuracy for class: 03398_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_hartlaubii is 20.0 %
# Accuracy for class: 03399_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_maculipennis is 30.0 %
# Accuracy for class: 03400_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_novaehollandiae is 30.0 %
# Accuracy for class: 03401_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_philadelphia is 10.0 %
# Accuracy for class: 03402_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_ridibundus is 0.0 %
# Accuracy for class: 03403_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_serranus is 30.0 %
# Accuracy for class: 03404_Animalia_Chordata_Aves_Charadriiformes_Laridae_Gelochelidon_nilotica is 20.0 %
# Accuracy for class: 03405_Animalia_Chordata_Aves_Charadriiformes_Laridae_Hydrocoloeus_minutus is 20.0 %
# Accuracy for class: 03406_Animalia_Chordata_Aves_Charadriiformes_Laridae_Hydroprogne_caspia is 40.0 %
# Accuracy for class: 03407_Animalia_Chordata_Aves_Charadriiformes_Laridae_Ichthyaetus_ichthyaetus is 50.0 %
# Accuracy for class: 03408_Animalia_Chordata_Aves_Charadriiformes_Laridae_Ichthyaetus_melanocephalus is 30.0 %
# Accuracy for class: 03409_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_argentatus is 0.0 %
# Accuracy for class: 03410_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_cachinnans is 10.0 %
# Accuracy for class: 03411_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_californicus is 30.0 %
# Accuracy for class: 03412_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_canus is 10.0 %
# Accuracy for class: 03413_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_crassirostris is 0.0 %
# Accuracy for class: 03414_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_delawarensis is 10.0 %
# Accuracy for class: 03415_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_dominicanus is 10.0 %
# Accuracy for class: 03416_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_fuscus is 20.0 %
# Accuracy for class: 03417_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_glaucescens is 30.0 %
# Accuracy for class: 03418_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_glaucoides is 10.0 %
# Accuracy for class: 03419_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_heermanni is 60.0 %
# Accuracy for class: 03420_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_hyperboreus is 10.0 %
# Accuracy for class: 03421_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_livens is 50.0 %
# Accuracy for class: 03422_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_marinus is 10.0 %
# Accuracy for class: 03423_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_michahellis is 20.0 %
# Accuracy for class: 03424_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_occidentalis is 40.0 %
# Accuracy for class: 03425_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_pacificus is 30.0 %
# Accuracy for class: 03426_Animalia_Chordata_Aves_Charadriiformes_Laridae_Leucophaeus_atricilla is 20.0 %
# Accuracy for class: 03427_Animalia_Chordata_Aves_Charadriiformes_Laridae_Leucophaeus_pipixcan is 10.0 %
# Accuracy for class: 03428_Animalia_Chordata_Aves_Charadriiformes_Laridae_Phaetusa_simplex is 60.0 %
# Accuracy for class: 03429_Animalia_Chordata_Aves_Charadriiformes_Laridae_Rissa_tridactyla is 10.0 %
# Accuracy for class: 03430_Animalia_Chordata_Aves_Charadriiformes_Laridae_Rynchops_niger is 70.0 %
# Accuracy for class: 03431_Animalia_Chordata_Aves_Charadriiformes_Laridae_Sterna_forsteri is 10.0 %
# Accuracy for class: 03432_Animalia_Chordata_Aves_Charadriiformes_Laridae_Sterna_hirundo is 30.0 %
# Accuracy for class: 03433_Animalia_Chordata_Aves_Charadriiformes_Laridae_Sterna_paradisaea is 20.0 %
# Accuracy for class: 03434_Animalia_Chordata_Aves_Charadriiformes_Laridae_Sterna_striata is 70.0 %
# Accuracy for class: 03435_Animalia_Chordata_Aves_Charadriiformes_Laridae_Sternula_albifrons is 20.0 %
# Accuracy for class: 03436_Animalia_Chordata_Aves_Charadriiformes_Laridae_Sternula_antillarum is 20.0 %
# Accuracy for class: 03437_Animalia_Chordata_Aves_Charadriiformes_Laridae_Thalasseus_bergii is 40.0 %
# Accuracy for class: 03438_Animalia_Chordata_Aves_Charadriiformes_Laridae_Thalasseus_elegans is 40.0 %
# Accuracy for class: 03439_Animalia_Chordata_Aves_Charadriiformes_Laridae_Thalasseus_maximus is 40.0 %
# Accuracy for class: 03440_Animalia_Chordata_Aves_Charadriiformes_Laridae_Thalasseus_sandvicensis is 20.0 %
# Accuracy for class: 03441_Animalia_Chordata_Aves_Charadriiformes_Recurvirostridae_Himantopus_himantopus is 50.0 %
# Accuracy for class: 03442_Animalia_Chordata_Aves_Charadriiformes_Recurvirostridae_Himantopus_leucocephalus is 20.0 %
# Accuracy for class: 03443_Animalia_Chordata_Aves_Charadriiformes_Recurvirostridae_Himantopus_mexicanus is 60.0 %
# Accuracy for class: 03444_Animalia_Chordata_Aves_Charadriiformes_Recurvirostridae_Recurvirostra_americana is 60.0 %
# Accuracy for class: 03445_Animalia_Chordata_Aves_Charadriiformes_Recurvirostridae_Recurvirostra_avosetta is 70.0 %
# Accuracy for class: 03446_Animalia_Chordata_Aves_Charadriiformes_Rostratulidae_Rostratula_benghalensis is 60.0 %
# Accuracy for class: 03447_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Actitis_hypoleucos is 10.0 %
# Accuracy for class: 03448_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Actitis_macularius is 10.0 %
# Accuracy for class: 03449_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Arenaria_interpres is 40.0 %
# Accuracy for class: 03450_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Arenaria_melanocephala is 40.0 %
# Accuracy for class: 03451_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Bartramia_longicauda is 70.0 %
# Accuracy for class: 03452_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_acuminata is 50.0 %
# Accuracy for class: 03453_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_alba is 40.0 %
# Accuracy for class: 03454_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_alpina is 30.0 %
# Accuracy for class: 03455_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_bairdii is 50.0 %
# Accuracy for class: 03456_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_canutus is 30.0 %
# Accuracy for class: 03457_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_ferruginea is 30.0 %
# Accuracy for class: 03458_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_fuscicollis is 30.0 %
# Accuracy for class: 03459_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_himantopus is 0.0 %
# Accuracy for class: 03460_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_maritima is 60.0 %
# Accuracy for class: 03461_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_mauri is 30.0 %
# Accuracy for class: 03462_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_melanotos is 50.0 %
# Accuracy for class: 03463_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_minuta is 30.0 %
# Accuracy for class: 03464_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_minutilla is 10.0 %
# Accuracy for class: 03465_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_pugnax is 10.0 %
# Accuracy for class: 03466_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_pusilla is 50.0 %
# Accuracy for class: 03467_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_ruficollis is 40.0 %
# Accuracy for class: 03468_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_subruficollis is 20.0 %
# Accuracy for class: 03469_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_temminckii is 50.0 %
# Accuracy for class: 03470_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_virgata is 60.0 %
# Accuracy for class: 03471_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Gallinago_delicata is 30.0 %
# Accuracy for class: 03472_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Gallinago_gallinago is 50.0 %
# Accuracy for class: 03473_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Limnodromus_griseus is 10.0 %
# Accuracy for class: 03474_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Limnodromus_scolopaceus is 40.0 %
# Accuracy for class: 03475_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Limosa_fedoa is 60.0 %
# Accuracy for class: 03476_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Limosa_haemastica is 30.0 %
# Accuracy for class: 03477_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Limosa_lapponica is 10.0 %
# Accuracy for class: 03478_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Limosa_limosa is 50.0 %
# Accuracy for class: 03479_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Numenius_americanus is 10.0 %
# Accuracy for class: 03480_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Numenius_arquata is 30.0 %
# Accuracy for class: 03481_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Numenius_madagascariensis is 70.0 %
# Accuracy for class: 03482_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Numenius_phaeopus is 30.0 %
# Accuracy for class: 03483_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Phalaropus_fulicarius is 40.0 %
# Accuracy for class: 03484_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Phalaropus_lobatus is 40.0 %
# Accuracy for class: 03485_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Phalaropus_tricolor is 30.0 %
# Accuracy for class: 03486_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Scolopax_minor is 70.0 %
# Accuracy for class: 03487_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_brevipes is 80.0 %
# Accuracy for class: 03488_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_erythropus is 30.0 %
# Accuracy for class: 03489_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_flavipes is 10.0 %
# Accuracy for class: 03490_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_glareola is 40.0 %
# Accuracy for class: 03491_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_incana is 20.0 %
# Accuracy for class: 03492_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_melanoleuca is 20.0 %
# Accuracy for class: 03493_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_nebularia is 20.0 %
# Accuracy for class: 03494_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_ochropus is 40.0 %
# Accuracy for class: 03495_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_semipalmata is 40.0 %
# Accuracy for class: 03496_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_solitaria is 50.0 %
# Accuracy for class: 03497_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_stagnatilis is 30.0 %
# Accuracy for class: 03498_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_totanus is 20.0 %
# Accuracy for class: 03499_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Xenus_cinereus is 30.0 %
# Accuracy for class: 03500_Animalia_Chordata_Aves_Charadriiformes_Stercorariidae_Stercorarius_parasiticus is 10.0 %
# Accuracy for class: 03501_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Anastomus_oscitans is 30.0 %
# Accuracy for class: 03502_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Ciconia_ciconia is 60.0 %
# Accuracy for class: 03503_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Ciconia_episcopus is 80.0 %
# Accuracy for class: 03504_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Ciconia_maguari is 40.0 %
# Accuracy for class: 03505_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Ciconia_nigra is 10.0 %
# Accuracy for class: 03506_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Jabiru_mycteria is 70.0 %
# Accuracy for class: 03507_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Leptoptilos_crumenifer is 40.0 %
# Accuracy for class: 03508_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Mycteria_americana is 20.0 %
# Accuracy for class: 03509_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Mycteria_ibis is 90.0 %
# Accuracy for class: 03510_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Mycteria_leucocephala is 40.0 %
# Accuracy for class: 03511_Animalia_Chordata_Aves_Coliiformes_Coliidae_Colius_striatus is 80.0 %
# Accuracy for class: 03512_Animalia_Chordata_Aves_Columbiformes_Columbidae_Chalcophaps_indica is 90.0 %
# Accuracy for class: 03513_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columba_guinea is 40.0 %
# Accuracy for class: 03514_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columba_livia is 60.0 %
# Accuracy for class: 03515_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columba_oenas is 30.0 %
# Accuracy for class: 03516_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columba_palumbus is 60.0 %
# Accuracy for class: 03517_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columbina_inca is 30.0 %
# Accuracy for class: 03518_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columbina_passerina is 50.0 %
# Accuracy for class: 03519_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columbina_picui is 10.0 %
# Accuracy for class: 03520_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columbina_talpacoti is 40.0 %
# Accuracy for class: 03521_Animalia_Chordata_Aves_Columbiformes_Columbidae_Geopelia_humeralis is 70.0 %
# Accuracy for class: 03522_Animalia_Chordata_Aves_Columbiformes_Columbidae_Geopelia_placida is 70.0 %
# Accuracy for class: 03523_Animalia_Chordata_Aves_Columbiformes_Columbidae_Geopelia_striata is 30.0 %
# Accuracy for class: 03524_Animalia_Chordata_Aves_Columbiformes_Columbidae_Hemiphaga_novaeseelandiae is 50.0 %
# Accuracy for class: 03525_Animalia_Chordata_Aves_Columbiformes_Columbidae_Leptotila_verreauxi is 70.0 %
# Accuracy for class: 03526_Animalia_Chordata_Aves_Columbiformes_Columbidae_Ocyphaps_lophotes is 90.0 %
# Accuracy for class: 03527_Animalia_Chordata_Aves_Columbiformes_Columbidae_Patagioenas_cayennensis is 70.0 %
# Accuracy for class: 03528_Animalia_Chordata_Aves_Columbiformes_Columbidae_Patagioenas_fasciata is 0.0 %
# Accuracy for class: 03529_Animalia_Chordata_Aves_Columbiformes_Columbidae_Patagioenas_flavirostris is 30.0 %
# Accuracy for class: 03530_Animalia_Chordata_Aves_Columbiformes_Columbidae_Patagioenas_leucocephala is 50.0 %
# Accuracy for class: 03531_Animalia_Chordata_Aves_Columbiformes_Columbidae_Patagioenas_maculosa is 80.0 %
# Accuracy for class: 03532_Animalia_Chordata_Aves_Columbiformes_Columbidae_Patagioenas_picazuro is 60.0 %
# Accuracy for class: 03533_Animalia_Chordata_Aves_Columbiformes_Columbidae_Phaps_chalcoptera is 60.0 %
# Accuracy for class: 03534_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_capicola is 20.0 %
# Accuracy for class: 03535_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_chinensis is 30.0 %
# Accuracy for class: 03536_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_decaocto is 30.0 %
# Accuracy for class: 03537_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_orientalis is 50.0 %
# Accuracy for class: 03538_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_semitorquata is 70.0 %
# Accuracy for class: 03539_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_senegalensis is 50.0 %
# Accuracy for class: 03540_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_tranquebarica is 50.0 %
# Accuracy for class: 03541_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_turtur is 70.0 %
# Accuracy for class: 03542_Animalia_Chordata_Aves_Columbiformes_Columbidae_Treron_calvus is 10.0 %
# Accuracy for class: 03543_Animalia_Chordata_Aves_Columbiformes_Columbidae_Treron_vernans is 50.0 %
# Accuracy for class: 03544_Animalia_Chordata_Aves_Columbiformes_Columbidae_Zenaida_asiatica is 20.0 %
# Accuracy for class: 03545_Animalia_Chordata_Aves_Columbiformes_Columbidae_Zenaida_auriculata is 50.0 %
# Accuracy for class: 03546_Animalia_Chordata_Aves_Columbiformes_Columbidae_Zenaida_aurita is 50.0 %
# Accuracy for class: 03547_Animalia_Chordata_Aves_Columbiformes_Columbidae_Zenaida_macroura is 0.0 %
# Accuracy for class: 03548_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Alcedo_atthis is 70.0 %
# Accuracy for class: 03549_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Ceryle_rudis is 80.0 %
# Accuracy for class: 03550_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Chloroceryle_amazona is 60.0 %
# Accuracy for class: 03551_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Chloroceryle_americana is 50.0 %
# Accuracy for class: 03552_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Corythornis_cristatus is 80.0 %
# Accuracy for class: 03553_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Dacelo_novaeguineae is 50.0 %
# Accuracy for class: 03554_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Halcyon_albiventris is 70.0 %
# Accuracy for class: 03555_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Halcyon_senegalensis is 80.0 %
# Accuracy for class: 03556_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Halcyon_smyrnensis is 40.0 %
# Accuracy for class: 03557_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Megaceryle_alcyon is 40.0 %
# Accuracy for class: 03558_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Megaceryle_maxima is 60.0 %
# Accuracy for class: 03559_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Megaceryle_torquata is 30.0 %
# Accuracy for class: 03560_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Pelargopsis_capensis is 40.0 %
# Accuracy for class: 03561_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Todiramphus_chloris is 50.0 %
# Accuracy for class: 03562_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Todiramphus_macleayii is 100.0 %
# Accuracy for class: 03563_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Todiramphus_sanctus is 20.0 %
# Accuracy for class: 03564_Animalia_Chordata_Aves_Coraciiformes_Coraciidae_Coracias_benghalensis is 70.0 %
# Accuracy for class: 03565_Animalia_Chordata_Aves_Coraciiformes_Coraciidae_Coracias_caudatus is 70.0 %
# Accuracy for class: 03566_Animalia_Chordata_Aves_Coraciiformes_Coraciidae_Coracias_garrulus is 40.0 %
# Accuracy for class: 03567_Animalia_Chordata_Aves_Coraciiformes_Coraciidae_Eurystomus_orientalis is 70.0 %
# Accuracy for class: 03568_Animalia_Chordata_Aves_Coraciiformes_Meropidae_Merops_apiaster is 40.0 %
# Accuracy for class: 03569_Animalia_Chordata_Aves_Coraciiformes_Meropidae_Merops_bullockoides is 80.0 %
# ...
# Accuracy for class: 04444_Animalia_Chordata_Aves_Piciformes_Picidae_Dryobates_villosus is 20.0 %
# Accuracy for class: 04445_Animalia_Chordata_Aves_Piciformes_Picidae_Dryocopus_lineatus is 40.0 %
# Accuracy for class: 04446_Animalia_Chordata_Aves_Piciformes_Picidae_Dryocopus_martius is 40.0 %
# Accuracy for class: 04447_Animalia_Chordata_Aves_Piciformes_Picidae_Dryocopus_pileatus is 20.0 %
# Accuracy for class: 04448_Animalia_Chordata_Aves_Piciformes_Picidae_Jynx_torquilla is 30.0 %
# Accuracy for class: 04449_Animalia_Chordata_Aves_Piciformes_Picidae_Melanerpes_aurifrons is 0.0 %
# Accuracy for class: 04450_Animalia_Chordata_Aves_Piciformes_Picidae_Melanerpes_carolinus is 10.0 %
# Accuracy for class: 04451_Animalia_Chordata_Aves_Piciformes_Picidae_Melanerpes_chrysogenys is 60.0 %
# Accuracy for class: 04452_Animalia_Chordata_Aves_Piciformes_Picidae_Melanerpes_erythrocephalus is 50.0 %
# Accuracy for class: 04453_Animalia_Chordata_Aves_Piciformes_Picidae_Melanerpes_formicivorus is 20.0 %
# Accuracy for class: 04454_Animalia_Chordata_Aves_Piciformes_Picidae_Melanerpes_hoffmannii is 30.0 %
# Accuracy for class: 04455_Animalia_Chordata_Aves_Piciformes_Picidae_Melanerpes_lewis is 30.0 %
# Accuracy for class: 04456_Animalia_Chordata_Aves_Piciformes_Picidae_Melanerpes_pucherani is 70.0 %
# Accuracy for class: 04457_Animalia_Chordata_Aves_Piciformes_Picidae_Melanerpes_rubricapillus is 50.0 %
# Accuracy for class: 04458_Animalia_Chordata_Aves_Piciformes_Picidae_Melanerpes_uropygialis is 40.0 %
# Accuracy for class: 04459_Animalia_Chordata_Aves_Piciformes_Picidae_Picoides_arcticus is 30.0 %
# Accuracy for class: 04460_Animalia_Chordata_Aves_Piciformes_Picidae_Picoides_dorsalis is 60.0 %
# Accuracy for class: 04461_Animalia_Chordata_Aves_Piciformes_Picidae_Picus_canus is 50.0 %
# Accuracy for class: 04462_Animalia_Chordata_Aves_Piciformes_Picidae_Picus_viridis is 20.0 %
# Accuracy for class: 04463_Animalia_Chordata_Aves_Piciformes_Picidae_Sphyrapicus_nuchalis is 30.0 %
# Accuracy for class: 04464_Animalia_Chordata_Aves_Piciformes_Picidae_Sphyrapicus_ruber is 60.0 %
# Accuracy for class: 04465_Animalia_Chordata_Aves_Piciformes_Picidae_Sphyrapicus_thyroideus is 30.0 %
# Accuracy for class: 04466_Animalia_Chordata_Aves_Piciformes_Picidae_Sphyrapicus_varius is 10.0 %
# Accuracy for class: 04467_Animalia_Chordata_Aves_Piciformes_Ramphastidae_Aulacorhynchus_prasinus is 80.0 %
# Accuracy for class: 04468_Animalia_Chordata_Aves_Piciformes_Ramphastidae_Pteroglossus_castanotis is 80.0 %
# Accuracy for class: 04469_Animalia_Chordata_Aves_Piciformes_Ramphastidae_Pteroglossus_torquatus is 40.0 %
# Accuracy for class: 04470_Animalia_Chordata_Aves_Piciformes_Ramphastidae_Ramphastos_ambiguus is 40.0 %
# Accuracy for class: 04471_Animalia_Chordata_Aves_Piciformes_Ramphastidae_Ramphastos_sulfuratus is 60.0 %
# Accuracy for class: 04472_Animalia_Chordata_Aves_Piciformes_Ramphastidae_Ramphastos_toco is 70.0 %
# Accuracy for class: 04473_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Aechmophorus_clarkii is 40.0 %
# Accuracy for class: 04474_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Aechmophorus_occidentalis is 70.0 %
# Accuracy for class: 04475_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Podiceps_auritus is 30.0 %
# Accuracy for class: 04476_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Podiceps_cristatus is 60.0 %
# Accuracy for class: 04477_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Podiceps_grisegena is 20.0 %
# Accuracy for class: 04478_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Podiceps_major is 40.0 %
# Accuracy for class: 04479_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Podiceps_nigricollis is 20.0 %
# Accuracy for class: 04480_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Podilymbus_podiceps is 30.0 %
# Accuracy for class: 04481_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Poliocephalus_poliocephalus is 60.0 %
# Accuracy for class: 04482_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Rollandia_rolland is 90.0 %
# Accuracy for class: 04483_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Tachybaptus_dominicus is 60.0 %
# Accuracy for class: 04484_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Tachybaptus_novaehollandiae is 40.0 %
# Accuracy for class: 04485_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Tachybaptus_ruficollis is 20.0 %
# Accuracy for class: 04486_Animalia_Chordata_Aves_Procellariiformes_Diomedeidae_Phoebastria_immutabilis is 30.0 %
# Accuracy for class: 04487_Animalia_Chordata_Aves_Procellariiformes_Diomedeidae_Phoebastria_nigripes is 50.0 %
# Accuracy for class: 04488_Animalia_Chordata_Aves_Procellariiformes_Diomedeidae_Thalassarche_melanophris is 70.0 %
# Accuracy for class: 04489_Animalia_Chordata_Aves_Procellariiformes_Procellariidae_Ardenna_creatopus is 60.0 %
# Accuracy for class: 04490_Animalia_Chordata_Aves_Procellariiformes_Procellariidae_Ardenna_grisea is 30.0 %
# Accuracy for class: 04491_Animalia_Chordata_Aves_Procellariiformes_Procellariidae_Ardenna_pacifica is 30.0 %
# Accuracy for class: 04492_Animalia_Chordata_Aves_Procellariiformes_Procellariidae_Calonectris_diomedea is 40.0 %
# Accuracy for class: 04493_Animalia_Chordata_Aves_Procellariiformes_Procellariidae_Fulmarus_glacialis is 20.0 %
# Accuracy for class: 04494_Animalia_Chordata_Aves_Procellariiformes_Procellariidae_Macronectes_giganteus is 30.0 %
# Accuracy for class: 04495_Animalia_Chordata_Aves_Psittaciformes_Cacatuidae_Cacatua_galerita is 30.0 %
# Accuracy for class: 04496_Animalia_Chordata_Aves_Psittaciformes_Cacatuidae_Cacatua_sanguinea is 70.0 %
# Accuracy for class: 04497_Animalia_Chordata_Aves_Psittaciformes_Cacatuidae_Cacatua_tenuirostris is 70.0 %
# Accuracy for class: 04498_Animalia_Chordata_Aves_Psittaciformes_Cacatuidae_Callocephalon_fimbriatum is 60.0 %
# Accuracy for class: 04499_Animalia_Chordata_Aves_Psittaciformes_Cacatuidae_Calyptorhynchus_banksii is 20.0 %
# Accuracy for class: 04500_Animalia_Chordata_Aves_Psittaciformes_Cacatuidae_Calyptorhynchus_funereus is 40.0 %
# Accuracy for class: 04501_Animalia_Chordata_Aves_Psittaciformes_Cacatuidae_Eolophus_roseicapilla is 100.0 %
# Accuracy for class: 04502_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Amazona_albifrons is 10.0 %
# Accuracy for class: 04503_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Amazona_autumnalis is 30.0 %
# Accuracy for class: 04504_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Amazona_finschi is 30.0 %
# Accuracy for class: 04505_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Amazona_viridigenalis is 30.0 %
# Accuracy for class: 04506_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Ara_ararauna is 30.0 %
# Accuracy for class: 04507_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Ara_macao is 30.0 %
# Accuracy for class: 04508_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Aratinga_nenday is 40.0 %
# Accuracy for class: 04509_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Brotogeris_chiriri is 0.0 %
# Accuracy for class: 04510_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Brotogeris_jugularis is 60.0 %
# Accuracy for class: 04511_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Eupsittula_canicularis is 50.0 %
# Accuracy for class: 04512_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Eupsittula_nana is 30.0 %
# Accuracy for class: 04513_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Eupsittula_pertinax is 40.0 %
# Accuracy for class: 04514_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Forpus_conspicillatus is 50.0 %
# Accuracy for class: 04515_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Myiopsitta_monachus is 40.0 %
# Accuracy for class: 04516_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Pionus_menstruus is 60.0 %
# Accuracy for class: 04517_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Psittacara_erythrogenys is 10.0 %
# Accuracy for class: 04518_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Psittacara_holochlorus is 10.0 %
# Accuracy for class: 04519_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Psittacara_leucophthalmus is 40.0 %
# Accuracy for class: 04520_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Psittacara_mitratus is 20.0 %
# Accuracy for class: 04521_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Agapornis_roseicollis is 70.0 %
# Accuracy for class: 04522_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Alisterus_scapularis is 80.0 %
# Accuracy for class: 04523_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Barnardius_zonarius is 60.0 %
# Accuracy for class: 04524_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Cyanoramphus_novaezelandiae is 50.0 %
# Accuracy for class: 04525_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Glossopsitta_concinna is 50.0 %
# Accuracy for class: 04526_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Melopsittacus_undulatus is 30.0 %
# Accuracy for class: 04527_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Platycercus_adscitus is 80.0 %
# Accuracy for class: 04528_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Platycercus_elegans is 50.0 %
# Accuracy for class: 04529_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Platycercus_eximius is 60.0 %
# Accuracy for class: 04530_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Psephotus_haematonotus is 80.0 %
# Accuracy for class: 04531_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Psittacula_krameri is 40.0 %
# Accuracy for class: 04532_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Trichoglossus_chlorolepidotus is 50.0 %
# Accuracy for class: 04533_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Trichoglossus_moluccanus is 90.0 %
# Accuracy for class: 04534_Animalia_Chordata_Aves_Psittaciformes_Strigopidae_Nestor_meridionalis is 50.0 %
# Accuracy for class: 04535_Animalia_Chordata_Aves_Psittaciformes_Strigopidae_Nestor_notabilis is 50.0 %
# Accuracy for class: 04536_Animalia_Chordata_Aves_Sphenisciformes_Spheniscidae_Eudyptula_minor is 10.0 %
# Accuracy for class: 04537_Animalia_Chordata_Aves_Sphenisciformes_Spheniscidae_Pygoscelis_papua is 70.0 %
# Accuracy for class: 04538_Animalia_Chordata_Aves_Sphenisciformes_Spheniscidae_Spheniscus_demersus is 60.0 %
# Accuracy for class: 04539_Animalia_Chordata_Aves_Sphenisciformes_Spheniscidae_Spheniscus_magellanicus is 40.0 %
# Accuracy for class: 04540_Animalia_Chordata_Aves_Strigiformes_Strigidae_Aegolius_acadicus is 60.0 %
# Accuracy for class: 04541_Animalia_Chordata_Aves_Strigiformes_Strigidae_Asio_flammeus is 40.0 %
# Accuracy for class: 04542_Animalia_Chordata_Aves_Strigiformes_Strigidae_Asio_otus is 30.0 %
# Accuracy for class: 04543_Animalia_Chordata_Aves_Strigiformes_Strigidae_Athene_brama is 40.0 %
# Accuracy for class: 04544_Animalia_Chordata_Aves_Strigiformes_Strigidae_Athene_cunicularia is 40.0 %
# Accuracy for class: 04545_Animalia_Chordata_Aves_Strigiformes_Strigidae_Athene_noctua is 40.0 %
# Accuracy for class: 04546_Animalia_Chordata_Aves_Strigiformes_Strigidae_Bubo_africanus is 40.0 %
# Accuracy for class: 04547_Animalia_Chordata_Aves_Strigiformes_Strigidae_Bubo_bubo is 10.0 %
# Accuracy for class: 04548_Animalia_Chordata_Aves_Strigiformes_Strigidae_Bubo_scandiacus is 60.0 %
# Accuracy for class: 04549_Animalia_Chordata_Aves_Strigiformes_Strigidae_Bubo_virginianus is 0.0 %
# Accuracy for class: 04550_Animalia_Chordata_Aves_Strigiformes_Strigidae_Ciccaba_virgata is 60.0 %
# Accuracy for class: 04551_Animalia_Chordata_Aves_Strigiformes_Strigidae_Glaucidium_brasilianum is 70.0 %
# Accuracy for class: 04552_Animalia_Chordata_Aves_Strigiformes_Strigidae_Glaucidium_gnoma is 60.0 %
# Accuracy for class: 04553_Animalia_Chordata_Aves_Strigiformes_Strigidae_Megascops_asio is 30.0 %
# Accuracy for class: 04554_Animalia_Chordata_Aves_Strigiformes_Strigidae_Megascops_choliba is 40.0 %
# Accuracy for class: 04555_Animalia_Chordata_Aves_Strigiformes_Strigidae_Megascops_kennicottii is 10.0 %
# Accuracy for class: 04556_Animalia_Chordata_Aves_Strigiformes_Strigidae_Ninox_novaeseelandiae is 60.0 %
# Accuracy for class: 04557_Animalia_Chordata_Aves_Strigiformes_Strigidae_Strix_aluco is 10.0 %
# Accuracy for class: 04558_Animalia_Chordata_Aves_Strigiformes_Strigidae_Strix_nebulosa is 30.0 %
# Accuracy for class: 04559_Animalia_Chordata_Aves_Strigiformes_Strigidae_Strix_uralensis is 40.0 %
# Accuracy for class: 04560_Animalia_Chordata_Aves_Strigiformes_Strigidae_Strix_varia is 30.0 %
# Accuracy for class: 04561_Animalia_Chordata_Aves_Strigiformes_Strigidae_Surnia_ulula is 70.0 %
# Accuracy for class: 04562_Animalia_Chordata_Aves_Strigiformes_Tytonidae_Tyto_alba is 20.0 %
# Accuracy for class: 04563_Animalia_Chordata_Aves_Struthioniformes_Struthionidae_Struthio_camelus is 70.0 %
# Accuracy for class: 04564_Animalia_Chordata_Aves_Suliformes_Anhingidae_Anhinga_anhinga is 20.0 %
# Accuracy for class: 04565_Animalia_Chordata_Aves_Suliformes_Anhingidae_Anhinga_melanogaster is 20.0 %
# Accuracy for class: 04566_Animalia_Chordata_Aves_Suliformes_Anhingidae_Anhinga_novaehollandiae is 20.0 %
# Accuracy for class: 04567_Animalia_Chordata_Aves_Suliformes_Anhingidae_Anhinga_rufa is 40.0 %
# Accuracy for class: 04568_Animalia_Chordata_Aves_Suliformes_Fregatidae_Fregata_magnificens is 80.0 %
# Accuracy for class: 04569_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Microcarbo_africanus is 50.0 %
# Accuracy for class: 04570_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Microcarbo_melanoleucos is 70.0 %
# Accuracy for class: 04571_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Microcarbo_niger is 30.0 %
# Accuracy for class: 04572_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Microcarbo_pygmaeus is 0.0 %
# Accuracy for class: 04573_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Phalacrocorax_aristotelis is 20.0 %
# Accuracy for class: 04574_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Phalacrocorax_auritus is 10.0 %
# Accuracy for class: 04575_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Phalacrocorax_brasilianus is 30.0 %
# Accuracy for class: 04576_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Phalacrocorax_capensis is 0.0 %
# Accuracy for class: 04577_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Phalacrocorax_carbo is 0.0 %
# Accuracy for class: 04578_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Phalacrocorax_pelagicus is 10.0 %
# Accuracy for class: 04579_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Phalacrocorax_penicillatus is 50.0 %
# Accuracy for class: 04580_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Phalacrocorax_punctatus is 30.0 %
# Accuracy for class: 04581_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Phalacrocorax_sulcirostris is 30.0 %
# Accuracy for class: 04582_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Phalacrocorax_varius is 50.0 %
# Accuracy for class: 04583_Animalia_Chordata_Aves_Suliformes_Sulidae_Morus_bassanus is 10.0 %
# Accuracy for class: 04584_Animalia_Chordata_Aves_Suliformes_Sulidae_Morus_serrator is 60.0 %
# Accuracy for class: 04585_Animalia_Chordata_Aves_Suliformes_Sulidae_Sula_dactylatra is 20.0 %
# Accuracy for class: 04586_Animalia_Chordata_Aves_Suliformes_Sulidae_Sula_leucogaster is 20.0 %
# Accuracy for class: 04587_Animalia_Chordata_Aves_Suliformes_Sulidae_Sula_nebouxii is 60.0 %
# Accuracy for class: 04588_Animalia_Chordata_Aves_Suliformes_Sulidae_Sula_sula is 40.0 %
# Accuracy for class: 04589_Animalia_Chordata_Aves_Trogoniformes_Trogonidae_Pharomachrus_mocinno is 40.0 %
# Accuracy for class: 04590_Animalia_Chordata_Aves_Trogoniformes_Trogonidae_Trogon_caligatus is 40.0 %
# Accuracy for class: 04591_Animalia_Chordata_Aves_Trogoniformes_Trogonidae_Trogon_citreolus is 50.0 %
# Accuracy for class: 04592_Animalia_Chordata_Aves_Trogoniformes_Trogonidae_Trogon_collaris is 50.0 %
# Accuracy for class: 04593_Animalia_Chordata_Aves_Trogoniformes_Trogonidae_Trogon_elegans is 20.0 %
# Accuracy for class: 04594_Animalia_Chordata_Aves_Trogoniformes_Trogonidae_Trogon_massena is 90.0 %
# Accuracy for class: 04595_Animalia_Chordata_Aves_Trogoniformes_Trogonidae_Trogon_melanocephalus is 60.0 %
# Accuracy for class: 04596_Animalia_Chordata_Aves_Trogoniformes_Trogonidae_Trogon_rufus is 60.0 %
