# %%
import random
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import torch
import torch.optim as optim
import torch.nn as nn
from torch.utils.data import Subset
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.utils import make_grid 
from torch.utils.tensorboard import SummaryWriter
from torchvision.models import efficientnet_b0, EfficientNet_B0_Weights
from sklearn.model_selection import train_test_split

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
writer = SummaryWriter()

# %%
# Define transformations
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(30),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),    
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

val_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(), 
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])



# Load datasets from disk with transforms applied
train_data = datasets.INaturalist(root='data/train_mini', version="2021_train_mini", transform=train_transform, download=False)
validation_data = datasets.INaturalist(root='data/validation', version="2021_valid", transform=val_transform, download=False)

# Create DataLoaders
train_loader = DataLoader(train_data, batch_size=128, shuffle=True, num_workers=4)
val_loader = DataLoader(validation_data, batch_size=128, shuffle=True, num_workers=4)

print(f"Training samples: {len(train_data)}")
print(f"Validation samples: {len(validation_data)}")

# %%
cat_list = [int(cat[1:5]) for cat in train_data.all_categories if "Animalia_Chordata_Aves" in cat]
# get corresponding labels

# %%
bird_indices = []
with open('bird_indices.txt', 'r') as f:
    for line in f:
        bird_indices.append(int(line[0:-1]))

bird_test_indices = []
with open('bird_val_indices.txt', 'r') as f:
    for line in f:
        bird_test_indices.append(int(line[0:-1]))

# %%
# Find all indices where the target (label) corresponds to birds
# Create a subset dataset containing only birds
train_data_birds = Subset(train_data, bird_indices)

label_index_map = {}
index_list = [] 
label_list = []

# for i, (_, label) in enumerate(train_data_birds):
#     index_list.append(i)
#     label_list.append(label)
# # now, for each label, randomly select 20% of indices, these will become the val set. 
# index_list_train, index_list_val, labels_train, labels_val = train_test_split(
# index_list, label_list, test_size=0.2, random_state=42, stratify=label_list)

# %%
def read_list_from_file(file_name):
    output_list = []
    with open(file_name, 'r') as f:
        for line in f:
            output_list.append(int(line[0:-1]))
    return output_list

index_list_train = read_list_from_file("index_list_train.csv") 
index_list_val = read_list_from_file("index_list_val.csv") 
labels_train = read_list_from_file("labels_train.csv") 
labels_val = read_list_from_file("labels_val.csv")

# %%
val_data_birds = Subset(train_data_birds, index_list_val)
train_data_birds = Subset(train_data_birds, index_list_train)

# %%
# Create a DataLoader for the filtered dataset
train_loader_birds = DataLoader(train_data_birds, batch_size=32, shuffle=True, num_workers=4)
val_loader_birds = DataLoader(val_data_birds, batch_size=32, shuffle=True, num_workers=4)

# use validation set from problem as the unseen test set
test_data_birds = Subset(validation_data, bird_test_indices)
test_loader_birds = DataLoader(test_data_birds, batch_size=32, shuffle=True, num_workers=4)

print(f"Filtered train dataset contains {len(train_data_birds)} bird images.")
print(f"Filtered val dataset contains {len(val_data_birds)} bird images.")
print(f"Filtered test dataset contains {len(test_data_birds)} bird images.")
# Out:
# Filtered train dataset contains 59440 bird images.
# Filtered val dataset contains 14860 bird images.
# Filtered test dataset contains 14860 bird images.

# %%
# functions to show an image
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# get some random training images
dataiter = iter(train_loader_birds)
images, labels = next(dataiter)

# show images
imshow(make_grid(images))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.558952..1.82].

# %%
n_classes = len(cat_list)

# %%
def remap_labels(labels):
    return (labels - 3111).long()  


def log_metrics_tensor_board(data_type, accuracy, top_5_accuracy, loss, epoch ):
    writer.add_scalar(f"Loss -  {data_type}", loss, epoch)
    writer.add_scalar(f"Accuracy -  {data_type}", 100 * accuracy, epoch)
    writer.add_scalar(f"Top 5 Accuracy - {data_type}", 100 * top_5_accuracy, epoch)
    return


def save_model(model, criterion, optimizer,  epoch, model_name):
    torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'loss': criterion,
                }, f"runs/model_{model_name}.pth")
    return


def run_epoch(model, loader, criterion, optimizer=None, epoch=0, mode="train"):
    is_train = mode == "train"
    model.train() if is_train else model.eval()

    running_loss = 0.0
    correct = 0
    top_5_correct = 0
    total = 0

    with torch.set_grad_enabled(is_train):  # Only compute gradients during training
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            labels = remap_labels(labels).to(device)

            outputs = model(images)  # Forward pass
            loss = criterion(outputs, labels)  # Compute loss

            if is_train:
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

            running_loss += loss.item()
            _, predicted = outputs.max(1)
            # count total correct predicitions in batch
            correct += (predicted == labels).sum().item()
            total += labels.size(0)
            # count total matches of label in top 5 class predictions 
            _, top_5_predicted = outputs.topk(5, dim=1)
            top_5_correct += torch.isin(labels, top_5_predicted).sum().item()

    avg_loss = running_loss / len(loader)
    accuracy = correct / total
    top_5_accuracy = top_5_correct / total
    log_metrics_tensor_board(mode, accuracy, top_5_accuracy, avg_loss, epoch)

    print(f"{mode.capitalize()} Accuracy: {100 * accuracy:.2f}%")
    print(f"Top 5 {mode.capitalize()} Accuracy: {100 * top_5_accuracy:.2f}%")
    print(f"Epoch {epoch+1} - {mode.capitalize()} Loss: {avg_loss:.4f}")
    return avg_loss, accuracy


def train_model(model, model_name, train_loader, val_loader, criterion, optimizer, epochs=5, early_stop_limit=5):
    best_val_loss = float('inf')
    early_stop_count = 0
    # lists to track of loss and accuracy metrics
    train_loss_list, val_loss_list = [], []
    train_acc_list, val_acc_list = [], []

    for epoch in range(epochs):
        train_loss, train_acc = run_epoch(model, train_loader, criterion, optimizer, epoch, mode="train")
        # if no val loader, evaluate stopping based on train metrics (e.g. when training on validation after training on train before evaluating on test)
        if val_loader is None:
            val_loss, val_acc = train_loss, train_acc
        else:
            val_loss, val_acc = run_epoch(model, val_loader, criterion, None, epoch, mode="validation")
        # store metrics
        train_loss_list.append(train_loss)
        val_loss_list.append(val_loss)
        train_acc_list.append(train_acc)
        val_acc_list.append(val_acc)
        # early stopping
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            early_stop_count = 0
            # save best model so far
            save_model(model, criterion, optimizer,  epoch, model_name)
        else:
            early_stop_count += 1
        if early_stop_count == early_stop_limit:
            break
    eval_metrics = {
            "train_loss": train_loss_list,
            "val_loss": val_loss_list,
            "train_acc": train_acc_list,
            "val_acc": val_acc_list
        }
    return eval_metrics

# %%
# efficient net model 
weights = EfficientNet_B0_Weights.DEFAULT
pretrained_model = efficientnet_b0(weights=weights)

for param in pretrained_model.parameters():
    param.requires_grad = True  # Enable/Disable fine tune training on all layers

pretrained_model.classifier = nn.Sequential(
            nn.Linear(pretrained_model.classifier[1].in_features, 2048), 
            nn.BatchNorm1d(2048),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(2048, n_classes)  # Final output layer
)

pretrained_model.to(device)

criterion =  nn.CrossEntropyLoss().to(device)
optimizer = optim.Adam(pretrained_model.parameters(), lr=0.0001, weight_decay=1e-3)


# Train the model
eval_metrics = train_model(pretrained_model, "efficientnet_b0", train_loader_birds, val_loader_birds, criterion, optimizer, epochs=100, early_stop_limit=3)
# Out:
# Train Accuracy: 2.63%
# Top 5 Train Accuracy: 24.38%
# Epoch 1 - Train Loss: 6.5086
# Validation Accuracy: 4.68%
# Top 5 Validation Accuracy: 29.58%
# Epoch 1 - Validation Loss: 5.8214
# Train Accuracy: 6.41%
# Top 5 Train Accuracy: 33.78%
# Epoch 2 - Train Loss: 5.6009
# Validation Accuracy: 6.22%
# Top 5 Validation Accuracy: 33.65%
# Epoch 2 - Validation Loss: 5.5997
# Train Accuracy: 7.87%
# Top 5 Train Accuracy: 36.08%
# Epoch 3 - Train Loss: 5.4225
# Validation Accuracy: 6.86%
# Top 5 Validation Accuracy: 35.45%
# Epoch 3 - Validation Loss: 5.5298
# Train Accuracy: 8.29%
# Top 5 Train Accuracy: 37.45%
# Epoch 4 - Train Loss: 5.3452
# Validation Accuracy: 7.65%
# Top 5 Validation Accuracy: 37.27%
# Epoch 4 - Validation Loss: 5.4668
# Train Accuracy: 8.78%
# Top 5 Train Accuracy: 37.99%
# Epoch 5 - Train Loss: 5.3153
# Validation Accuracy: 7.20%
# Top 5 Validation Accuracy: 36.95%
# Epoch 5 - Validation Loss: 5.4579
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 23
#      19 optimizer = optim.Adam(pretrained_model.parameters(), lr=0.001, weight_decay=1e-3)
#      22 # Train the model
# ---> 23 eval_metrics = train_model(pretrained_model, "efficientnet_b0_freeze_weights", train_loader_birds, val_loader_birds, criterion, optimizer, epochs=100, early_stop_limit=3)
#
# Cell In[13], line 72, in train_model(model, model_name, train_loader, val_loader, criterion, optimizer, epochs, early_stop_limit)
#      69 train_acc_list, val_acc_list = [], []
#      71 for epoch in range(epochs):
# ---> 72     train_loss, train_acc = run_epoch(model, train_loader, criterion, optimizer, epoch, mode="train")
#      73     # if no val loader, evaluate stopping based on train metrics (e.g. when training on validation after training on train before evaluating on test)
#      74     if val_loader is None:
#
# Cell In[13], line 32, in run_epoch(model, loader, criterion, optimizer, epoch, mode)
#      29 total = 0
#      31 with torch.set_grad_enabled(is_train):  # Only compute gradients during training
# ---> 32     for images, labels in loader:
#      33         images, labels = images.to(device), labels.to(device)
#      34         labels = remap_labels(labels).to(device)
#
# File c:\Users\Sean\.conda\envs\inat\Lib\site-packages\torch\utils\data\dataloader.py:491, in DataLoader.__iter__(self)
#     489     return self._iterator
#     490 else:
# --> 491     return self._get_iterator()
#
# File c:\Users\Sean\.conda\envs\inat\Lib\site-packages\torch\utils\data\dataloader.py:422, in DataLoader._get_iterator(self)
#     420 else:
#     421     self.check_worker_number_rationality()
# --> 422     return _MultiProcessingDataLoaderIter(self)
#
# File c:\Users\Sean\.conda\envs\inat\Lib\site-packages\torch\utils\data\dataloader.py:1146, in _MultiProcessingDataLoaderIter.__init__(self, loader)
#    1139 w.daemon = True
#    1140 # NB: Process.start() actually take some time as it needs to
#    1141 #     start a process and pass the arguments over via a pipe.
#    1142 #     Therefore, we only add a worker to self._workers list after
#    1143 #     it started, so that we do not call .join() if program dies
#    1144 #     before it starts, and __del__ tries to join but will get:
#    1145 #     AssertionError: can only join a started process.
# -> 1146 w.start()
#    1147 self._index_queues.append(index_queue)
#    1148 self._workers.append(w)
#
# File c:\Users\Sean\.conda\envs\inat\Lib\multiprocessing\process.py:121, in BaseProcess.start(self)
#     118 assert not _current_process._config.get('daemon'), \
#     119        'daemonic processes are not allowed to have children'
#     120 _cleanup()
# --> 121 self._popen = self._Popen(self)
#     122 self._sentinel = self._popen.sentinel
#     123 # Avoid a refcycle if the target function holds an indirect
#     124 # reference to the process object (see bpo-30775)
#
# File c:\Users\Sean\.conda\envs\inat\Lib\multiprocessing\context.py:224, in Process._Popen(process_obj)
#     222 @staticmethod
#     223 def _Popen(process_obj):
# --> 224     return _default_context.get_context().Process._Popen(process_obj)
#
# File c:\Users\Sean\.conda\envs\inat\Lib\multiprocessing\context.py:337, in SpawnProcess._Popen(process_obj)
#     334 @staticmethod
#     335 def _Popen(process_obj):
#     336     from .popen_spawn_win32 import Popen
# --> 337     return Popen(process_obj)
#
# File c:\Users\Sean\.conda\envs\inat\Lib\multiprocessing\popen_spawn_win32.py:94, in Popen.__init__(self, process_obj)
#      92 try:
#      93     reduction.dump(prep_data, to_child)
# ---> 94     reduction.dump(process_obj, to_child)
#      95 finally:
#      96     set_spawning_popen(None)
#
# File c:\Users\Sean\.conda\envs\inat\Lib\multiprocessing\reduction.py:60, in dump(obj, file, protocol)
#      58 def dump(obj, file, protocol=None):
#      59     '''Replacement for pickle.dump() using ForkingPickler.'''
# ---> 60     ForkingPickler(file, protocol).dump(obj)
#
# KeyboardInterrupt:

# %%
def create_eval_plots(eval_metrics, model_name):
    # Convert eval_metrics to a DataFrame and add an 'epoch' column
    plot_df = pd.DataFrame.from_dict(eval_metrics)
    plot_df["epoch"] = plot_df.index + 1

    # Loss Plot 
    fig, ax = plt.subplots(figsize=(10, 8))
    
    ax.plot(plot_df["epoch"], plot_df["train_loss"], label="Training Loss",
            color="darkblue", linewidth=2)
    ax.plot(plot_df["epoch"], plot_df["val_loss"], label="Validation Loss",
            color="darkgreen", linewidth=2)
    
    # styling
    ax.set_xlabel("Epoch", fontsize=14)
    ax.set_ylabel("Loss", fontsize=14)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.grid(axis="y", alpha=0.7)
    ax.grid(axis="x", visible=False)
    ax.legend(fontsize=12)
    # save plot
    fig.savefig(f"outputs/loss_{model_name}.png", bbox_inches="tight")
    
    # Accuracy Plot
    fig, ax = plt.subplots(figsize=(10, 8))
    
    # Scale accuracy values to percentages
    plot_df["train_acc"] *= 100
    plot_df["val_acc"] *= 100
    
    # Plot training and validation accuracies
    ax.plot(plot_df["epoch"], plot_df["train_acc"], label="Training Accuracy",
            color="darkblue", linewidth=2)
    ax.plot(plot_df["epoch"], plot_df["val_acc"], label="Validation Accuracy",
            color="darkgreen", linewidth=2)
    
    # styling
    ax.set_xlabel("Epoch", fontsize=14)
    ax.set_ylabel("Accuracy (%)", fontsize=14)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.grid(axis="y", alpha=0.7)
    ax.grid(axis="x", visible=False)
    ax.legend(fontsize=12)
    # save plot
    fig.savefig(f"outputs/accuracy_{model_name}.png", bbox_inches="tight")
    plt.close("all")
    return

create_eval_plots(eval_metrics, "efficientnet_b0_freeze_weights")

# %%
# Load the checkpoint
checkpoint = torch.load(f"runs/model_efficientnet_b0.pth")

# turn to function def rebuild model
# Load the pretrained EfficientNet model
trained_model = efficientnet_b0(pretrained=False) 

trained_model.classifier = nn.Sequential(
            nn.Linear(trained_model.classifier[1].in_features, 2048), 
            nn.BatchNorm1d(2048),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(2048, n_classes)  # Final output layer
)

for param in trained_model.parameters():
    param.requires_grad = True  # Enable fine tune training on all layers

trained_model.to(device)

# Define optimizer
optimizer = torch.optim.Adam(trained_model.parameters(), lr=0.0001, weight_decay=1e-3) # Use the same optimizer as before
# Load model and optimizer states
trained_model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

train_model(trained_model, "efficientnet_b0_final", val_loader_birds, None, criterion, optimizer, epochs=5, early_stop_limit=2)
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[33], line 2
#       1 # Load the checkpoint
# ----> 2 checkpoint = torch.load(f"runs/model_efficientnet_b0_freeze_weights.pth")
#       4 # turn to function def rebuild model
#       5 # Load the pretrained EfficientNet model
#       6 trained_model = efficientnet_b0(pretrained=False)
#
# File c:\Users\Sean\.conda\envs\inat\Lib\site-packages\torch\serialization.py:1470, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1462                 return _load(
#    1463                     opened_zipfile,
#    1464                     map_location,
#    (...)   1467                     **pickle_load_args,
#    1468                 )
#    1469             except pickle.UnpicklingError as e:
# -> 1470                 raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
#    1471         return _load(
#    1472             opened_zipfile,
#    1473             map_location,
#    (...)   1476             **pickle_load_args,
#    1477         )
#    1478 if mmap:
#
# UnpicklingError: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL timm.loss.cross_entropy.LabelSmoothingCrossEntropy was not an allowed global by default. Please use `torch.serialization.add_safe_globals([LabelSmoothingCrossEntropy])` or the `torch.serialization.safe_globals([LabelSmoothingCrossEntropy])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.

# %%
# evaluate on test
val_loss, val_acc = run_epoch(trained_model, test_loader_birds, criterion, None, epoch=0, mode="validation")
# Out:
# Validation Accuracy: 41.61%
# Top 5 Validation Accuracy: 70.26%
# Epoch 1 - Validation Loss: 2.7022

# %%
save_model(trained_model, criterion, optimizer, epoch=18, model_name="efficientnet_b0_full_train")

# %%
bird_classes = [cat for cat in train_data.all_categories if "Animalia_Chordata_Aves" in cat]

# %%
# prepare to count predictions for each class
correct_pred = {classname: 0 for classname in bird_classes}
total_pred = {classname: 0 for classname in bird_classes}

# again no gradients needed
with torch.no_grad():
    for data in test_loader_birds:
        images, labels = data
        images, labels = images.to(device), labels.to(device)
        labels = remap_labels(labels).to(device)
        outputs = trained_model(images)
        _, predictions = torch.max(outputs, 1)
        # collect the correct predictions for each class
        for label, prediction in zip(labels, predictions):
            if label == prediction:
                correct_pred[bird_classes[label]] += 1
            total_pred[bird_classes[label]] += 1
# turn into dataframe and sort by smallest success classes
# then create confusion matrix for all classes - find the biggest misses


# print accuracy for each class
for classname, correct_count in correct_pred.items():
    accuracy = 100 * float(correct_count) / total_pred[classname]
    print(f'Accuracy for class: {classname:5s} is {accuracy:.1f} %')
# Out:
# Accuracy for class: 03111_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_badius is 40.0 %
# Accuracy for class: 03112_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_cooperii is 10.0 %
# Accuracy for class: 03113_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_gentilis is 0.0 %
# Accuracy for class: 03114_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_nisus is 10.0 %
# Accuracy for class: 03115_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_striatus is 10.0 %
# Accuracy for class: 03116_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_trivirgatus is 30.0 %
# Accuracy for class: 03117_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aegypius_monachus is 20.0 %
# Accuracy for class: 03118_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_audax is 30.0 %
# Accuracy for class: 03119_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_chrysaetos is 30.0 %
# Accuracy for class: 03120_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_heliaca is 0.0 %
# Accuracy for class: 03121_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_nipalensis is 50.0 %
# Accuracy for class: 03122_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_rapax is 40.0 %
# Accuracy for class: 03123_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Busarellus_nigricollis is 70.0 %
# Accuracy for class: 03124_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_albonotatus is 50.0 %
# Accuracy for class: 03125_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_brachyurus is 20.0 %
# Accuracy for class: 03126_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_buteo is 0.0 %
# Accuracy for class: 03127_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_jamaicensis is 0.0 %
# Accuracy for class: 03128_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_lagopus is 10.0 %
# Accuracy for class: 03129_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_lineatus is 10.0 %
# Accuracy for class: 03130_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_plagiatus is 40.0 %
# Accuracy for class: 03131_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_platypterus is 10.0 %
# Accuracy for class: 03132_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_regalis is 30.0 %
# Accuracy for class: 03133_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_rufinus is 20.0 %
# Accuracy for class: 03134_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_rufofuscus is 20.0 %
# Accuracy for class: 03135_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_swainsoni is 0.0 %
# Accuracy for class: 03136_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteogallus_anthracinus is 0.0 %
# Accuracy for class: 03137_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteogallus_meridionalis is 60.0 %
# Accuracy for class: 03138_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteogallus_urubitinga is 30.0 %
# Accuracy for class: 03139_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Chondrohierax_uncinatus is 30.0 %
# Accuracy for class: 03140_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circaetus_cinereus is 60.0 %
# Accuracy for class: 03141_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circaetus_gallicus is 20.0 %
# Accuracy for class: 03142_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circus_aeruginosus is 0.0 %
# Accuracy for class: 03143_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circus_approximans is 0.0 %
# Accuracy for class: 03144_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circus_cyaneus is 30.0 %
# Accuracy for class: 03145_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circus_hudsonius is 20.0 %
# Accuracy for class: 03146_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circus_macrourus is 40.0 %
# Accuracy for class: 03147_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circus_pygargus is 30.0 %
# Accuracy for class: 03148_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Clanga_clanga is 10.0 %
# Accuracy for class: 03149_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Elanoides_forficatus is 60.0 %
# Accuracy for class: 03150_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Elanus_axillaris is 10.0 %
# Accuracy for class: 03151_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Elanus_caeruleus is 60.0 %
# Accuracy for class: 03152_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Elanus_leucurus is 0.0 %
# Accuracy for class: 03153_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Geranoaetus_albicaudatus is 0.0 %
# Accuracy for class: 03154_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Geranoaetus_melanoleucus is 20.0 %
# Accuracy for class: 03155_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Geranoaetus_polyosoma is 10.0 %
# Accuracy for class: 03156_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Geranospiza_caerulescens is 40.0 %
# Accuracy for class: 03157_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Gypaetus_barbatus is 40.0 %
# Accuracy for class: 03158_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Gyps_africanus is 40.0 %
# Accuracy for class: 03159_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Gyps_fulvus is 50.0 %
# Accuracy for class: 03160_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Haliaeetus_albicilla is 0.0 %
# Accuracy for class: 03161_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Haliaeetus_leucocephalus is 20.0 %
# Accuracy for class: 03162_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Haliaeetus_leucogaster is 10.0 %
# Accuracy for class: 03163_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Haliaeetus_vocifer is 50.0 %
# Accuracy for class: 03164_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Haliastur_indus is 70.0 %
# Accuracy for class: 03165_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Haliastur_sphenurus is 20.0 %
# Accuracy for class: 03166_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Hieraaetus_pennatus is 60.0 %
# Accuracy for class: 03167_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Ictinia_mississippiensis is 10.0 %
# Accuracy for class: 03168_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Ictinia_plumbea is 50.0 %
# Accuracy for class: 03169_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Lophaetus_occipitalis is 60.0 %
# Accuracy for class: 03170_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Melierax_canorus is 60.0 %
# Accuracy for class: 03171_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Milvus_migrans is 0.0 %
# Accuracy for class: 03172_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Milvus_milvus is 10.0 %
# Accuracy for class: 03173_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Necrosyrtes_monachus is 40.0 %
# Accuracy for class: 03174_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Neophron_percnopterus is 40.0 %
# Accuracy for class: 03175_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Nisaetus_cirrhatus is 60.0 %
# Accuracy for class: 03176_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Parabuteo_unicinctus is 20.0 %
# Accuracy for class: 03177_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Pernis_apivorus is 10.0 %
# Accuracy for class: 03178_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Pernis_ptilorhynchus is 40.0 %
# Accuracy for class: 03179_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Polemaetus_bellicosus is 40.0 %
# Accuracy for class: 03180_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Polyboroides_typus is 20.0 %
# Accuracy for class: 03181_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Rostrhamus_sociabilis is 0.0 %
# Accuracy for class: 03182_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Rupornis_magnirostris is 40.0 %
# Accuracy for class: 03183_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Spilornis_cheela is 50.0 %
# Accuracy for class: 03184_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Terathopius_ecaudatus is 40.0 %
# Accuracy for class: 03185_Animalia_Chordata_Aves_Accipitriformes_Pandionidae_Pandion_haliaetus is 10.0 %
# Accuracy for class: 03186_Animalia_Chordata_Aves_Accipitriformes_Sagittariidae_Sagittarius_serpentarius is 60.0 %
# Accuracy for class: 03187_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aix_galericulata is 40.0 %
# Accuracy for class: 03188_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aix_sponsa is 30.0 %
# Accuracy for class: 03189_Animalia_Chordata_Aves_Anseriformes_Anatidae_Alopochen_aegyptiaca is 40.0 %
# Accuracy for class: 03190_Animalia_Chordata_Aves_Anseriformes_Anatidae_Amazonetta_brasiliensis is 40.0 %
# Accuracy for class: 03191_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_acuta is 60.0 %
# Accuracy for class: 03192_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_bahamensis is 60.0 %
# Accuracy for class: 03193_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_castanea is 50.0 %
# Accuracy for class: 03194_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_crecca is 40.0 %
# Accuracy for class: 03195_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_diazi is 10.0 %
# Accuracy for class: 03196_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_erythrorhyncha is 80.0 %
# Accuracy for class: 03197_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_flavirostris is 70.0 %
# Accuracy for class: 03198_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_fulvigula is 50.0 %
# Accuracy for class: 03199_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_georgica is 50.0 %
# Accuracy for class: 03200_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_gracilis is 50.0 %
# Accuracy for class: 03201_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_platyrhynchos is 30.0 %
# Accuracy for class: 03202_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_poecilorhyncha is 50.0 %
# Accuracy for class: 03203_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_rubripes is 30.0 %
# Accuracy for class: 03204_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_superciliosa is 40.0 %
# Accuracy for class: 03205_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_undulata is 60.0 %
# Accuracy for class: 03206_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_zonorhyncha is 40.0 %
# Accuracy for class: 03207_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_albifrons is 40.0 %
# Accuracy for class: 03208_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_anser is 20.0 %
# Accuracy for class: 03209_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_brachyrhynchus is 30.0 %
# Accuracy for class: 03210_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_caerulescens is 20.0 %
# Accuracy for class: 03211_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_cygnoides is 30.0 %
# Accuracy for class: 03212_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_fabalis is 50.0 %
# Accuracy for class: 03213_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_indicus is 80.0 %
# Accuracy for class: 03214_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_rossii is 50.0 %
# Accuracy for class: 03215_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_affinis is 10.0 %
# Accuracy for class: 03216_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_americana is 50.0 %
# Accuracy for class: 03217_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_australis is 60.0 %
# Accuracy for class: 03218_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_collaris is 0.0 %
# Accuracy for class: 03219_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_ferina is 10.0 %
# Accuracy for class: 03220_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_fuligula is 20.0 %
# Accuracy for class: 03221_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_marila is 30.0 %
# Accuracy for class: 03222_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_novaeseelandiae is 50.0 %
# Accuracy for class: 03223_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_nyroca is 40.0 %
# Accuracy for class: 03224_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_valisineria is 70.0 %
# Accuracy for class: 03225_Animalia_Chordata_Aves_Anseriformes_Anatidae_Branta_bernicla is 40.0 %
# Accuracy for class: 03226_Animalia_Chordata_Aves_Anseriformes_Anatidae_Branta_canadensis is 10.0 %
# Accuracy for class: 03227_Animalia_Chordata_Aves_Anseriformes_Anatidae_Branta_hutchinsii is 80.0 %
# Accuracy for class: 03228_Animalia_Chordata_Aves_Anseriformes_Anatidae_Branta_leucopsis is 80.0 %
# Accuracy for class: 03229_Animalia_Chordata_Aves_Anseriformes_Anatidae_Branta_sandvicensis is 50.0 %
# Accuracy for class: 03230_Animalia_Chordata_Aves_Anseriformes_Anatidae_Bucephala_albeola is 70.0 %
# Accuracy for class: 03231_Animalia_Chordata_Aves_Anseriformes_Anatidae_Bucephala_clangula is 0.0 %
# Accuracy for class: 03232_Animalia_Chordata_Aves_Anseriformes_Anatidae_Bucephala_islandica is 100.0 %
# Accuracy for class: 03233_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cairina_moschata is 60.0 %
# Accuracy for class: 03234_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cereopsis_novaehollandiae is 60.0 %
# Accuracy for class: 03235_Animalia_Chordata_Aves_Anseriformes_Anatidae_Chenonetta_jubata is 90.0 %
# Accuracy for class: 03236_Animalia_Chordata_Aves_Anseriformes_Anatidae_Chloephaga_picta is 50.0 %
# Accuracy for class: 03237_Animalia_Chordata_Aves_Anseriformes_Anatidae_Clangula_hyemalis is 60.0 %
# Accuracy for class: 03238_Animalia_Chordata_Aves_Anseriformes_Anatidae_Coscoroba_coscoroba is 40.0 %
# Accuracy for class: 03239_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cygnus_atratus is 80.0 %
# Accuracy for class: 03240_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cygnus_buccinator is 50.0 %
# Accuracy for class: 03241_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cygnus_columbianus is 20.0 %
# Accuracy for class: 03242_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cygnus_cygnus is 40.0 %
# Accuracy for class: 03243_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cygnus_melancoryphus is 60.0 %
# Accuracy for class: 03244_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cygnus_olor is 70.0 %
# Accuracy for class: 03245_Animalia_Chordata_Aves_Anseriformes_Anatidae_Dendrocygna_autumnalis is 50.0 %
# Accuracy for class: 03246_Animalia_Chordata_Aves_Anseriformes_Anatidae_Dendrocygna_bicolor is 40.0 %
# Accuracy for class: 03247_Animalia_Chordata_Aves_Anseriformes_Anatidae_Dendrocygna_javanica is 50.0 %
# Accuracy for class: 03248_Animalia_Chordata_Aves_Anseriformes_Anatidae_Dendrocygna_viduata is 70.0 %
# Accuracy for class: 03249_Animalia_Chordata_Aves_Anseriformes_Anatidae_Histrionicus_histrionicus is 20.0 %
# Accuracy for class: 03250_Animalia_Chordata_Aves_Anseriformes_Anatidae_Lophodytes_cucullatus is 20.0 %
# Accuracy for class: 03251_Animalia_Chordata_Aves_Anseriformes_Anatidae_Lophonetta_specularioides is 40.0 %
# Accuracy for class: 03252_Animalia_Chordata_Aves_Anseriformes_Anatidae_Malacorhynchus_membranaceus is 80.0 %
# Accuracy for class: 03253_Animalia_Chordata_Aves_Anseriformes_Anatidae_Mareca_americana is 30.0 %
# Accuracy for class: 03254_Animalia_Chordata_Aves_Anseriformes_Anatidae_Mareca_penelope is 50.0 %
# Accuracy for class: 03255_Animalia_Chordata_Aves_Anseriformes_Anatidae_Mareca_strepera is 30.0 %
# Accuracy for class: 03256_Animalia_Chordata_Aves_Anseriformes_Anatidae_Melanitta_americana is 0.0 %
# Accuracy for class: 03257_Animalia_Chordata_Aves_Anseriformes_Anatidae_Melanitta_deglandi is 50.0 %
# Accuracy for class: 03258_Animalia_Chordata_Aves_Anseriformes_Anatidae_Melanitta_perspicillata is 60.0 %
# Accuracy for class: 03259_Animalia_Chordata_Aves_Anseriformes_Anatidae_Mergellus_albellus is 20.0 %
# Accuracy for class: 03260_Animalia_Chordata_Aves_Anseriformes_Anatidae_Mergus_merganser is 40.0 %
# Accuracy for class: 03261_Animalia_Chordata_Aves_Anseriformes_Anatidae_Mergus_serrator is 30.0 %
# Accuracy for class: 03262_Animalia_Chordata_Aves_Anseriformes_Anatidae_Netta_peposaca is 50.0 %
# Accuracy for class: 03263_Animalia_Chordata_Aves_Anseriformes_Anatidae_Netta_rufina is 30.0 %
# Accuracy for class: 03264_Animalia_Chordata_Aves_Anseriformes_Anatidae_Oxyura_jamaicensis is 60.0 %
# Accuracy for class: 03265_Animalia_Chordata_Aves_Anseriformes_Anatidae_Plectropterus_gambensis is 50.0 %
# Accuracy for class: 03266_Animalia_Chordata_Aves_Anseriformes_Anatidae_Sarkidiornis_melanotos is 40.0 %
# Accuracy for class: 03267_Animalia_Chordata_Aves_Anseriformes_Anatidae_Somateria_mollissima is 40.0 %
# Accuracy for class: 03268_Animalia_Chordata_Aves_Anseriformes_Anatidae_Spatula_clypeata is 80.0 %
# Accuracy for class: 03269_Animalia_Chordata_Aves_Anseriformes_Anatidae_Spatula_cyanoptera is 80.0 %
# Accuracy for class: 03270_Animalia_Chordata_Aves_Anseriformes_Anatidae_Spatula_discors is 10.0 %
# Accuracy for class: 03271_Animalia_Chordata_Aves_Anseriformes_Anatidae_Spatula_querquedula is 20.0 %
# Accuracy for class: 03272_Animalia_Chordata_Aves_Anseriformes_Anatidae_Spatula_rhynchotis is 60.0 %
# Accuracy for class: 03273_Animalia_Chordata_Aves_Anseriformes_Anatidae_Tadorna_ferruginea is 70.0 %
# Accuracy for class: 03274_Animalia_Chordata_Aves_Anseriformes_Anatidae_Tadorna_tadorna is 40.0 %
# Accuracy for class: 03275_Animalia_Chordata_Aves_Anseriformes_Anatidae_Tadorna_tadornoides is 70.0 %
# Accuracy for class: 03276_Animalia_Chordata_Aves_Anseriformes_Anatidae_Tadorna_variegata is 30.0 %
# Accuracy for class: 03277_Animalia_Chordata_Aves_Anseriformes_Anhimidae_Chauna_torquata is 80.0 %
# Accuracy for class: 03278_Animalia_Chordata_Aves_Anseriformes_Anseranatidae_Anseranas_semipalmata is 50.0 %
# Accuracy for class: 03279_Animalia_Chordata_Aves_Bucerotiformes_Bucerotidae_Anthracoceros_albirostris is 70.0 %
# Accuracy for class: 03280_Animalia_Chordata_Aves_Bucerotiformes_Bucerotidae_Lophoceros_alboterminatus is 80.0 %
# Accuracy for class: 03281_Animalia_Chordata_Aves_Bucerotiformes_Bucerotidae_Lophoceros_nasutus is 40.0 %
# Accuracy for class: 03282_Animalia_Chordata_Aves_Bucerotiformes_Bucerotidae_Tockus_leucomelas is 90.0 %
# Accuracy for class: 03283_Animalia_Chordata_Aves_Bucerotiformes_Bucorvidae_Bucorvus_leadbeateri is 80.0 %
# Accuracy for class: 03284_Animalia_Chordata_Aves_Bucerotiformes_Phoeniculidae_Phoeniculus_purpureus is 90.0 %
# Accuracy for class: 03285_Animalia_Chordata_Aves_Bucerotiformes_Upupidae_Upupa_epops is 60.0 %
# Accuracy for class: 03286_Animalia_Chordata_Aves_Caprimulgiformes_Apodidae_Aeronautes_saxatalis is 50.0 %
# Accuracy for class: 03287_Animalia_Chordata_Aves_Caprimulgiformes_Apodidae_Apus_apus is 40.0 %
# Accuracy for class: 03288_Animalia_Chordata_Aves_Caprimulgiformes_Apodidae_Chaetura_pelagica is 0.0 %
# Accuracy for class: 03289_Animalia_Chordata_Aves_Caprimulgiformes_Apodidae_Chaetura_vauxi is 10.0 %
# Accuracy for class: 03290_Animalia_Chordata_Aves_Caprimulgiformes_Caprimulgidae_Caprimulgus_europaeus is 20.0 %
# Accuracy for class: 03291_Animalia_Chordata_Aves_Caprimulgiformes_Caprimulgidae_Chordeiles_acutipennis is 10.0 %
# Accuracy for class: 03292_Animalia_Chordata_Aves_Caprimulgiformes_Caprimulgidae_Chordeiles_minor is 40.0 %
# Accuracy for class: 03293_Animalia_Chordata_Aves_Caprimulgiformes_Caprimulgidae_Nyctidromus_albicollis is 60.0 %
# Accuracy for class: 03294_Animalia_Chordata_Aves_Caprimulgiformes_Caprimulgidae_Phalaenoptilus_nuttallii is 50.0 %
# Accuracy for class: 03295_Animalia_Chordata_Aves_Caprimulgiformes_Nyctibiidae_Nyctibius_griseus is 50.0 %
# Accuracy for class: 03296_Animalia_Chordata_Aves_Caprimulgiformes_Nyctibiidae_Nyctibius_jamaicensis is 10.0 %
# Accuracy for class: 03297_Animalia_Chordata_Aves_Caprimulgiformes_Podargidae_Podargus_strigoides is 50.0 %
# Accuracy for class: 03298_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Amazilia_beryllina is 50.0 %
# Accuracy for class: 03299_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Amazilia_cyanocephala is 40.0 %
# Accuracy for class: 03300_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Amazilia_rutila is 60.0 %
# Accuracy for class: 03301_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Amazilia_tzacatl is 10.0 %
# Accuracy for class: 03302_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Amazilia_violiceps is 80.0 %
# Accuracy for class: 03303_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Amazilia_yucatanensis is 50.0 %
# Accuracy for class: 03304_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Anthracothorax_nigricollis is 0.0 %
# Accuracy for class: 03305_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Anthracothorax_prevostii is 10.0 %
# Accuracy for class: 03306_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Archilochus_alexandri is 50.0 %
# Accuracy for class: 03307_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Archilochus_colubris is 10.0 %
# Accuracy for class: 03308_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Boissonneaua_flavescens is 60.0 %
# Accuracy for class: 03309_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Calothorax_lucifer is 30.0 %
# Accuracy for class: 03310_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Calypte_anna is 10.0 %
# Accuracy for class: 03311_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Calypte_costae is 20.0 %
# Accuracy for class: 03312_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Campylopterus_hemileucurus is 80.0 %
# Accuracy for class: 03313_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Chlorostilbon_canivetii is 0.0 %
# Accuracy for class: 03314_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Chlorostilbon_lucidus is 20.0 %
# Accuracy for class: 03315_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Colibri_coruscans is 20.0 %
# Accuracy for class: 03316_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Colibri_cyanotus is 50.0 %
# Accuracy for class: 03317_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Cynanthus_latirostris is 10.0 %
# Accuracy for class: 03318_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Eugenes_fulgens is 40.0 %
# Accuracy for class: 03319_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Eupetomena_macroura is 30.0 %
# Accuracy for class: 03320_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Florisuga_mellivora is 80.0 %
# Accuracy for class: 03321_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Heliodoxa_jacula is 60.0 %
# Accuracy for class: 03322_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Hylocharis_leucotis is 30.0 %
# Accuracy for class: 03323_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Lampornis_clemenciae is 60.0 %
# Accuracy for class: 03324_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Ocreatus_underwoodii is 60.0 %
# Accuracy for class: 03325_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Selasphorus_calliope is 10.0 %
# Accuracy for class: 03326_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Selasphorus_platycercus is 30.0 %
# Accuracy for class: 03327_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Selasphorus_rufus is 20.0 %
# Accuracy for class: 03328_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Selasphorus_sasin is 20.0 %
# Accuracy for class: 03329_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Thalurania_colombica is 60.0 %
# Accuracy for class: 03330_Animalia_Chordata_Aves_Casuariiformes_Casuariidae_Dromaius_novaehollandiae is 70.0 %
# Accuracy for class: 03331_Animalia_Chordata_Aves_Cathartiformes_Cathartidae_Cathartes_aura is 30.0 %
# Accuracy for class: 03332_Animalia_Chordata_Aves_Cathartiformes_Cathartidae_Cathartes_burrovianus is 70.0 %
# Accuracy for class: 03333_Animalia_Chordata_Aves_Cathartiformes_Cathartidae_Coragyps_atratus is 30.0 %
# Accuracy for class: 03334_Animalia_Chordata_Aves_Cathartiformes_Cathartidae_Gymnogyps_californianus is 20.0 %
# Accuracy for class: 03335_Animalia_Chordata_Aves_Cathartiformes_Cathartidae_Sarcoramphus_papa is 60.0 %
# Accuracy for class: 03336_Animalia_Chordata_Aves_Cathartiformes_Cathartidae_Vultur_gryphus is 80.0 %
# Accuracy for class: 03337_Animalia_Chordata_Aves_Charadriiformes_Alcidae_Alca_torda is 40.0 %
# Accuracy for class: 03338_Animalia_Chordata_Aves_Charadriiformes_Alcidae_Brachyramphus_marmoratus is 30.0 %
# Accuracy for class: 03339_Animalia_Chordata_Aves_Charadriiformes_Alcidae_Cepphus_columba is 20.0 %
# Accuracy for class: 03340_Animalia_Chordata_Aves_Charadriiformes_Alcidae_Cepphus_grylle is 20.0 %
# Accuracy for class: 03341_Animalia_Chordata_Aves_Charadriiformes_Alcidae_Cerorhinca_monocerata is 30.0 %
# Accuracy for class: 03342_Animalia_Chordata_Aves_Charadriiformes_Alcidae_Fratercula_arctica is 80.0 %
# Accuracy for class: 03343_Animalia_Chordata_Aves_Charadriiformes_Alcidae_Uria_aalge is 50.0 %
# Accuracy for class: 03344_Animalia_Chordata_Aves_Charadriiformes_Burhinidae_Burhinus_bistriatus is 80.0 %
# Accuracy for class: 03345_Animalia_Chordata_Aves_Charadriiformes_Burhinidae_Burhinus_capensis is 80.0 %
# Accuracy for class: 03346_Animalia_Chordata_Aves_Charadriiformes_Burhinidae_Burhinus_grallarius is 70.0 %
# Accuracy for class: 03347_Animalia_Chordata_Aves_Charadriiformes_Burhinidae_Burhinus_vermiculatus is 80.0 %
# Accuracy for class: 03348_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_alexandrinus is 70.0 %
# Accuracy for class: 03349_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_bicinctus is 30.0 %
# Accuracy for class: 03350_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_collaris is 50.0 %
# Accuracy for class: 03351_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_dubius is 50.0 %
# Accuracy for class: 03352_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_hiaticula is 70.0 %
# Accuracy for class: 03353_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_leschenaultii is 10.0 %
# Accuracy for class: 03354_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_marginatus is 50.0 %
# Accuracy for class: 03355_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_melodus is 40.0 %
# Accuracy for class: 03356_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_mongolus is 30.0 %
# Accuracy for class: 03357_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_nivosus is 30.0 %
# Accuracy for class: 03358_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_obscurus is 50.0 %
# Accuracy for class: 03359_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_pecuarius is 50.0 %
# Accuracy for class: 03360_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_ruficapillus is 40.0 %
# Accuracy for class: 03361_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_semipalmatus is 40.0 %
# Accuracy for class: 03362_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_tricollaris is 70.0 %
# Accuracy for class: 03363_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_vociferus is 30.0 %
# Accuracy for class: 03364_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_wilsonia is 80.0 %
# Accuracy for class: 03365_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Elseyornis_melanops is 90.0 %
# Accuracy for class: 03366_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Pluvialis_apricaria is 20.0 %
# Accuracy for class: 03367_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Pluvialis_dominica is 40.0 %
# Accuracy for class: 03368_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Pluvialis_fulva is 10.0 %
# Accuracy for class: 03369_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Pluvialis_squatarola is 40.0 %
# Accuracy for class: 03370_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_armatus is 70.0 %
# Accuracy for class: 03371_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_chilensis is 60.0 %
# Accuracy for class: 03372_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_coronatus is 70.0 %
# Accuracy for class: 03373_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_indicus is 70.0 %
# Accuracy for class: 03374_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_miles is 60.0 %
# Accuracy for class: 03375_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_senegallus is 80.0 %
# Accuracy for class: 03376_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_spinosus is 40.0 %
# Accuracy for class: 03377_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_vanellus is 40.0 %
# Accuracy for class: 03378_Animalia_Chordata_Aves_Charadriiformes_Glareolidae_Glareola_pratincola is 80.0 %
# Accuracy for class: 03379_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_bachmani is 60.0 %
# Accuracy for class: 03380_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_finschi is 20.0 %
# Accuracy for class: 03381_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_fuliginosus is 20.0 %
# Accuracy for class: 03382_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_longirostris is 30.0 %
# Accuracy for class: 03383_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_moquini is 40.0 %
# Accuracy for class: 03384_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_ostralegus is 10.0 %
# Accuracy for class: 03385_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_palliatus is 40.0 %
# Accuracy for class: 03386_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_unicolor is 40.0 %
# Accuracy for class: 03387_Animalia_Chordata_Aves_Charadriiformes_Jacanidae_Actophilornis_africanus is 90.0 %
# Accuracy for class: 03388_Animalia_Chordata_Aves_Charadriiformes_Jacanidae_Hydrophasianus_chirurgus is 70.0 %
# Accuracy for class: 03389_Animalia_Chordata_Aves_Charadriiformes_Jacanidae_Irediparra_gallinacea is 70.0 %
# Accuracy for class: 03390_Animalia_Chordata_Aves_Charadriiformes_Jacanidae_Jacana_jacana is 80.0 %
# Accuracy for class: 03391_Animalia_Chordata_Aves_Charadriiformes_Jacanidae_Jacana_spinosa is 40.0 %
# Accuracy for class: 03392_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chlidonias_hybrida is 60.0 %
# Accuracy for class: 03393_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chlidonias_leucopterus is 20.0 %
# Accuracy for class: 03394_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chlidonias_niger is 50.0 %
# Accuracy for class: 03395_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_bulleri is 60.0 %
# Accuracy for class: 03396_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_cirrocephalus is 90.0 %
# Accuracy for class: 03397_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_genei is 30.0 %
# Accuracy for class: 03398_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_hartlaubii is 10.0 %
# Accuracy for class: 03399_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_maculipennis is 20.0 %
# Accuracy for class: 03400_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_novaehollandiae is 10.0 %
# Accuracy for class: 03401_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_philadelphia is 10.0 %
# Accuracy for class: 03402_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_ridibundus is 0.0 %
# Accuracy for class: 03403_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_serranus is 20.0 %
# Accuracy for class: 03404_Animalia_Chordata_Aves_Charadriiformes_Laridae_Gelochelidon_nilotica is 10.0 %
# Accuracy for class: 03405_Animalia_Chordata_Aves_Charadriiformes_Laridae_Hydrocoloeus_minutus is 10.0 %
# Accuracy for class: 03406_Animalia_Chordata_Aves_Charadriiformes_Laridae_Hydroprogne_caspia is 40.0 %
# Accuracy for class: 03407_Animalia_Chordata_Aves_Charadriiformes_Laridae_Ichthyaetus_ichthyaetus is 40.0 %
# Accuracy for class: 03408_Animalia_Chordata_Aves_Charadriiformes_Laridae_Ichthyaetus_melanocephalus is 30.0 %
# Accuracy for class: 03409_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_argentatus is 0.0 %
# Accuracy for class: 03410_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_cachinnans is 10.0 %
# Accuracy for class: 03411_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_californicus is 20.0 %
# Accuracy for class: 03412_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_canus is 0.0 %
# Accuracy for class: 03413_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_crassirostris is 0.0 %
# Accuracy for class: 03414_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_delawarensis is 30.0 %
# Accuracy for class: 03415_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_dominicanus is 0.0 %
# Accuracy for class: 03416_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_fuscus is 70.0 %
# Accuracy for class: 03417_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_glaucescens is 40.0 %
# Accuracy for class: 03418_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_glaucoides is 20.0 %
# Accuracy for class: 03419_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_heermanni is 60.0 %
# Accuracy for class: 03420_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_hyperboreus is 20.0 %
# Accuracy for class: 03421_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_livens is 30.0 %
# Accuracy for class: 03422_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_marinus is 10.0 %
# Accuracy for class: 03423_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_michahellis is 10.0 %
# Accuracy for class: 03424_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_occidentalis is 0.0 %
# Accuracy for class: 03425_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_pacificus is 20.0 %
# Accuracy for class: 03426_Animalia_Chordata_Aves_Charadriiformes_Laridae_Leucophaeus_atricilla is 0.0 %
# Accuracy for class: 03427_Animalia_Chordata_Aves_Charadriiformes_Laridae_Leucophaeus_pipixcan is 30.0 %
# Accuracy for class: 03428_Animalia_Chordata_Aves_Charadriiformes_Laridae_Phaetusa_simplex is 70.0 %
# Accuracy for class: 03429_Animalia_Chordata_Aves_Charadriiformes_Laridae_Rissa_tridactyla is 0.0 %
# Accuracy for class: 03430_Animalia_Chordata_Aves_Charadriiformes_Laridae_Rynchops_niger is 70.0 %
# Accuracy for class: 03431_Animalia_Chordata_Aves_Charadriiformes_Laridae_Sterna_forsteri is 0.0 %
# Accuracy for class: 03432_Animalia_Chordata_Aves_Charadriiformes_Laridae_Sterna_hirundo is 30.0 %
# Accuracy for class: 03433_Animalia_Chordata_Aves_Charadriiformes_Laridae_Sterna_paradisaea is 50.0 %
# Accuracy for class: 03434_Animalia_Chordata_Aves_Charadriiformes_Laridae_Sterna_striata is 50.0 %
# Accuracy for class: 03435_Animalia_Chordata_Aves_Charadriiformes_Laridae_Sternula_albifrons is 10.0 %
# Accuracy for class: 03436_Animalia_Chordata_Aves_Charadriiformes_Laridae_Sternula_antillarum is 30.0 %
# Accuracy for class: 03437_Animalia_Chordata_Aves_Charadriiformes_Laridae_Thalasseus_bergii is 30.0 %
# Accuracy for class: 03438_Animalia_Chordata_Aves_Charadriiformes_Laridae_Thalasseus_elegans is 20.0 %
# Accuracy for class: 03439_Animalia_Chordata_Aves_Charadriiformes_Laridae_Thalasseus_maximus is 40.0 %
# Accuracy for class: 03440_Animalia_Chordata_Aves_Charadriiformes_Laridae_Thalasseus_sandvicensis is 10.0 %
# Accuracy for class: 03441_Animalia_Chordata_Aves_Charadriiformes_Recurvirostridae_Himantopus_himantopus is 30.0 %
# Accuracy for class: 03442_Animalia_Chordata_Aves_Charadriiformes_Recurvirostridae_Himantopus_leucocephalus is 40.0 %
# Accuracy for class: 03443_Animalia_Chordata_Aves_Charadriiformes_Recurvirostridae_Himantopus_mexicanus is 20.0 %
# Accuracy for class: 03444_Animalia_Chordata_Aves_Charadriiformes_Recurvirostridae_Recurvirostra_americana is 60.0 %
# Accuracy for class: 03445_Animalia_Chordata_Aves_Charadriiformes_Recurvirostridae_Recurvirostra_avosetta is 60.0 %
# Accuracy for class: 03446_Animalia_Chordata_Aves_Charadriiformes_Rostratulidae_Rostratula_benghalensis is 50.0 %
# Accuracy for class: 03447_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Actitis_hypoleucos is 30.0 %
# Accuracy for class: 03448_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Actitis_macularius is 10.0 %
# Accuracy for class: 03449_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Arenaria_interpres is 70.0 %
# Accuracy for class: 03450_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Arenaria_melanocephala is 40.0 %
# Accuracy for class: 03451_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Bartramia_longicauda is 50.0 %
# Accuracy for class: 03452_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_acuminata is 50.0 %
# Accuracy for class: 03453_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_alba is 50.0 %
# Accuracy for class: 03454_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_alpina is 20.0 %
# Accuracy for class: 03455_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_bairdii is 10.0 %
# Accuracy for class: 03456_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_canutus is 30.0 %
# Accuracy for class: 03457_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_ferruginea is 20.0 %
# Accuracy for class: 03458_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_fuscicollis is 50.0 %
# Accuracy for class: 03459_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_himantopus is 10.0 %
# Accuracy for class: 03460_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_maritima is 70.0 %
# Accuracy for class: 03461_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_mauri is 10.0 %
# Accuracy for class: 03462_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_melanotos is 20.0 %
# Accuracy for class: 03463_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_minuta is 20.0 %
# Accuracy for class: 03464_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_minutilla is 60.0 %
# Accuracy for class: 03465_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_pugnax is 10.0 %
# Accuracy for class: 03466_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_pusilla is 20.0 %
# Accuracy for class: 03467_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_ruficollis is 30.0 %
# Accuracy for class: 03468_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_subruficollis is 40.0 %
# Accuracy for class: 03469_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_temminckii is 40.0 %
# Accuracy for class: 03470_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_virgata is 20.0 %
# Accuracy for class: 03471_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Gallinago_delicata is 10.0 %
# Accuracy for class: 03472_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Gallinago_gallinago is 80.0 %
# Accuracy for class: 03473_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Limnodromus_griseus is 30.0 %
# Accuracy for class: 03474_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Limnodromus_scolopaceus is 10.0 %
# Accuracy for class: 03475_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Limosa_fedoa is 40.0 %
# Accuracy for class: 03476_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Limosa_haemastica is 30.0 %
# Accuracy for class: 03477_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Limosa_lapponica is 0.0 %
# Accuracy for class: 03478_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Limosa_limosa is 40.0 %
# Accuracy for class: 03479_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Numenius_americanus is 30.0 %
# Accuracy for class: 03480_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Numenius_arquata is 0.0 %
# Accuracy for class: 03481_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Numenius_madagascariensis is 70.0 %
# Accuracy for class: 03482_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Numenius_phaeopus is 30.0 %
# Accuracy for class: 03483_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Phalaropus_fulicarius is 50.0 %
# Accuracy for class: 03484_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Phalaropus_lobatus is 40.0 %
# Accuracy for class: 03485_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Phalaropus_tricolor is 40.0 %
# Accuracy for class: 03486_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Scolopax_minor is 50.0 %
# Accuracy for class: 03487_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_brevipes is 50.0 %
# Accuracy for class: 03488_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_erythropus is 30.0 %
# Accuracy for class: 03489_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_flavipes is 0.0 %
# Accuracy for class: 03490_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_glareola is 40.0 %
# Accuracy for class: 03491_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_incana is 10.0 %
# Accuracy for class: 03492_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_melanoleuca is 40.0 %
# Accuracy for class: 03493_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_nebularia is 40.0 %
# Accuracy for class: 03494_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_ochropus is 40.0 %
# Accuracy for class: 03495_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_semipalmata is 30.0 %
# Accuracy for class: 03496_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_solitaria is 60.0 %
# Accuracy for class: 03497_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_stagnatilis is 40.0 %
# Accuracy for class: 03498_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_totanus is 20.0 %
# Accuracy for class: 03499_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Xenus_cinereus is 10.0 %
# Accuracy for class: 03500_Animalia_Chordata_Aves_Charadriiformes_Stercorariidae_Stercorarius_parasiticus is 0.0 %
# Accuracy for class: 03501_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Anastomus_oscitans is 20.0 %
# Accuracy for class: 03502_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Ciconia_ciconia is 50.0 %
# Accuracy for class: 03503_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Ciconia_episcopus is 50.0 %
# Accuracy for class: 03504_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Ciconia_maguari is 40.0 %
# Accuracy for class: 03505_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Ciconia_nigra is 10.0 %
# Accuracy for class: 03506_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Jabiru_mycteria is 60.0 %
# Accuracy for class: 03507_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Leptoptilos_crumenifer is 60.0 %
# Accuracy for class: 03508_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Mycteria_americana is 30.0 %
# Accuracy for class: 03509_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Mycteria_ibis is 20.0 %
# Accuracy for class: 03510_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Mycteria_leucocephala is 50.0 %
# Accuracy for class: 03511_Animalia_Chordata_Aves_Coliiformes_Coliidae_Colius_striatus is 70.0 %
# Accuracy for class: 03512_Animalia_Chordata_Aves_Columbiformes_Columbidae_Chalcophaps_indica is 80.0 %
# Accuracy for class: 03513_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columba_guinea is 40.0 %
# Accuracy for class: 03514_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columba_livia is 50.0 %
# Accuracy for class: 03515_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columba_oenas is 50.0 %
# Accuracy for class: 03516_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columba_palumbus is 70.0 %
# Accuracy for class: 03517_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columbina_inca is 30.0 %
# Accuracy for class: 03518_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columbina_passerina is 50.0 %
# Accuracy for class: 03519_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columbina_picui is 30.0 %
# Accuracy for class: 03520_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columbina_talpacoti is 50.0 %
# Accuracy for class: 03521_Animalia_Chordata_Aves_Columbiformes_Columbidae_Geopelia_humeralis is 70.0 %
# Accuracy for class: 03522_Animalia_Chordata_Aves_Columbiformes_Columbidae_Geopelia_placida is 70.0 %
# Accuracy for class: 03523_Animalia_Chordata_Aves_Columbiformes_Columbidae_Geopelia_striata is 0.0 %
# Accuracy for class: 03524_Animalia_Chordata_Aves_Columbiformes_Columbidae_Hemiphaga_novaeseelandiae is 30.0 %
# Accuracy for class: 03525_Animalia_Chordata_Aves_Columbiformes_Columbidae_Leptotila_verreauxi is 70.0 %
# Accuracy for class: 03526_Animalia_Chordata_Aves_Columbiformes_Columbidae_Ocyphaps_lophotes is 50.0 %
# Accuracy for class: 03527_Animalia_Chordata_Aves_Columbiformes_Columbidae_Patagioenas_cayennensis is 70.0 %
# Accuracy for class: 03528_Animalia_Chordata_Aves_Columbiformes_Columbidae_Patagioenas_fasciata is 30.0 %
# Accuracy for class: 03529_Animalia_Chordata_Aves_Columbiformes_Columbidae_Patagioenas_flavirostris is 30.0 %
# Accuracy for class: 03530_Animalia_Chordata_Aves_Columbiformes_Columbidae_Patagioenas_leucocephala is 50.0 %
# Accuracy for class: 03531_Animalia_Chordata_Aves_Columbiformes_Columbidae_Patagioenas_maculosa is 60.0 %
# Accuracy for class: 03532_Animalia_Chordata_Aves_Columbiformes_Columbidae_Patagioenas_picazuro is 30.0 %
# Accuracy for class: 03533_Animalia_Chordata_Aves_Columbiformes_Columbidae_Phaps_chalcoptera is 40.0 %
# Accuracy for class: 03534_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_capicola is 60.0 %
# Accuracy for class: 03535_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_chinensis is 10.0 %
# Accuracy for class: 03536_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_decaocto is 20.0 %
# Accuracy for class: 03537_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_orientalis is 40.0 %
# Accuracy for class: 03538_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_semitorquata is 60.0 %
# Accuracy for class: 03539_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_senegalensis is 70.0 %
# Accuracy for class: 03540_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_tranquebarica is 60.0 %
# Accuracy for class: 03541_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_turtur is 70.0 %
# Accuracy for class: 03542_Animalia_Chordata_Aves_Columbiformes_Columbidae_Treron_calvus is 50.0 %
# Accuracy for class: 03543_Animalia_Chordata_Aves_Columbiformes_Columbidae_Treron_vernans is 40.0 %
# Accuracy for class: 03544_Animalia_Chordata_Aves_Columbiformes_Columbidae_Zenaida_asiatica is 20.0 %
# Accuracy for class: 03545_Animalia_Chordata_Aves_Columbiformes_Columbidae_Zenaida_auriculata is 50.0 %
# Accuracy for class: 03546_Animalia_Chordata_Aves_Columbiformes_Columbidae_Zenaida_aurita is 40.0 %
# Accuracy for class: 03547_Animalia_Chordata_Aves_Columbiformes_Columbidae_Zenaida_macroura is 40.0 %
# Accuracy for class: 03548_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Alcedo_atthis is 60.0 %
# Accuracy for class: 03549_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Ceryle_rudis is 60.0 %
# Accuracy for class: 03550_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Chloroceryle_amazona is 60.0 %
# Accuracy for class: 03551_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Chloroceryle_americana is 40.0 %
# Accuracy for class: 03552_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Corythornis_cristatus is 70.0 %
# Accuracy for class: 03553_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Dacelo_novaeguineae is 40.0 %
# Accuracy for class: 03554_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Halcyon_albiventris is 70.0 %
# Accuracy for class: 03555_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Halcyon_senegalensis is 80.0 %
# Accuracy for class: 03556_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Halcyon_smyrnensis is 40.0 %
# Accuracy for class: 03557_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Megaceryle_alcyon is 50.0 %
# Accuracy for class: 03558_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Megaceryle_maxima is 70.0 %
# Accuracy for class: 03559_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Megaceryle_torquata is 40.0 %
# Accuracy for class: 03560_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Pelargopsis_capensis is 70.0 %
# Accuracy for class: 03561_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Todiramphus_chloris is 50.0 %
# Accuracy for class: 03562_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Todiramphus_macleayii is 80.0 %
# Accuracy for class: 03563_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Todiramphus_sanctus is 30.0 %
# Accuracy for class: 03564_Animalia_Chordata_Aves_Coraciiformes_Coraciidae_Coracias_benghalensis is 60.0 %
# Accuracy for class: 03565_Animalia_Chordata_Aves_Coraciiformes_Coraciidae_Coracias_caudatus is 80.0 %
# Accuracy for class: 03566_Animalia_Chordata_Aves_Coraciiformes_Coraciidae_Coracias_garrulus is 20.0 %
# Accuracy for class: 03567_Animalia_Chordata_Aves_Coraciiformes_Coraciidae_Eurystomus_orientalis is 60.0 %
# Accuracy for class: 03568_Animalia_Chordata_Aves_Coraciiformes_Meropidae_Merops_apiaster is 30.0 %
# Accuracy for class: 03569_Animalia_Chordata_Aves_Coraciiformes_Meropidae_Merops_bullockoides is 80.0 %
# ...
# Accuracy for class: 04444_Animalia_Chordata_Aves_Piciformes_Picidae_Dryobates_villosus is 20.0 %
# Accuracy for class: 04445_Animalia_Chordata_Aves_Piciformes_Picidae_Dryocopus_lineatus is 70.0 %
# Accuracy for class: 04446_Animalia_Chordata_Aves_Piciformes_Picidae_Dryocopus_martius is 50.0 %
# Accuracy for class: 04447_Animalia_Chordata_Aves_Piciformes_Picidae_Dryocopus_pileatus is 10.0 %
# Accuracy for class: 04448_Animalia_Chordata_Aves_Piciformes_Picidae_Jynx_torquilla is 40.0 %
# Accuracy for class: 04449_Animalia_Chordata_Aves_Piciformes_Picidae_Melanerpes_aurifrons is 0.0 %
# Accuracy for class: 04450_Animalia_Chordata_Aves_Piciformes_Picidae_Melanerpes_carolinus is 50.0 %
# Accuracy for class: 04451_Animalia_Chordata_Aves_Piciformes_Picidae_Melanerpes_chrysogenys is 50.0 %
# Accuracy for class: 04452_Animalia_Chordata_Aves_Piciformes_Picidae_Melanerpes_erythrocephalus is 40.0 %
# Accuracy for class: 04453_Animalia_Chordata_Aves_Piciformes_Picidae_Melanerpes_formicivorus is 40.0 %
# Accuracy for class: 04454_Animalia_Chordata_Aves_Piciformes_Picidae_Melanerpes_hoffmannii is 0.0 %
# Accuracy for class: 04455_Animalia_Chordata_Aves_Piciformes_Picidae_Melanerpes_lewis is 40.0 %
# Accuracy for class: 04456_Animalia_Chordata_Aves_Piciformes_Picidae_Melanerpes_pucherani is 40.0 %
# Accuracy for class: 04457_Animalia_Chordata_Aves_Piciformes_Picidae_Melanerpes_rubricapillus is 60.0 %
# Accuracy for class: 04458_Animalia_Chordata_Aves_Piciformes_Picidae_Melanerpes_uropygialis is 80.0 %
# Accuracy for class: 04459_Animalia_Chordata_Aves_Piciformes_Picidae_Picoides_arcticus is 20.0 %
# Accuracy for class: 04460_Animalia_Chordata_Aves_Piciformes_Picidae_Picoides_dorsalis is 90.0 %
# Accuracy for class: 04461_Animalia_Chordata_Aves_Piciformes_Picidae_Picus_canus is 50.0 %
# Accuracy for class: 04462_Animalia_Chordata_Aves_Piciformes_Picidae_Picus_viridis is 40.0 %
# Accuracy for class: 04463_Animalia_Chordata_Aves_Piciformes_Picidae_Sphyrapicus_nuchalis is 50.0 %
# Accuracy for class: 04464_Animalia_Chordata_Aves_Piciformes_Picidae_Sphyrapicus_ruber is 60.0 %
# Accuracy for class: 04465_Animalia_Chordata_Aves_Piciformes_Picidae_Sphyrapicus_thyroideus is 30.0 %
# Accuracy for class: 04466_Animalia_Chordata_Aves_Piciformes_Picidae_Sphyrapicus_varius is 20.0 %
# Accuracy for class: 04467_Animalia_Chordata_Aves_Piciformes_Ramphastidae_Aulacorhynchus_prasinus is 70.0 %
# Accuracy for class: 04468_Animalia_Chordata_Aves_Piciformes_Ramphastidae_Pteroglossus_castanotis is 70.0 %
# Accuracy for class: 04469_Animalia_Chordata_Aves_Piciformes_Ramphastidae_Pteroglossus_torquatus is 40.0 %
# Accuracy for class: 04470_Animalia_Chordata_Aves_Piciformes_Ramphastidae_Ramphastos_ambiguus is 30.0 %
# Accuracy for class: 04471_Animalia_Chordata_Aves_Piciformes_Ramphastidae_Ramphastos_sulfuratus is 100.0 %
# Accuracy for class: 04472_Animalia_Chordata_Aves_Piciformes_Ramphastidae_Ramphastos_toco is 40.0 %
# Accuracy for class: 04473_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Aechmophorus_clarkii is 20.0 %
# Accuracy for class: 04474_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Aechmophorus_occidentalis is 70.0 %
# Accuracy for class: 04475_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Podiceps_auritus is 20.0 %
# Accuracy for class: 04476_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Podiceps_cristatus is 50.0 %
# Accuracy for class: 04477_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Podiceps_grisegena is 20.0 %
# Accuracy for class: 04478_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Podiceps_major is 60.0 %
# Accuracy for class: 04479_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Podiceps_nigricollis is 50.0 %
# Accuracy for class: 04480_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Podilymbus_podiceps is 10.0 %
# Accuracy for class: 04481_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Poliocephalus_poliocephalus is 50.0 %
# Accuracy for class: 04482_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Rollandia_rolland is 80.0 %
# Accuracy for class: 04483_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Tachybaptus_dominicus is 50.0 %
# Accuracy for class: 04484_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Tachybaptus_novaehollandiae is 20.0 %
# Accuracy for class: 04485_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Tachybaptus_ruficollis is 0.0 %
# Accuracy for class: 04486_Animalia_Chordata_Aves_Procellariiformes_Diomedeidae_Phoebastria_immutabilis is 20.0 %
# Accuracy for class: 04487_Animalia_Chordata_Aves_Procellariiformes_Diomedeidae_Phoebastria_nigripes is 70.0 %
# Accuracy for class: 04488_Animalia_Chordata_Aves_Procellariiformes_Diomedeidae_Thalassarche_melanophris is 50.0 %
# Accuracy for class: 04489_Animalia_Chordata_Aves_Procellariiformes_Procellariidae_Ardenna_creatopus is 70.0 %
# Accuracy for class: 04490_Animalia_Chordata_Aves_Procellariiformes_Procellariidae_Ardenna_grisea is 0.0 %
# Accuracy for class: 04491_Animalia_Chordata_Aves_Procellariiformes_Procellariidae_Ardenna_pacifica is 30.0 %
# Accuracy for class: 04492_Animalia_Chordata_Aves_Procellariiformes_Procellariidae_Calonectris_diomedea is 10.0 %
# Accuracy for class: 04493_Animalia_Chordata_Aves_Procellariiformes_Procellariidae_Fulmarus_glacialis is 10.0 %
# Accuracy for class: 04494_Animalia_Chordata_Aves_Procellariiformes_Procellariidae_Macronectes_giganteus is 40.0 %
# Accuracy for class: 04495_Animalia_Chordata_Aves_Psittaciformes_Cacatuidae_Cacatua_galerita is 70.0 %
# Accuracy for class: 04496_Animalia_Chordata_Aves_Psittaciformes_Cacatuidae_Cacatua_sanguinea is 50.0 %
# Accuracy for class: 04497_Animalia_Chordata_Aves_Psittaciformes_Cacatuidae_Cacatua_tenuirostris is 80.0 %
# Accuracy for class: 04498_Animalia_Chordata_Aves_Psittaciformes_Cacatuidae_Callocephalon_fimbriatum is 70.0 %
# Accuracy for class: 04499_Animalia_Chordata_Aves_Psittaciformes_Cacatuidae_Calyptorhynchus_banksii is 60.0 %
# Accuracy for class: 04500_Animalia_Chordata_Aves_Psittaciformes_Cacatuidae_Calyptorhynchus_funereus is 40.0 %
# Accuracy for class: 04501_Animalia_Chordata_Aves_Psittaciformes_Cacatuidae_Eolophus_roseicapilla is 100.0 %
# Accuracy for class: 04502_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Amazona_albifrons is 0.0 %
# Accuracy for class: 04503_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Amazona_autumnalis is 30.0 %
# Accuracy for class: 04504_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Amazona_finschi is 20.0 %
# Accuracy for class: 04505_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Amazona_viridigenalis is 20.0 %
# Accuracy for class: 04506_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Ara_ararauna is 40.0 %
# Accuracy for class: 04507_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Ara_macao is 20.0 %
# Accuracy for class: 04508_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Aratinga_nenday is 70.0 %
# Accuracy for class: 04509_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Brotogeris_chiriri is 10.0 %
# Accuracy for class: 04510_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Brotogeris_jugularis is 20.0 %
# Accuracy for class: 04511_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Eupsittula_canicularis is 30.0 %
# Accuracy for class: 04512_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Eupsittula_nana is 20.0 %
# Accuracy for class: 04513_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Eupsittula_pertinax is 30.0 %
# Accuracy for class: 04514_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Forpus_conspicillatus is 60.0 %
# Accuracy for class: 04515_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Myiopsitta_monachus is 40.0 %
# Accuracy for class: 04516_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Pionus_menstruus is 50.0 %
# Accuracy for class: 04517_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Psittacara_erythrogenys is 0.0 %
# Accuracy for class: 04518_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Psittacara_holochlorus is 10.0 %
# Accuracy for class: 04519_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Psittacara_leucophthalmus is 50.0 %
# Accuracy for class: 04520_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Psittacara_mitratus is 30.0 %
# Accuracy for class: 04521_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Agapornis_roseicollis is 80.0 %
# Accuracy for class: 04522_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Alisterus_scapularis is 90.0 %
# Accuracy for class: 04523_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Barnardius_zonarius is 60.0 %
# Accuracy for class: 04524_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Cyanoramphus_novaezelandiae is 50.0 %
# Accuracy for class: 04525_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Glossopsitta_concinna is 70.0 %
# Accuracy for class: 04526_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Melopsittacus_undulatus is 50.0 %
# Accuracy for class: 04527_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Platycercus_adscitus is 80.0 %
# Accuracy for class: 04528_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Platycercus_elegans is 50.0 %
# Accuracy for class: 04529_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Platycercus_eximius is 90.0 %
# Accuracy for class: 04530_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Psephotus_haematonotus is 80.0 %
# Accuracy for class: 04531_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Psittacula_krameri is 30.0 %
# Accuracy for class: 04532_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Trichoglossus_chlorolepidotus is 40.0 %
# Accuracy for class: 04533_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Trichoglossus_moluccanus is 80.0 %
# Accuracy for class: 04534_Animalia_Chordata_Aves_Psittaciformes_Strigopidae_Nestor_meridionalis is 60.0 %
# Accuracy for class: 04535_Animalia_Chordata_Aves_Psittaciformes_Strigopidae_Nestor_notabilis is 50.0 %
# Accuracy for class: 04536_Animalia_Chordata_Aves_Sphenisciformes_Spheniscidae_Eudyptula_minor is 10.0 %
# Accuracy for class: 04537_Animalia_Chordata_Aves_Sphenisciformes_Spheniscidae_Pygoscelis_papua is 90.0 %
# Accuracy for class: 04538_Animalia_Chordata_Aves_Sphenisciformes_Spheniscidae_Spheniscus_demersus is 30.0 %
# Accuracy for class: 04539_Animalia_Chordata_Aves_Sphenisciformes_Spheniscidae_Spheniscus_magellanicus is 50.0 %
# Accuracy for class: 04540_Animalia_Chordata_Aves_Strigiformes_Strigidae_Aegolius_acadicus is 40.0 %
# Accuracy for class: 04541_Animalia_Chordata_Aves_Strigiformes_Strigidae_Asio_flammeus is 20.0 %
# Accuracy for class: 04542_Animalia_Chordata_Aves_Strigiformes_Strigidae_Asio_otus is 20.0 %
# Accuracy for class: 04543_Animalia_Chordata_Aves_Strigiformes_Strigidae_Athene_brama is 60.0 %
# Accuracy for class: 04544_Animalia_Chordata_Aves_Strigiformes_Strigidae_Athene_cunicularia is 60.0 %
# Accuracy for class: 04545_Animalia_Chordata_Aves_Strigiformes_Strigidae_Athene_noctua is 30.0 %
# Accuracy for class: 04546_Animalia_Chordata_Aves_Strigiformes_Strigidae_Bubo_africanus is 30.0 %
# Accuracy for class: 04547_Animalia_Chordata_Aves_Strigiformes_Strigidae_Bubo_bubo is 10.0 %
# Accuracy for class: 04548_Animalia_Chordata_Aves_Strigiformes_Strigidae_Bubo_scandiacus is 70.0 %
# Accuracy for class: 04549_Animalia_Chordata_Aves_Strigiformes_Strigidae_Bubo_virginianus is 10.0 %
# Accuracy for class: 04550_Animalia_Chordata_Aves_Strigiformes_Strigidae_Ciccaba_virgata is 80.0 %
# Accuracy for class: 04551_Animalia_Chordata_Aves_Strigiformes_Strigidae_Glaucidium_brasilianum is 70.0 %
# Accuracy for class: 04552_Animalia_Chordata_Aves_Strigiformes_Strigidae_Glaucidium_gnoma is 60.0 %
# Accuracy for class: 04553_Animalia_Chordata_Aves_Strigiformes_Strigidae_Megascops_asio is 40.0 %
# Accuracy for class: 04554_Animalia_Chordata_Aves_Strigiformes_Strigidae_Megascops_choliba is 50.0 %
# Accuracy for class: 04555_Animalia_Chordata_Aves_Strigiformes_Strigidae_Megascops_kennicottii is 30.0 %
# Accuracy for class: 04556_Animalia_Chordata_Aves_Strigiformes_Strigidae_Ninox_novaeseelandiae is 40.0 %
# Accuracy for class: 04557_Animalia_Chordata_Aves_Strigiformes_Strigidae_Strix_aluco is 0.0 %
# Accuracy for class: 04558_Animalia_Chordata_Aves_Strigiformes_Strigidae_Strix_nebulosa is 20.0 %
# Accuracy for class: 04559_Animalia_Chordata_Aves_Strigiformes_Strigidae_Strix_uralensis is 50.0 %
# Accuracy for class: 04560_Animalia_Chordata_Aves_Strigiformes_Strigidae_Strix_varia is 30.0 %
# Accuracy for class: 04561_Animalia_Chordata_Aves_Strigiformes_Strigidae_Surnia_ulula is 80.0 %
# Accuracy for class: 04562_Animalia_Chordata_Aves_Strigiformes_Tytonidae_Tyto_alba is 20.0 %
# Accuracy for class: 04563_Animalia_Chordata_Aves_Struthioniformes_Struthionidae_Struthio_camelus is 70.0 %
# Accuracy for class: 04564_Animalia_Chordata_Aves_Suliformes_Anhingidae_Anhinga_anhinga is 20.0 %
# Accuracy for class: 04565_Animalia_Chordata_Aves_Suliformes_Anhingidae_Anhinga_melanogaster is 30.0 %
# Accuracy for class: 04566_Animalia_Chordata_Aves_Suliformes_Anhingidae_Anhinga_novaehollandiae is 10.0 %
# Accuracy for class: 04567_Animalia_Chordata_Aves_Suliformes_Anhingidae_Anhinga_rufa is 50.0 %
# Accuracy for class: 04568_Animalia_Chordata_Aves_Suliformes_Fregatidae_Fregata_magnificens is 50.0 %
# Accuracy for class: 04569_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Microcarbo_africanus is 50.0 %
# Accuracy for class: 04570_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Microcarbo_melanoleucos is 50.0 %
# Accuracy for class: 04571_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Microcarbo_niger is 50.0 %
# Accuracy for class: 04572_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Microcarbo_pygmaeus is 0.0 %
# Accuracy for class: 04573_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Phalacrocorax_aristotelis is 10.0 %
# Accuracy for class: 04574_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Phalacrocorax_auritus is 0.0 %
# Accuracy for class: 04575_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Phalacrocorax_brasilianus is 20.0 %
# Accuracy for class: 04576_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Phalacrocorax_capensis is 10.0 %
# Accuracy for class: 04577_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Phalacrocorax_carbo is 10.0 %
# Accuracy for class: 04578_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Phalacrocorax_pelagicus is 10.0 %
# Accuracy for class: 04579_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Phalacrocorax_penicillatus is 50.0 %
# Accuracy for class: 04580_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Phalacrocorax_punctatus is 40.0 %
# Accuracy for class: 04581_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Phalacrocorax_sulcirostris is 40.0 %
# Accuracy for class: 04582_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Phalacrocorax_varius is 60.0 %
# Accuracy for class: 04583_Animalia_Chordata_Aves_Suliformes_Sulidae_Morus_bassanus is 20.0 %
# Accuracy for class: 04584_Animalia_Chordata_Aves_Suliformes_Sulidae_Morus_serrator is 10.0 %
# Accuracy for class: 04585_Animalia_Chordata_Aves_Suliformes_Sulidae_Sula_dactylatra is 20.0 %
# Accuracy for class: 04586_Animalia_Chordata_Aves_Suliformes_Sulidae_Sula_leucogaster is 10.0 %
# Accuracy for class: 04587_Animalia_Chordata_Aves_Suliformes_Sulidae_Sula_nebouxii is 60.0 %
# Accuracy for class: 04588_Animalia_Chordata_Aves_Suliformes_Sulidae_Sula_sula is 40.0 %
# Accuracy for class: 04589_Animalia_Chordata_Aves_Trogoniformes_Trogonidae_Pharomachrus_mocinno is 30.0 %
# Accuracy for class: 04590_Animalia_Chordata_Aves_Trogoniformes_Trogonidae_Trogon_caligatus is 30.0 %
# Accuracy for class: 04591_Animalia_Chordata_Aves_Trogoniformes_Trogonidae_Trogon_citreolus is 60.0 %
# Accuracy for class: 04592_Animalia_Chordata_Aves_Trogoniformes_Trogonidae_Trogon_collaris is 50.0 %
# Accuracy for class: 04593_Animalia_Chordata_Aves_Trogoniformes_Trogonidae_Trogon_elegans is 60.0 %
# Accuracy for class: 04594_Animalia_Chordata_Aves_Trogoniformes_Trogonidae_Trogon_massena is 40.0 %
# Accuracy for class: 04595_Animalia_Chordata_Aves_Trogoniformes_Trogonidae_Trogon_melanocephalus is 50.0 %
# Accuracy for class: 04596_Animalia_Chordata_Aves_Trogoniformes_Trogonidae_Trogon_rufus is 60.0 %
