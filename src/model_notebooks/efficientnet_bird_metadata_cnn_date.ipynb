# %%
import random
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import torch
import torch.optim as optim
import torch.nn as nn
from torch.utils.data import Subset
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.utils import make_grid 
from torch.utils.tensorboard import SummaryWriter
from torchvision.models import efficientnet_b0, EfficientNet_B0_Weights
from sklearn.model_selection import train_test_split
from PIL import Image

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
writer = SummaryWriter()

# %%
# Define transformations
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(30),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),    
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

val_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(), 
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
import json
import os
image_dir="data/train_mini/2021_train_mini"
json_file="data/train_mini/train_mini.json"
    
with open(json_file, 'r') as f:
    metadata = json.load(f)

# Extract images and annotations
image_metadata = metadata["images"]  # List of image metadata dicts
annotations = {ann["image_id"]: ann["category_id"] for ann in metadata["annotations"]}  # Map image_id to category_id
categories = {cat["id"]: cat["name"] for cat in metadata["categories"]}  # Map category_id to category name
# Create a mapping: {filename -> (latitude, longitude, category_id)}
image_data = {}
for img in image_metadata:
    #print(img["file_name"])
    #print(img["file_name"].split("/")[-2:])
    filename = img["file_name"].split("/")[-1]
    print(filename)
    image_id = img["id"]
    lat, long = img["latitude"], img["longitude"]
    category_id = annotations.get(image_id, -1)  # Default to -1 if not found
    image_data[filename] = (lat, long, category_id)
    break
# Get all valid image filenames that exist in metadata and directory
#self.image_files = [f for f in os.listdir(image_dir) if f in self.image_data]
image_files = []
for root, dirs, files in os.walk(image_dir):
    for file in files:
        if file in image_data:
            print(str(root + "/" + file).split("/")[-2:])
            print(str("/" + root + "/" + file).split("\\")[-1])
            image_files.append(str("/" + root + "/" + file).split("\\")[-1])
            break
# Out:
# d615f184-8af4-4c60-b9f8-3081c1607644.jpg
# ['2021_train_mini\\02912_Animalia_Chordata_Actinopterygii_Siluriformes_Ictaluridae_Ameiurus_nebulosus', 'd615f184-8af4-4c60-b9f8-3081c1607644.jpg']
# 02912_Animalia_Chordata_Actinopterygii_Siluriformes_Ictaluridae_Ameiurus_nebulosus/d615f184-8af4-4c60-b9f8-3081c1607644.jpg

# %%
image_data[filename]
# Out:
# (43.83486, -71.22231, 2912)

# %%
from torch.utils.data import Dataset
import json
import os


# need to normalise lat long data and add in the date data (month will do)

class ImageDatasetWithContext(Dataset):
    def __init__(self, image_dir, json_file, transform=None):
        self.image_dir = image_dir
        self.transform = transform

        # Load metadata JSON
        with open(json_file, 'r') as f:
            metadata = json.load(f)

        # Extract images and annotations
        self.image_metadata = metadata["images"]  # List of image metadata dicts
        self.annotations = {ann["image_id"]: ann["category_id"] for ann in metadata["annotations"]}  # Map image_id to category_id
        self.categories = {cat["id"]: cat["name"] for cat in metadata["categories"]}  # Map category_id to category name
        # Create a mapping: {filename -> (latitude, longitude, category_id)}
        self.image_data = {}
        for img in self.image_metadata:
            filename = img["file_name"].split("/")[-1]
            image_id = img["id"]

            lat, long = img["latitude"], img["longitude"]
            if type(img["latitude"]) is not float or img["latitude"] > 180 or img["latitude"] < -180:
                lat = 0
            if type(img["longitude"]) is not float or img["longitude"] > 180 or img["longitude"] < -180:
                long = 0   

            # normalise to be in range of cnn output [-0.25, 4.5]
            lat = ((lat + 180) / 360) * 4.75 - 0.25
            long = ((long + 180) / 360) * 4.75 - 0.25

            month = int(img["date"][5:7])
            month = (month / 12) * 4.75 - 0.25

            category_id = self.annotations[image_id]
            self.image_data[filename] = (lat, long, month, category_id)
        # Get all valid image filenames that exist in metadata and directory
        self.image_files = []
        for root, _, files in os.walk(image_dir):
            for file in files:
                if file in self.image_data:
                    self.image_files.append(str("/" + root + "/" + file).split("\\")[-1])



    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        file_path= self.image_files[idx]
        file_name = file_path.split("/")[-1]
        image_path = os.path.join(self.image_dir, file_path)

        # Load and transform image
        image = Image.open(image_path).convert("RGB")
        if self.transform:
            image = self.transform(image)

        # Retrieve lat/long and category
        lat, long, month, category_id = self.image_data[file_name]

        # Convert to tensors
        context_features = torch.tensor([lat, long, month], dtype=torch.float32)

        return image, context_features, category_id

# %%
train_data = ImageDatasetWithContext(image_dir="data/train_mini/2021_train_mini", json_file="data/train_mini/train_mini.json", transform=train_transform)
validation_data = ImageDatasetWithContext(image_dir="data/validation/2021_valid", json_file="data/validation/val.json", transform=val_transform)

# %%
# Create DataLoaders
train_loader = DataLoader(train_data, batch_size=128, shuffle=True, num_workers=0)
val_loader = DataLoader(validation_data, batch_size=128, shuffle=True, num_workers=0)

print(f"Training samples: {len(train_data)}")
print(f"Validation samples: {len(validation_data)}")
# Out:
# Training samples: 500000
# Validation samples: 100000

# %%
bird_indices = []
with open('bird_indices.txt', 'r') as f:
    for line in f:
        bird_indices.append(int(line[0:-1]))

bird_test_indices = []
with open('bird_val_indices.txt', 'r') as f:
    for line in f:
        bird_test_indices.append(int(line[0:-1]))

# %%
# Find all indices where the target (label) corresponds to birds
# Create a subset dataset containing only birds
train_data_birds = Subset(train_data, bird_indices)

# label_index_map = {}
# index_list = [] 
# label_list = []

# for i, (_, _, label) in enumerate(train_data_birds):
#     index_list.append(i)
#     label_list.append(label)
# # now, for each label, randomly select 20% of indices, these will become the val set. 
# index_list_train, index_list_val, labels_train, labels_val = train_test_split(
# index_list, label_list, test_size=0.2, random_state=42, stratify=label_list)

# %%
def output_list(list, file_name):
    with open(file_name, 'w') as f:
        for line in list:
            f.write(f"{line}\n")
    return

# output_list(index_list_train, "index_list_train.csv")
# output_list(index_list_val, "index_list_val.csv")
# output_list(labels_train, "labels_train.csv")
# output_list(labels_val, "labels_val.csv")

# %%
def read_list_from_file(file_name):
    output_list = []
    with open(file_name, 'r') as f:
        for line in f:
            output_list.append(int(line[0:-1]))
    return output_list

index_list_train = read_list_from_file("index_list_train.csv") 
index_list_val = read_list_from_file("index_list_val.csv") 
labels_train = read_list_from_file("labels_train.csv") 
labels_val = read_list_from_file("labels_val.csv")

# %%
val_data_birds = Subset(train_data_birds, index_list_val)
train_data_birds = Subset(train_data_birds, index_list_train)

# %%
# Create a DataLoader for the filtered dataset
train_loader_birds = DataLoader(train_data_birds, batch_size=32, shuffle=True, num_workers=0)
val_loader_birds = DataLoader(val_data_birds, batch_size=32, shuffle=True, num_workers=0)

# use validation set from problem as the unseen test set
test_data_birds = Subset(validation_data, bird_test_indices)
test_loader_birds = DataLoader(test_data_birds, batch_size=32, shuffle=True, num_workers=0)

print(f"Filtered train dataset contains {len(train_data_birds)} bird images.")
print(f"Filtered val dataset contains {len(val_data_birds)} bird images.")
print(f"Filtered test dataset contains {len(test_data_birds)} bird images.")
# Out:
# Filtered train dataset contains 59440 bird images.
# Filtered val dataset contains 14860 bird images.
# Filtered test dataset contains 14860 bird images.

# %%
plt.imshow(train_data_birds[198][0].permute(1,2,0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(train_data_birds[1334][0].permute(1,2,0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# functions to show an image
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# create data augmentation example plot
images = []
for i in range(0, 16):
    images.append(train_data_birds[1334][0])

# show images
imshow(make_grid(images, nrow=4))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
bird_cat_list = []

for file_name in train_data.image_files:
    full_species = file_name.split("/")[0]
    if "Animalia_Chordata_Aves" in full_species and full_species not in bird_cat_list:
        bird_cat_list.append(full_species)
n_classes = len(bird_cat_list)

# %%
def remap_labels(labels):
    return (labels - 3111).long()  


def log_metrics_tensor_board(data_type, accuracy, top_5_accuracy, loss, epoch ):
    writer.add_scalar(f"Loss -  {data_type}", loss, epoch)
    writer.add_scalar(f"Accuracy -  {data_type}", 100 * accuracy, epoch)
    writer.add_scalar(f"Top 5 Accuracy - {data_type}", 100 * top_5_accuracy, epoch)
    return


def save_model(model, criterion, optimizer,  epoch, model_name):
    torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'loss': criterion,
                }, f"runs/model_pretrained_{model_name}.pth")
    return


def run_epoch(model, loader, criterion, optimizer=None, epoch=0, mode="train"):
    is_train = mode == "train"
    model.train() if is_train else model.eval()

    running_loss = 0.0
    correct = 0
    top_5_correct = 0
    total = 0

    with torch.set_grad_enabled(is_train):  # Only compute gradients during training
        for images, contextual_data, labels in loader: ##HERE
            images, contextual_data, labels = images.to(device), contextual_data.to(device), labels.to(device) ##HERE
            labels = remap_labels(labels).to(device)
            outputs = model(images, contextual_data)  # Forward pass  ##HERE
            loss = criterion(outputs, labels)  # Compute loss

            if is_train:
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

            running_loss += loss.item()
            _, predicted = outputs.max(1)
            # count total correct predicitions in batch
            correct += (predicted == labels).sum().item()
            total += labels.size(0)
            # count total matches of label in top 5 class predictions 
            _, top_5_predicted = outputs.topk(5, dim=1)
            top_5_correct += torch.isin(labels, top_5_predicted).sum().item()

    avg_loss = running_loss / len(loader)
    accuracy = correct / total
    top_5_accuracy = top_5_correct / total
    log_metrics_tensor_board(mode, accuracy, top_5_accuracy, avg_loss, epoch)

    print(f"{mode.capitalize()} Accuracy: {100 * accuracy:.2f}%")
    print(f"Top 5 {mode.capitalize()} Accuracy: {100 * top_5_accuracy:.2f}%")
    print(f"Epoch {epoch+1} - {mode.capitalize()} Loss: {avg_loss:.4f}")
    return avg_loss, accuracy


def train_model(model, model_name, train_loader, val_loader, criterion, optimizer, epochs=5, early_stop_limit=5):
    best_val_loss = float('inf')
    early_stop_count = 0
    # lists to track of loss and accuracy metrics
    train_loss_list, val_loss_list = [], []
    train_acc_list, val_acc_list = [], []

    for epoch in range(epochs):
        train_loss, train_acc = run_epoch(model, train_loader, criterion, optimizer, epoch, mode="train")
        # if no val loader, evaluate stopping based on train metrics (e.g. when training on validation after training on train before evaluating on test)
        if val_loader is None:
            val_loss, val_acc = train_loss, train_acc
        else:
            val_loss, val_acc = run_epoch(model, val_loader, criterion, None, epoch, mode="validation")
        # store metrics
        train_loss_list.append(train_loss)
        val_loss_list.append(val_loss)
        train_acc_list.append(train_acc)
        val_acc_list.append(val_acc)
        # early stopping
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            early_stop_count = 0
            # save best model so far
            save_model(model, criterion, optimizer,  epoch, model_name)
        else:
            early_stop_count += 1
        if early_stop_count == early_stop_limit:
            break
    eval_metrics = {
            "train_loss": train_loss_list,
            "val_loss": val_loss_list,
            "train_acc": train_acc_list,
            "val_acc": val_acc_list
        }
    return eval_metrics

# %%
class EfficientNet_ContextualData(nn.Module):
    def __init__(self, num_classes, contextual_dim, tune_all_layers=True):
        super(EfficientNet_ContextualData, self).__init__()

        # Load EfficientNet-B0 with pretrained weights
        self.weights = EfficientNet_B0_Weights.DEFAULT
        self.pretrained_model = efficientnet_b0(weights=self.weights)

        # Remove classifier by keeping only the feature extractor cnn layers
        self.feature_extractor = self.pretrained_model.features

        # Freeze or unfreeze the training of cnn layers
        if not tune_all_layers:
            for param in self.feature_extractor.parameters():
                param.requires_grad = False

        # get pretrained model number of output features
        cnn_out_features = self.pretrained_model.classifier[1].in_features
        
        # Define final classifier layer combining CNN + Contextual Data
        self.classifier = nn.Sequential(
            nn.Linear(cnn_out_features + contextual_dim, 2048),  # Combine features
            nn.BatchNorm1d(2048),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(2048, num_classes)  # Final output layer
        )

    def forward(self, image_data, contextual_data):

        # put image data through feature extactor 
        cnn_output = self.feature_extractor(image_data)
        cnn_output = torch.mean(cnn_output, dim=[2, 3])  # Global average pooling
        # flatten CNN output data
        cnn_output = cnn_output.view(cnn_output.size(0), -1)  

        # combine CNN output with contextual data
        combined_input = torch.cat((cnn_output, contextual_data), dim=1)
        # Pass through the classifier for final prediction
        output = self.classifier(combined_input)
        return output

# %%
# efficient net model 

model = EfficientNet_ContextualData(n_classes, 3)
model.to(device)

criterion = nn.CrossEntropyLoss().to(device)
optimizer = optim.Adam(model.parameters(), lr=0.0001, weight_decay=1e-3)


# Train the model
eval_metrics = train_model(model, "efficientnet_geographical_date_data_b0", train_loader_birds, val_loader_birds, criterion, optimizer, epochs=100, early_stop_limit=3)
# Out:
# Train Accuracy: 4.53%
# Top 5 Train Accuracy: 18.02%
# Epoch 1 - Train Loss: 6.0792
# Validation Accuracy: 16.54%
# Top 5 Validation Accuracy: 42.46%
# Epoch 1 - Validation Loss: 4.5327
# Train Accuracy: 19.57%
# Top 5 Train Accuracy: 46.62%
# Epoch 2 - Train Loss: 4.1898
# Validation Accuracy: 29.49%
# Top 5 Validation Accuracy: 59.73%
# Epoch 2 - Validation Loss: 3.5129
# Train Accuracy: 32.17%
# Top 5 Train Accuracy: 62.34%
# Epoch 3 - Train Loss: 3.3421
# Validation Accuracy: 37.84%
# Top 5 Validation Accuracy: 68.22%
# Epoch 3 - Validation Loss: 2.9367
# Train Accuracy: 41.03%
# Top 5 Train Accuracy: 70.68%
# Epoch 4 - Train Loss: 2.8163
# Validation Accuracy: 42.75%
# Top 5 Validation Accuracy: 71.84%
# Epoch 4 - Validation Loss: 2.6494
# Train Accuracy: 46.82%
# Top 5 Train Accuracy: 75.38%
# Epoch 5 - Train Loss: 2.4933
# Validation Accuracy: 45.11%
# Top 5 Validation Accuracy: 73.88%
# Epoch 5 - Validation Loss: 2.4983
# Train Accuracy: 50.90%
# Top 5 Train Accuracy: 78.47%
# Epoch 6 - Train Loss: 2.2890
# Validation Accuracy: 47.07%
# Top 5 Validation Accuracy: 75.18%
# Epoch 6 - Validation Loss: 2.3966
# Train Accuracy: 53.63%
# Top 5 Train Accuracy: 80.54%
# Epoch 7 - Train Loss: 2.1367
# Validation Accuracy: 48.59%
# Top 5 Validation Accuracy: 76.05%
# Epoch 7 - Validation Loss: 2.3297
# Train Accuracy: 56.39%
# Top 5 Train Accuracy: 82.20%
# Epoch 8 - Train Loss: 2.0231
# Validation Accuracy: 48.58%
# Top 5 Validation Accuracy: 76.28%
# Epoch 8 - Validation Loss: 2.2993
# Train Accuracy: 57.78%
# Top 5 Train Accuracy: 83.54%
# Epoch 9 - Train Loss: 1.9372
# Validation Accuracy: 49.24%
# Top 5 Validation Accuracy: 76.06%
# Epoch 9 - Validation Loss: 2.2811
# Train Accuracy: 59.27%
# Top 5 Train Accuracy: 84.48%
# Epoch 10 - Train Loss: 1.8693
# Validation Accuracy: 49.87%
# Top 5 Validation Accuracy: 77.15%
# Epoch 10 - Validation Loss: 2.2304
# Train Accuracy: 60.38%
# Top 5 Train Accuracy: 85.37%
# Epoch 11 - Train Loss: 1.8143
# Validation Accuracy: 49.75%
# Top 5 Validation Accuracy: 76.82%
# Epoch 11 - Validation Loss: 2.2491
# Train Accuracy: 61.40%
# Top 5 Train Accuracy: 85.83%
# Epoch 12 - Train Loss: 1.7721
# Validation Accuracy: 51.15%
# Top 5 Validation Accuracy: 76.94%
# Epoch 12 - Validation Loss: 2.2034
# Train Accuracy: 62.35%
# Top 5 Train Accuracy: 86.46%
# Epoch 13 - Train Loss: 1.7291
# Validation Accuracy: 50.58%
# Top 5 Validation Accuracy: 77.17%
# Epoch 13 - Validation Loss: 2.2087
# Train Accuracy: 63.01%
# Top 5 Train Accuracy: 86.88%
# Epoch 14 - Train Loss: 1.6981
# Validation Accuracy: 51.15%
# Top 5 Validation Accuracy: 77.19%
# Epoch 14 - Validation Loss: 2.1961
# Train Accuracy: 63.63%
# Top 5 Train Accuracy: 87.42%
# Epoch 15 - Train Loss: 1.6654
# Validation Accuracy: 50.22%
# Top 5 Validation Accuracy: 76.97%
# Epoch 15 - Validation Loss: 2.2037
# Train Accuracy: 64.25%
# Top 5 Train Accuracy: 87.85%
# Epoch 16 - Train Loss: 1.6362
# Validation Accuracy: 50.40%
# Top 5 Validation Accuracy: 77.09%
# Epoch 16 - Validation Loss: 2.2113
# Train Accuracy: 64.70%
# Top 5 Train Accuracy: 88.08%
# Epoch 17 - Train Loss: 1.6117
# Validation Accuracy: 50.95%
# Top 5 Validation Accuracy: 77.21%
# Epoch 17 - Validation Loss: 2.1974

# %%
def create_eval_plots(eval_metrics, model_name):
    # Convert eval_metrics to a DataFrame and add an 'epoch' column
    plot_df = pd.DataFrame.from_dict(eval_metrics)
    plot_df["epoch"] = plot_df.index + 1

    # Loss Plot 
    fig, ax = plt.subplots(figsize=(10, 8))
    
    ax.plot(plot_df["epoch"], plot_df["train_loss"], label="Training Loss",
            color="darkblue", linewidth=2)
    ax.plot(plot_df["epoch"], plot_df["val_loss"], label="Validation Loss",
            color="darkgreen", linewidth=2)
    
    # styling
    ax.set_xlabel("Epoch", fontsize=14)
    ax.set_ylabel("Loss", fontsize=14)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.grid(axis="y", alpha=0.7)
    ax.grid(axis="x", visible=False)
    ax.legend(fontsize=12)
    # save plot
    fig.savefig(f"outputs/loss_{model_name}.png", bbox_inches="tight")
    
    # Accuracy Plot
    fig, ax = plt.subplots(figsize=(10, 8))
    
    # Scale accuracy values to percentages
    plot_df["train_acc"] *= 100
    plot_df["val_acc"] *= 100
    
    # Plot training and validation accuracies
    ax.plot(plot_df["epoch"], plot_df["train_acc"], label="Training Accuracy",
            color="darkblue", linewidth=2)
    ax.plot(plot_df["epoch"], plot_df["val_acc"], label="Validation Accuracy",
            color="darkgreen", linewidth=2)
    
    # styling
    ax.set_xlabel("Epoch", fontsize=14)
    ax.set_ylabel("Accuracy (%)", fontsize=14)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.grid(axis="y", alpha=0.7)
    ax.grid(axis="x", visible=False)
    ax.legend(fontsize=12)
    # save plot
    fig.savefig(f"outputs/accuracy_{model_name}.png", bbox_inches="tight")
    plt.close("all")
    return

create_eval_plots(eval_metrics, "efficientnet_geographical_date_data_b")

# %%
# Load the checkpoint
checkpoint = torch.load(f"runs/model_pretrained_efficientnet_geographical_date_data_b0.pth")

trained_model = EfficientNet_ContextualData(n_classes, 3)
trained_model.to(device)


# Define optimizer
optimizer = optim.Adam(trained_model.parameters(), lr=0.0001, weight_decay=1e-3)  # Use the same optimizer as before
# Load model and optimizer states
trained_model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

train_model(trained_model, "efficientnet_geographical_date_data_b0_final", val_loader_birds, None, criterion, optimizer, epochs=5, early_stop_limit=3)
# Out:
# C:\Users\Sean\AppData\Local\Temp\ipykernel_17164\4173131790.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(f"runs/model_pretrained_efficientnet_geographical_date_data_b0.pth")
# Train Accuracy: 43.01%
# Top 5 Train Accuracy: 70.90%
# Epoch 1 - Train Loss: 2.6268
# Train Accuracy: 50.51%
# Top 5 Train Accuracy: 77.69%
# Epoch 2 - Train Loss: 2.2448
# Train Accuracy: 55.91%
# Top 5 Train Accuracy: 81.91%
# Epoch 3 - Train Loss: 2.0074
# Train Accuracy: 60.77%
# Top 5 Train Accuracy: 84.88%
# Epoch 4 - Train Loss: 1.8330
# Train Accuracy: 64.58%
# Top 5 Train Accuracy: 87.83%
# Epoch 5 - Train Loss: 1.6699
# {'train_loss': [2.6268441869366552,
#   2.2447947971282467,
#   2.007387006410988,
#   1.8330326801987105,
#   1.6698576551611706],
#  'val_loss': [2.6268441869366552,
#   2.2447947971282467,
#   2.007387006410988,
#   1.8330326801987105,
#   1.6698576551611706],
#  'train_acc': [0.4300807537012113,
#   0.505114401076716,
#   0.5590847913862719,
#   0.6077388963660835,
#   0.6457604306864064],
#  'val_acc': [0.4300807537012113,
#   0.505114401076716,
#   0.5590847913862719,
#   0.6077388963660835,
#   0.6457604306864064]}

# %%
# evaluate on test
val_loss, val_acc = run_epoch(trained_model, test_loader_birds, criterion, None, epoch=0, mode="validation")
# Out:
# Validation Accuracy: 52.71%
# Top 5 Validation Accuracy: 78.80%
# Epoch 1 - Validation Loss: 2.1127

# %%
save_model(trained_model, criterion, optimizer, epoch=18, model_name="efficientnet_geographical_date_data_b0_full_train")

# %%
bird_classes = []
for file_name in train_data.image_files:
    full_species = file_name.split("/")[0]
    if "Animalia_Chordata_Aves" in full_species and full_species not in bird_classes:
        bird_classes.append(full_species)

# %%
bird_classes
# Out:
# ['03111_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_badius',
#  '03112_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_cooperii',
#  '03113_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_gentilis',
#  '03114_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_nisus',
#  '03115_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_striatus',
#  '03116_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_trivirgatus',
#  '03117_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aegypius_monachus',
#  '03118_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_audax',
#  '03119_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_chrysaetos',
#  '03120_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_heliaca',
#  '03121_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_nipalensis',
#  '03122_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_rapax',
#  '03123_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Busarellus_nigricollis',
#  '03124_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_albonotatus',
#  '03125_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_brachyurus',
#  '03126_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_buteo',
#  '03127_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_jamaicensis',
#  '03128_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_lagopus',
#  '03129_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_lineatus',
#  '03130_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_plagiatus',
#  '03131_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_platypterus',
#  '03132_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_regalis',
#  '03133_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_rufinus',
#  '03134_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_rufofuscus',
#  '03135_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_swainsoni',
#  '03136_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteogallus_anthracinus',
#  '03137_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteogallus_meridionalis',
#  '03138_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteogallus_urubitinga',
#  '03139_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Chondrohierax_uncinatus',
#  '03140_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circaetus_cinereus',
#  '03141_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circaetus_gallicus',
#  '03142_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circus_aeruginosus',
#  '03143_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circus_approximans',
#  '03144_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circus_cyaneus',
#  '03145_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circus_hudsonius',
#  '03146_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circus_macrourus',
#  '03147_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circus_pygargus',
#  '03148_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Clanga_clanga',
#  '03149_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Elanoides_forficatus',
#  '03150_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Elanus_axillaris',
#  '03151_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Elanus_caeruleus',
#  '03152_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Elanus_leucurus',
#  '03153_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Geranoaetus_albicaudatus',
#  '03154_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Geranoaetus_melanoleucus',
#  '03155_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Geranoaetus_polyosoma',
#  '03156_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Geranospiza_caerulescens',
#  '03157_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Gypaetus_barbatus',
#  '03158_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Gyps_africanus',
#  '03159_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Gyps_fulvus',
#  '03160_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Haliaeetus_albicilla',
#  '03161_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Haliaeetus_leucocephalus',
#  '03162_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Haliaeetus_leucogaster',
#  '03163_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Haliaeetus_vocifer',
#  '03164_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Haliastur_indus',
#  '03165_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Haliastur_sphenurus',
#  '03166_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Hieraaetus_pennatus',
#  '03167_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Ictinia_mississippiensis',
#  '03168_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Ictinia_plumbea',
#  '03169_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Lophaetus_occipitalis',
#  '03170_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Melierax_canorus',
#  '03171_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Milvus_migrans',
#  '03172_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Milvus_milvus',
#  '03173_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Necrosyrtes_monachus',
#  '03174_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Neophron_percnopterus',
#  '03175_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Nisaetus_cirrhatus',
#  '03176_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Parabuteo_unicinctus',
#  '03177_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Pernis_apivorus',
#  '03178_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Pernis_ptilorhynchus',
#  '03179_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Polemaetus_bellicosus',
#  '03180_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Polyboroides_typus',
#  '03181_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Rostrhamus_sociabilis',
#  '03182_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Rupornis_magnirostris',
#  '03183_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Spilornis_cheela',
#  '03184_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Terathopius_ecaudatus',
#  '03185_Animalia_Chordata_Aves_Accipitriformes_Pandionidae_Pandion_haliaetus',
#  '03186_Animalia_Chordata_Aves_Accipitriformes_Sagittariidae_Sagittarius_serpentarius',
#  '03187_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aix_galericulata',
#  '03188_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aix_sponsa',
#  '03189_Animalia_Chordata_Aves_Anseriformes_Anatidae_Alopochen_aegyptiaca',
#  '03190_Animalia_Chordata_Aves_Anseriformes_Anatidae_Amazonetta_brasiliensis',
#  '03191_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_acuta',
#  '03192_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_bahamensis',
#  '03193_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_castanea',
#  '03194_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_crecca',
#  '03195_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_diazi',
#  '03196_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_erythrorhyncha',
#  '03197_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_flavirostris',
#  '03198_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_fulvigula',
#  '03199_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_georgica',
#  '03200_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_gracilis',
#  '03201_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_platyrhynchos',
#  '03202_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_poecilorhyncha',
#  '03203_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_rubripes',
#  '03204_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_superciliosa',
#  '03205_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_undulata',
#  '03206_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_zonorhyncha',
#  '03207_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_albifrons',
#  '03208_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_anser',
#  '03209_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_brachyrhynchus',
#  '03210_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_caerulescens',
#  '03211_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_cygnoides',
#  '03212_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_fabalis',
#  '03213_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_indicus',
#  '03214_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_rossii',
#  '03215_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_affinis',
#  '03216_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_americana',
#  '03217_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_australis',
#  '03218_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_collaris',
#  '03219_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_ferina',
#  '03220_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_fuligula',
#  '03221_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_marila',
#  '03222_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_novaeseelandiae',
#  '03223_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_nyroca',
#  '03224_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_valisineria',
#  '03225_Animalia_Chordata_Aves_Anseriformes_Anatidae_Branta_bernicla',
#  '03226_Animalia_Chordata_Aves_Anseriformes_Anatidae_Branta_canadensis',
#  '03227_Animalia_Chordata_Aves_Anseriformes_Anatidae_Branta_hutchinsii',
#  '03228_Animalia_Chordata_Aves_Anseriformes_Anatidae_Branta_leucopsis',
#  '03229_Animalia_Chordata_Aves_Anseriformes_Anatidae_Branta_sandvicensis',
#  '03230_Animalia_Chordata_Aves_Anseriformes_Anatidae_Bucephala_albeola',
#  '03231_Animalia_Chordata_Aves_Anseriformes_Anatidae_Bucephala_clangula',
#  '03232_Animalia_Chordata_Aves_Anseriformes_Anatidae_Bucephala_islandica',
#  '03233_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cairina_moschata',
#  '03234_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cereopsis_novaehollandiae',
#  '03235_Animalia_Chordata_Aves_Anseriformes_Anatidae_Chenonetta_jubata',
#  '03236_Animalia_Chordata_Aves_Anseriformes_Anatidae_Chloephaga_picta',
#  '03237_Animalia_Chordata_Aves_Anseriformes_Anatidae_Clangula_hyemalis',
#  '03238_Animalia_Chordata_Aves_Anseriformes_Anatidae_Coscoroba_coscoroba',
#  '03239_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cygnus_atratus',
#  '03240_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cygnus_buccinator',
#  '03241_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cygnus_columbianus',
#  '03242_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cygnus_cygnus',
#  '03243_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cygnus_melancoryphus',
#  '03244_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cygnus_olor',
#  '03245_Animalia_Chordata_Aves_Anseriformes_Anatidae_Dendrocygna_autumnalis',
#  '03246_Animalia_Chordata_Aves_Anseriformes_Anatidae_Dendrocygna_bicolor',
#  '03247_Animalia_Chordata_Aves_Anseriformes_Anatidae_Dendrocygna_javanica',
#  '03248_Animalia_Chordata_Aves_Anseriformes_Anatidae_Dendrocygna_viduata',
#  '03249_Animalia_Chordata_Aves_Anseriformes_Anatidae_Histrionicus_histrionicus',
#  '03250_Animalia_Chordata_Aves_Anseriformes_Anatidae_Lophodytes_cucullatus',
#  '03251_Animalia_Chordata_Aves_Anseriformes_Anatidae_Lophonetta_specularioides',
#  '03252_Animalia_Chordata_Aves_Anseriformes_Anatidae_Malacorhynchus_membranaceus',
#  '03253_Animalia_Chordata_Aves_Anseriformes_Anatidae_Mareca_americana',
#  '03254_Animalia_Chordata_Aves_Anseriformes_Anatidae_Mareca_penelope',
#  '03255_Animalia_Chordata_Aves_Anseriformes_Anatidae_Mareca_strepera',
#  '03256_Animalia_Chordata_Aves_Anseriformes_Anatidae_Melanitta_americana',
#  '03257_Animalia_Chordata_Aves_Anseriformes_Anatidae_Melanitta_deglandi',
#  '03258_Animalia_Chordata_Aves_Anseriformes_Anatidae_Melanitta_perspicillata',
#  '03259_Animalia_Chordata_Aves_Anseriformes_Anatidae_Mergellus_albellus',
#  '03260_Animalia_Chordata_Aves_Anseriformes_Anatidae_Mergus_merganser',
#  '03261_Animalia_Chordata_Aves_Anseriformes_Anatidae_Mergus_serrator',
#  '03262_Animalia_Chordata_Aves_Anseriformes_Anatidae_Netta_peposaca',
#  '03263_Animalia_Chordata_Aves_Anseriformes_Anatidae_Netta_rufina',
#  '03264_Animalia_Chordata_Aves_Anseriformes_Anatidae_Oxyura_jamaicensis',
#  '03265_Animalia_Chordata_Aves_Anseriformes_Anatidae_Plectropterus_gambensis',
#  '03266_Animalia_Chordata_Aves_Anseriformes_Anatidae_Sarkidiornis_melanotos',
#  '03267_Animalia_Chordata_Aves_Anseriformes_Anatidae_Somateria_mollissima',
#  '03268_Animalia_Chordata_Aves_Anseriformes_Anatidae_Spatula_clypeata',
#  '03269_Animalia_Chordata_Aves_Anseriformes_Anatidae_Spatula_cyanoptera',
#  '03270_Animalia_Chordata_Aves_Anseriformes_Anatidae_Spatula_discors',
#  '03271_Animalia_Chordata_Aves_Anseriformes_Anatidae_Spatula_querquedula',
#  '03272_Animalia_Chordata_Aves_Anseriformes_Anatidae_Spatula_rhynchotis',
#  '03273_Animalia_Chordata_Aves_Anseriformes_Anatidae_Tadorna_ferruginea',
#  '03274_Animalia_Chordata_Aves_Anseriformes_Anatidae_Tadorna_tadorna',
#  '03275_Animalia_Chordata_Aves_Anseriformes_Anatidae_Tadorna_tadornoides',
#  '03276_Animalia_Chordata_Aves_Anseriformes_Anatidae_Tadorna_variegata',
#  '03277_Animalia_Chordata_Aves_Anseriformes_Anhimidae_Chauna_torquata',
#  '03278_Animalia_Chordata_Aves_Anseriformes_Anseranatidae_Anseranas_semipalmata',
#  '03279_Animalia_Chordata_Aves_Bucerotiformes_Bucerotidae_Anthracoceros_albirostris',
#  '03280_Animalia_Chordata_Aves_Bucerotiformes_Bucerotidae_Lophoceros_alboterminatus',
#  '03281_Animalia_Chordata_Aves_Bucerotiformes_Bucerotidae_Lophoceros_nasutus',
#  '03282_Animalia_Chordata_Aves_Bucerotiformes_Bucerotidae_Tockus_leucomelas',
#  '03283_Animalia_Chordata_Aves_Bucerotiformes_Bucorvidae_Bucorvus_leadbeateri',
#  '03284_Animalia_Chordata_Aves_Bucerotiformes_Phoeniculidae_Phoeniculus_purpureus',
#  '03285_Animalia_Chordata_Aves_Bucerotiformes_Upupidae_Upupa_epops',
#  '03286_Animalia_Chordata_Aves_Caprimulgiformes_Apodidae_Aeronautes_saxatalis',
#  '03287_Animalia_Chordata_Aves_Caprimulgiformes_Apodidae_Apus_apus',
#  '03288_Animalia_Chordata_Aves_Caprimulgiformes_Apodidae_Chaetura_pelagica',
#  '03289_Animalia_Chordata_Aves_Caprimulgiformes_Apodidae_Chaetura_vauxi',
#  '03290_Animalia_Chordata_Aves_Caprimulgiformes_Caprimulgidae_Caprimulgus_europaeus',
#  '03291_Animalia_Chordata_Aves_Caprimulgiformes_Caprimulgidae_Chordeiles_acutipennis',
#  '03292_Animalia_Chordata_Aves_Caprimulgiformes_Caprimulgidae_Chordeiles_minor',
#  '03293_Animalia_Chordata_Aves_Caprimulgiformes_Caprimulgidae_Nyctidromus_albicollis',
#  '03294_Animalia_Chordata_Aves_Caprimulgiformes_Caprimulgidae_Phalaenoptilus_nuttallii',
#  '03295_Animalia_Chordata_Aves_Caprimulgiformes_Nyctibiidae_Nyctibius_griseus',
#  '03296_Animalia_Chordata_Aves_Caprimulgiformes_Nyctibiidae_Nyctibius_jamaicensis',
#  '03297_Animalia_Chordata_Aves_Caprimulgiformes_Podargidae_Podargus_strigoides',
#  '03298_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Amazilia_beryllina',
#  '03299_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Amazilia_cyanocephala',
#  '03300_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Amazilia_rutila',
#  '03301_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Amazilia_tzacatl',
#  '03302_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Amazilia_violiceps',
#  '03303_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Amazilia_yucatanensis',
#  '03304_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Anthracothorax_nigricollis',
#  '03305_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Anthracothorax_prevostii',
#  '03306_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Archilochus_alexandri',
#  '03307_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Archilochus_colubris',
#  '03308_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Boissonneaua_flavescens',
#  '03309_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Calothorax_lucifer',
#  '03310_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Calypte_anna',
#  '03311_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Calypte_costae',
#  '03312_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Campylopterus_hemileucurus',
#  '03313_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Chlorostilbon_canivetii',
#  '03314_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Chlorostilbon_lucidus',
#  '03315_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Colibri_coruscans',
#  '03316_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Colibri_cyanotus',
#  '03317_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Cynanthus_latirostris',
#  '03318_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Eugenes_fulgens',
#  '03319_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Eupetomena_macroura',
#  '03320_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Florisuga_mellivora',
#  '03321_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Heliodoxa_jacula',
#  '03322_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Hylocharis_leucotis',
#  '03323_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Lampornis_clemenciae',
#  '03324_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Ocreatus_underwoodii',
#  '03325_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Selasphorus_calliope',
#  '03326_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Selasphorus_platycercus',
#  '03327_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Selasphorus_rufus',
#  '03328_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Selasphorus_sasin',
#  '03329_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Thalurania_colombica',
#  '03330_Animalia_Chordata_Aves_Casuariiformes_Casuariidae_Dromaius_novaehollandiae',
#  '03331_Animalia_Chordata_Aves_Cathartiformes_Cathartidae_Cathartes_aura',
#  '03332_Animalia_Chordata_Aves_Cathartiformes_Cathartidae_Cathartes_burrovianus',
#  '03333_Animalia_Chordata_Aves_Cathartiformes_Cathartidae_Coragyps_atratus',
#  '03334_Animalia_Chordata_Aves_Cathartiformes_Cathartidae_Gymnogyps_californianus',
#  '03335_Animalia_Chordata_Aves_Cathartiformes_Cathartidae_Sarcoramphus_papa',
#  '03336_Animalia_Chordata_Aves_Cathartiformes_Cathartidae_Vultur_gryphus',
#  '03337_Animalia_Chordata_Aves_Charadriiformes_Alcidae_Alca_torda',
#  '03338_Animalia_Chordata_Aves_Charadriiformes_Alcidae_Brachyramphus_marmoratus',
#  '03339_Animalia_Chordata_Aves_Charadriiformes_Alcidae_Cepphus_columba',
#  '03340_Animalia_Chordata_Aves_Charadriiformes_Alcidae_Cepphus_grylle',
#  '03341_Animalia_Chordata_Aves_Charadriiformes_Alcidae_Cerorhinca_monocerata',
#  '03342_Animalia_Chordata_Aves_Charadriiformes_Alcidae_Fratercula_arctica',
#  '03343_Animalia_Chordata_Aves_Charadriiformes_Alcidae_Uria_aalge',
#  '03344_Animalia_Chordata_Aves_Charadriiformes_Burhinidae_Burhinus_bistriatus',
#  '03345_Animalia_Chordata_Aves_Charadriiformes_Burhinidae_Burhinus_capensis',
#  '03346_Animalia_Chordata_Aves_Charadriiformes_Burhinidae_Burhinus_grallarius',
#  '03347_Animalia_Chordata_Aves_Charadriiformes_Burhinidae_Burhinus_vermiculatus',
#  '03348_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_alexandrinus',
#  '03349_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_bicinctus',
#  '03350_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_collaris',
#  '03351_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_dubius',
#  '03352_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_hiaticula',
#  '03353_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_leschenaultii',
#  '03354_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_marginatus',
#  '03355_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_melodus',
#  '03356_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_mongolus',
#  '03357_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_nivosus',
#  '03358_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_obscurus',
#  '03359_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_pecuarius',
#  '03360_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_ruficapillus',
#  '03361_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_semipalmatus',
#  '03362_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_tricollaris',
#  '03363_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_vociferus',
#  '03364_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_wilsonia',
#  '03365_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Elseyornis_melanops',
#  '03366_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Pluvialis_apricaria',
#  '03367_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Pluvialis_dominica',
#  '03368_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Pluvialis_fulva',
#  '03369_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Pluvialis_squatarola',
#  '03370_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_armatus',
#  '03371_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_chilensis',
#  '03372_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_coronatus',
#  '03373_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_indicus',
#  '03374_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_miles',
#  '03375_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_senegallus',
#  '03376_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_spinosus',
#  '03377_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_vanellus',
#  '03378_Animalia_Chordata_Aves_Charadriiformes_Glareolidae_Glareola_pratincola',
#  '03379_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_bachmani',
#  '03380_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_finschi',
#  '03381_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_fuliginosus',
#  '03382_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_longirostris',
#  '03383_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_moquini',
#  '03384_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_ostralegus',
#  '03385_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_palliatus',
#  '03386_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_unicolor',
#  '03387_Animalia_Chordata_Aves_Charadriiformes_Jacanidae_Actophilornis_africanus',
#  '03388_Animalia_Chordata_Aves_Charadriiformes_Jacanidae_Hydrophasianus_chirurgus',
#  '03389_Animalia_Chordata_Aves_Charadriiformes_Jacanidae_Irediparra_gallinacea',
#  '03390_Animalia_Chordata_Aves_Charadriiformes_Jacanidae_Jacana_jacana',
#  '03391_Animalia_Chordata_Aves_Charadriiformes_Jacanidae_Jacana_spinosa',
#  '03392_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chlidonias_hybrida',
#  '03393_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chlidonias_leucopterus',
#  '03394_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chlidonias_niger',
#  '03395_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_bulleri',
#  '03396_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_cirrocephalus',
#  '03397_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_genei',
#  '03398_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_hartlaubii',
#  '03399_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_maculipennis',
#  '03400_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_novaehollandiae',
#  '03401_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_philadelphia',
#  '03402_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_ridibundus',
#  '03403_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_serranus',
#  '03404_Animalia_Chordata_Aves_Charadriiformes_Laridae_Gelochelidon_nilotica',
#  '03405_Animalia_Chordata_Aves_Charadriiformes_Laridae_Hydrocoloeus_minutus',
#  '03406_Animalia_Chordata_Aves_Charadriiformes_Laridae_Hydroprogne_caspia',
#  '03407_Animalia_Chordata_Aves_Charadriiformes_Laridae_Ichthyaetus_ichthyaetus',
#  '03408_Animalia_Chordata_Aves_Charadriiformes_Laridae_Ichthyaetus_melanocephalus',
#  '03409_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_argentatus',
#  '03410_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_cachinnans',
#  '03411_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_californicus',
#  '03412_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_canus',
#  '03413_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_crassirostris',
#  '03414_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_delawarensis',
#  '03415_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_dominicanus',
#  '03416_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_fuscus',
#  '03417_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_glaucescens',
#  '03418_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_glaucoides',
#  '03419_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_heermanni',
#  '03420_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_hyperboreus',
#  '03421_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_livens',
#  '03422_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_marinus',
#  '03423_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_michahellis',
#  '03424_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_occidentalis',
#  '03425_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_pacificus',
#  '03426_Animalia_Chordata_Aves_Charadriiformes_Laridae_Leucophaeus_atricilla',
#  '03427_Animalia_Chordata_Aves_Charadriiformes_Laridae_Leucophaeus_pipixcan',
#  '03428_Animalia_Chordata_Aves_Charadriiformes_Laridae_Phaetusa_simplex',
#  '03429_Animalia_Chordata_Aves_Charadriiformes_Laridae_Rissa_tridactyla',
#  '03430_Animalia_Chordata_Aves_Charadriiformes_Laridae_Rynchops_niger',
#  '03431_Animalia_Chordata_Aves_Charadriiformes_Laridae_Sterna_forsteri',
#  '03432_Animalia_Chordata_Aves_Charadriiformes_Laridae_Sterna_hirundo',
#  '03433_Animalia_Chordata_Aves_Charadriiformes_Laridae_Sterna_paradisaea',
#  '03434_Animalia_Chordata_Aves_Charadriiformes_Laridae_Sterna_striata',
#  '03435_Animalia_Chordata_Aves_Charadriiformes_Laridae_Sternula_albifrons',
#  '03436_Animalia_Chordata_Aves_Charadriiformes_Laridae_Sternula_antillarum',
#  '03437_Animalia_Chordata_Aves_Charadriiformes_Laridae_Thalasseus_bergii',
#  '03438_Animalia_Chordata_Aves_Charadriiformes_Laridae_Thalasseus_elegans',
#  '03439_Animalia_Chordata_Aves_Charadriiformes_Laridae_Thalasseus_maximus',
#  '03440_Animalia_Chordata_Aves_Charadriiformes_Laridae_Thalasseus_sandvicensis',
#  '03441_Animalia_Chordata_Aves_Charadriiformes_Recurvirostridae_Himantopus_himantopus',
#  '03442_Animalia_Chordata_Aves_Charadriiformes_Recurvirostridae_Himantopus_leucocephalus',
#  '03443_Animalia_Chordata_Aves_Charadriiformes_Recurvirostridae_Himantopus_mexicanus',
#  '03444_Animalia_Chordata_Aves_Charadriiformes_Recurvirostridae_Recurvirostra_americana',
#  '03445_Animalia_Chordata_Aves_Charadriiformes_Recurvirostridae_Recurvirostra_avosetta',
#  '03446_Animalia_Chordata_Aves_Charadriiformes_Rostratulidae_Rostratula_benghalensis',
#  '03447_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Actitis_hypoleucos',
#  '03448_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Actitis_macularius',
#  '03449_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Arenaria_interpres',
#  '03450_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Arenaria_melanocephala',
#  '03451_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Bartramia_longicauda',
#  '03452_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_acuminata',
#  '03453_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_alba',
#  '03454_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_alpina',
#  '03455_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_bairdii',
#  '03456_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_canutus',
#  '03457_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_ferruginea',
#  '03458_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_fuscicollis',
#  '03459_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_himantopus',
#  '03460_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_maritima',
#  '03461_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_mauri',
#  '03462_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_melanotos',
#  '03463_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_minuta',
#  '03464_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_minutilla',
#  '03465_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_pugnax',
#  '03466_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_pusilla',
#  '03467_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_ruficollis',
#  '03468_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_subruficollis',
#  '03469_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_temminckii',
#  '03470_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_virgata',
#  '03471_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Gallinago_delicata',
#  '03472_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Gallinago_gallinago',
#  '03473_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Limnodromus_griseus',
#  '03474_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Limnodromus_scolopaceus',
#  '03475_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Limosa_fedoa',
#  '03476_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Limosa_haemastica',
#  '03477_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Limosa_lapponica',
#  '03478_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Limosa_limosa',
#  '03479_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Numenius_americanus',
#  '03480_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Numenius_arquata',
#  '03481_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Numenius_madagascariensis',
#  '03482_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Numenius_phaeopus',
#  '03483_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Phalaropus_fulicarius',
#  '03484_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Phalaropus_lobatus',
#  '03485_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Phalaropus_tricolor',
#  '03486_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Scolopax_minor',
#  '03487_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_brevipes',
#  '03488_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_erythropus',
#  '03489_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_flavipes',
#  '03490_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_glareola',
#  '03491_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_incana',
#  '03492_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_melanoleuca',
#  '03493_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_nebularia',
#  '03494_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_ochropus',
#  '03495_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_semipalmata',
#  '03496_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_solitaria',
#  '03497_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_stagnatilis',
#  '03498_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_totanus',
#  '03499_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Xenus_cinereus',
#  '03500_Animalia_Chordata_Aves_Charadriiformes_Stercorariidae_Stercorarius_parasiticus',
#  '03501_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Anastomus_oscitans',
#  '03502_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Ciconia_ciconia',
#  '03503_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Ciconia_episcopus',
#  '03504_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Ciconia_maguari',
#  '03505_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Ciconia_nigra',
#  '03506_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Jabiru_mycteria',
#  '03507_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Leptoptilos_crumenifer',
#  '03508_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Mycteria_americana',
#  '03509_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Mycteria_ibis',
#  '03510_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Mycteria_leucocephala',
#  '03511_Animalia_Chordata_Aves_Coliiformes_Coliidae_Colius_striatus',
#  '03512_Animalia_Chordata_Aves_Columbiformes_Columbidae_Chalcophaps_indica',
#  '03513_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columba_guinea',
#  '03514_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columba_livia',
#  '03515_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columba_oenas',
#  '03516_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columba_palumbus',
#  '03517_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columbina_inca',
#  '03518_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columbina_passerina',
#  '03519_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columbina_picui',
#  '03520_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columbina_talpacoti',
#  '03521_Animalia_Chordata_Aves_Columbiformes_Columbidae_Geopelia_humeralis',
#  '03522_Animalia_Chordata_Aves_Columbiformes_Columbidae_Geopelia_placida',
#  '03523_Animalia_Chordata_Aves_Columbiformes_Columbidae_Geopelia_striata',
#  '03524_Animalia_Chordata_Aves_Columbiformes_Columbidae_Hemiphaga_novaeseelandiae',
#  '03525_Animalia_Chordata_Aves_Columbiformes_Columbidae_Leptotila_verreauxi',
#  '03526_Animalia_Chordata_Aves_Columbiformes_Columbidae_Ocyphaps_lophotes',
#  '03527_Animalia_Chordata_Aves_Columbiformes_Columbidae_Patagioenas_cayennensis',
#  '03528_Animalia_Chordata_Aves_Columbiformes_Columbidae_Patagioenas_fasciata',
#  '03529_Animalia_Chordata_Aves_Columbiformes_Columbidae_Patagioenas_flavirostris',
#  '03530_Animalia_Chordata_Aves_Columbiformes_Columbidae_Patagioenas_leucocephala',
#  '03531_Animalia_Chordata_Aves_Columbiformes_Columbidae_Patagioenas_maculosa',
#  '03532_Animalia_Chordata_Aves_Columbiformes_Columbidae_Patagioenas_picazuro',
#  '03533_Animalia_Chordata_Aves_Columbiformes_Columbidae_Phaps_chalcoptera',
#  '03534_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_capicola',
#  '03535_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_chinensis',
#  '03536_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_decaocto',
#  '03537_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_orientalis',
#  '03538_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_semitorquata',
#  '03539_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_senegalensis',
#  '03540_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_tranquebarica',
#  '03541_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_turtur',
#  '03542_Animalia_Chordata_Aves_Columbiformes_Columbidae_Treron_calvus',
#  '03543_Animalia_Chordata_Aves_Columbiformes_Columbidae_Treron_vernans',
#  '03544_Animalia_Chordata_Aves_Columbiformes_Columbidae_Zenaida_asiatica',
#  '03545_Animalia_Chordata_Aves_Columbiformes_Columbidae_Zenaida_auriculata',
#  '03546_Animalia_Chordata_Aves_Columbiformes_Columbidae_Zenaida_aurita',
#  '03547_Animalia_Chordata_Aves_Columbiformes_Columbidae_Zenaida_macroura',
#  '03548_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Alcedo_atthis',
#  '03549_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Ceryle_rudis',
#  '03550_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Chloroceryle_amazona',
#  '03551_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Chloroceryle_americana',
#  '03552_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Corythornis_cristatus',
#  '03553_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Dacelo_novaeguineae',
#  '03554_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Halcyon_albiventris',
#  '03555_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Halcyon_senegalensis',
#  '03556_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Halcyon_smyrnensis',
#  '03557_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Megaceryle_alcyon',
#  '03558_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Megaceryle_maxima',
#  '03559_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Megaceryle_torquata',
#  '03560_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Pelargopsis_capensis',
#  '03561_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Todiramphus_chloris',
#  '03562_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Todiramphus_macleayii',
#  '03563_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Todiramphus_sanctus',
#  '03564_Animalia_Chordata_Aves_Coraciiformes_Coraciidae_Coracias_benghalensis',
#  '03565_Animalia_Chordata_Aves_Coraciiformes_Coraciidae_Coracias_caudatus',
#  '03566_Animalia_Chordata_Aves_Coraciiformes_Coraciidae_Coracias_garrulus',
#  '03567_Animalia_Chordata_Aves_Coraciiformes_Coraciidae_Eurystomus_orientalis',
#  '03568_Animalia_Chordata_Aves_Coraciiformes_Meropidae_Merops_apiaster',
#  '03569_Animalia_Chordata_Aves_Coraciiformes_Meropidae_Merops_bullockoides',
#  '03570_Animalia_Chordata_Aves_Coraciiformes_Meropidae_Merops_orientalis',
#  '03571_Animalia_Chordata_Aves_Coraciiformes_Meropidae_Merops_ornatus',
#  '03572_Animalia_Chordata_Aves_Coraciiformes_Meropidae_Merops_persicus',
#  '03573_Animalia_Chordata_Aves_Coraciiformes_Meropidae_Merops_philippinus',
#  '03574_Animalia_Chordata_Aves_Coraciiformes_Meropidae_Merops_pusillus',
#  '03575_Animalia_Chordata_Aves_Coraciiformes_Momotidae_Eumomota_superciliosa',
#  '03576_Animalia_Chordata_Aves_Coraciiformes_Momotidae_Momotus_aequatorialis',
#  '03577_Animalia_Chordata_Aves_Coraciiformes_Momotidae_Momotus_lessonii',
#  '03578_Animalia_Chordata_Aves_Coraciiformes_Momotidae_Momotus_mexicanus',
#  '03579_Animalia_Chordata_Aves_Cuculiformes_Cuculidae_Cacomantis_flabelliformis',
#  '03580_Animalia_Chordata_Aves_Cuculiformes_Cuculidae_Centropus_sinensis',
#  '03581_Animalia_Chordata_Aves_Cuculiformes_Cuculidae_Centropus_superciliosus',
#  '03582_Animalia_Chordata_Aves_Cuculiformes_Cuculidae_Coccyzus_americanus',
#  '03583_Animalia_Chordata_Aves_Cuculiformes_Cuculidae_Coccyzus_erythropthalmus',
#  '03584_Animalia_Chordata_Aves_Cuculiformes_Cuculidae_Crotophaga_ani',
#  '03585_Animalia_Chordata_Aves_Cuculiformes_Cuculidae_Crotophaga_major',
#  '03586_Animalia_Chordata_Aves_Cuculiformes_Cuculidae_Crotophaga_sulcirostris',
#  '03587_Animalia_Chordata_Aves_Cuculiformes_Cuculidae_Cuculus_canorus',
#  '03588_Animalia_Chordata_Aves_Cuculiformes_Cuculidae_Eudynamys_scolopaceus',
#  '03589_Animalia_Chordata_Aves_Cuculiformes_Cuculidae_Geococcyx_californianus',
#  '03590_Animalia_Chordata_Aves_Cuculiformes_Cuculidae_Guira_guira',
#  '03591_Animalia_Chordata_Aves_Cuculiformes_Cuculidae_Piaya_cayana',
#  '03592_Animalia_Chordata_Aves_Falconiformes_Falconidae_Caracara_cheriway',
#  '03593_Animalia_Chordata_Aves_Falconiformes_Falconidae_Caracara_plancus',
#  '03594_Animalia_Chordata_Aves_Falconiformes_Falconidae_Falco_berigora',
#  '03595_Animalia_Chordata_Aves_Falconiformes_Falconidae_Falco_cenchroides',
#  '03596_Animalia_Chordata_Aves_Falconiformes_Falconidae_Falco_columbarius',
#  '03597_Animalia_Chordata_Aves_Falconiformes_Falconidae_Falco_femoralis',
#  '03598_Animalia_Chordata_Aves_Falconiformes_Falconidae_Falco_mexicanus',
#  '03599_Animalia_Chordata_Aves_Falconiformes_Falconidae_Falco_naumanni',
#  '03600_Animalia_Chordata_Aves_Falconiformes_Falconidae_Falco_novaeseelandiae',
#  '03601_Animalia_Chordata_Aves_Falconiformes_Falconidae_Falco_peregrinus',
#  '03602_Animalia_Chordata_Aves_Falconiformes_Falconidae_Falco_rufigularis',
#  '03603_Animalia_Chordata_Aves_Falconiformes_Falconidae_Falco_rupicolus',
#  '03604_Animalia_Chordata_Aves_Falconiformes_Falconidae_Falco_sparverius',
#  '03605_Animalia_Chordata_Aves_Falconiformes_Falconidae_Falco_subbuteo',
#  '03606_Animalia_Chordata_Aves_Falconiformes_Falconidae_Falco_tinnunculus',
#  '03607_Animalia_Chordata_Aves_Falconiformes_Falconidae_Falco_vespertinus',
#  '03608_Animalia_Chordata_Aves_Falconiformes_Falconidae_Herpetotheres_cachinnans',
#  '03609_Animalia_Chordata_Aves_Falconiformes_Falconidae_Milvago_chimachima',
#  '03610_Animalia_Chordata_Aves_Falconiformes_Falconidae_Milvago_chimango',
#  '03611_Animalia_Chordata_Aves_Galbuliformes_Galbulidae_Galbula_ruficauda',
#  '03612_Animalia_Chordata_Aves_Galliformes_Cracidae_Crax_rubra',
#  '03613_Animalia_Chordata_Aves_Galliformes_Cracidae_Ortalis_cinereiceps',
#  '03614_Animalia_Chordata_Aves_Galliformes_Cracidae_Ortalis_poliocephala',
#  '03615_Animalia_Chordata_Aves_Galliformes_Cracidae_Ortalis_vetula',
#  '03616_Animalia_Chordata_Aves_Galliformes_Cracidae_Ortalis_wagleri',
#  '03617_Animalia_Chordata_Aves_Galliformes_Cracidae_Penelope_obscura',
#  '03618_Animalia_Chordata_Aves_Galliformes_Cracidae_Penelope_purpurascens',
#  '03619_Animalia_Chordata_Aves_Galliformes_Megapodiidae_Alectura_lathami',
#  '03620_Animalia_Chordata_Aves_Galliformes_Numididae_Numida_meleagris',
#  '03621_Animalia_Chordata_Aves_Galliformes_Odontophoridae_Callipepla_californica',
#  '03622_Animalia_Chordata_Aves_Galliformes_Odontophoridae_Callipepla_gambelii',
#  '03623_Animalia_Chordata_Aves_Galliformes_Odontophoridae_Callipepla_squamata',
#  '03624_Animalia_Chordata_Aves_Galliformes_Odontophoridae_Colinus_virginianus',
#  '03625_Animalia_Chordata_Aves_Galliformes_Phasianidae_Alectoris_chukar',
#  '03626_Animalia_Chordata_Aves_Galliformes_Phasianidae_Alectoris_rufa',
#  '03627_Animalia_Chordata_Aves_Galliformes_Phasianidae_Bonasa_umbellus',
#  '03628_Animalia_Chordata_Aves_Galliformes_Phasianidae_Dendragapus_fuliginosus',
#  '03629_Animalia_Chordata_Aves_Galliformes_Phasianidae_Dendragapus_obscurus',
#  '03630_Animalia_Chordata_Aves_Galliformes_Phasianidae_Falcipennis_canadensis',
#  '03631_Animalia_Chordata_Aves_Galliformes_Phasianidae_Francolinus_pondicerianus',
#  '03632_Animalia_Chordata_Aves_Galliformes_Phasianidae_Gallus_gallus',
#  '03633_Animalia_Chordata_Aves_Galliformes_Phasianidae_Lagopus_lagopus',
#  '03634_Animalia_Chordata_Aves_Galliformes_Phasianidae_Meleagris_gallopavo',
#  '03635_Animalia_Chordata_Aves_Galliformes_Phasianidae_Pavo_cristatus',
#  '03636_Animalia_Chordata_Aves_Galliformes_Phasianidae_Perdix_perdix',
#  '03637_Animalia_Chordata_Aves_Galliformes_Phasianidae_Phasianus_colchicus',
#  '03638_Animalia_Chordata_Aves_Galliformes_Phasianidae_Pternistis_capensis',
#  '03639_Animalia_Chordata_Aves_Galliformes_Phasianidae_Tetrao_tetrix',
#  '03640_Animalia_Chordata_Aves_Galliformes_Phasianidae_Tetrastes_bonasia',
#  '03641_Animalia_Chordata_Aves_Gaviiformes_Gaviidae_Gavia_arctica',
#  '03642_Animalia_Chordata_Aves_Gaviiformes_Gaviidae_Gavia_immer',
#  '03643_Animalia_Chordata_Aves_Gaviiformes_Gaviidae_Gavia_pacifica',
#  '03644_Animalia_Chordata_Aves_Gaviiformes_Gaviidae_Gavia_stellata',
#  '03645_Animalia_Chordata_Aves_Gruiformes_Aramidae_Aramus_guarauna',
#  '03646_Animalia_Chordata_Aves_Gruiformes_Gruidae_Anthropoides_paradiseus',
#  '03647_Animalia_Chordata_Aves_Gruiformes_Gruidae_Anthropoides_virgo',
#  '03648_Animalia_Chordata_Aves_Gruiformes_Gruidae_Antigone_canadensis',
#  '03649_Animalia_Chordata_Aves_Gruiformes_Gruidae_Antigone_rubicunda',
#  '03650_Animalia_Chordata_Aves_Gruiformes_Gruidae_Grus_americana',
#  '03651_Animalia_Chordata_Aves_Gruiformes_Gruidae_Grus_grus',
#  '03652_Animalia_Chordata_Aves_Gruiformes_Rallidae_Amaurornis_phoenicurus',
#  '03653_Animalia_Chordata_Aves_Gruiformes_Rallidae_Aramides_albiventris',
#  '03654_Animalia_Chordata_Aves_Gruiformes_Rallidae_Aramides_cajaneus',
#  '03655_Animalia_Chordata_Aves_Gruiformes_Rallidae_Fulica_americana',
#  '03656_Animalia_Chordata_Aves_Gruiformes_Rallidae_Fulica_ardesiaca',
#  '03657_Animalia_Chordata_Aves_Gruiformes_Rallidae_Fulica_armillata',
#  '03658_Animalia_Chordata_Aves_Gruiformes_Rallidae_Fulica_atra',
#  '03659_Animalia_Chordata_Aves_Gruiformes_Rallidae_Fulica_cristata',
#  '03660_Animalia_Chordata_Aves_Gruiformes_Rallidae_Gallinula_chloropus',
#  '03661_Animalia_Chordata_Aves_Gruiformes_Rallidae_Gallinula_galeata',
#  '03662_Animalia_Chordata_Aves_Gruiformes_Rallidae_Gallinula_tenebrosa',
#  '03663_Animalia_Chordata_Aves_Gruiformes_Rallidae_Gallirallus_australis',
#  '03664_Animalia_Chordata_Aves_Gruiformes_Rallidae_Gallirallus_philippensis',
#  '03665_Animalia_Chordata_Aves_Gruiformes_Rallidae_Porphyrio_martinica',
#  '03666_Animalia_Chordata_Aves_Gruiformes_Rallidae_Porphyrio_melanotus',
#  '03667_Animalia_Chordata_Aves_Gruiformes_Rallidae_Porphyrio_poliocephalus',
#  '03668_Animalia_Chordata_Aves_Gruiformes_Rallidae_Porzana_carolina',
#  '03669_Animalia_Chordata_Aves_Gruiformes_Rallidae_Rallus_aquaticus',
#  '03670_Animalia_Chordata_Aves_Gruiformes_Rallidae_Rallus_crepitans',
#  '03671_Animalia_Chordata_Aves_Gruiformes_Rallidae_Rallus_limicola',
#  '03672_Animalia_Chordata_Aves_Gruiformes_Rallidae_Rallus_obsoletus',
#  '03673_Animalia_Chordata_Aves_Gruiformes_Rallidae_Zapornia_flavirostra',
#  '03674_Animalia_Chordata_Aves_Musophagiformes_Musophagidae_Corythaixoides_concolor',
#  '03675_Animalia_Chordata_Aves_Opisthocomiformes_Opisthocomidae_Opisthocomus_hoazin',
#  '03676_Animalia_Chordata_Aves_Otidiformes_Otididae_Ardeotis_kori',
#  '03677_Animalia_Chordata_Aves_Passeriformes_Acanthisittidae_Acanthisitta_chloris',
#  '03678_Animalia_Chordata_Aves_Passeriformes_Acanthizidae_Acanthiza_chrysorrhoa',
#  '03679_Animalia_Chordata_Aves_Passeriformes_Acanthizidae_Acanthiza_pusilla',
#  '03680_Animalia_Chordata_Aves_Passeriformes_Acanthizidae_Gerygone_igata',
#  '03681_Animalia_Chordata_Aves_Passeriformes_Acanthizidae_Sericornis_frontalis',
#  '03682_Animalia_Chordata_Aves_Passeriformes_Acrocephalidae_Acrocephalus_arundinaceus',
#  '03683_Animalia_Chordata_Aves_Passeriformes_Acrocephalidae_Acrocephalus_australis',
#  '03684_Animalia_Chordata_Aves_Passeriformes_Acrocephalidae_Acrocephalus_dumetorum',
#  '03685_Animalia_Chordata_Aves_Passeriformes_Acrocephalidae_Acrocephalus_schoenobaenus',
#  '03686_Animalia_Chordata_Aves_Passeriformes_Acrocephalidae_Acrocephalus_scirpaceus',
#  '03687_Animalia_Chordata_Aves_Passeriformes_Acrocephalidae_Iduna_caligata',
#  '03688_Animalia_Chordata_Aves_Passeriformes_Aegithalidae_Aegithalos_caudatus',
#  '03689_Animalia_Chordata_Aves_Passeriformes_Aegithalidae_Psaltriparus_minimus',
#  '03690_Animalia_Chordata_Aves_Passeriformes_Aegithinidae_Aegithina_tiphia',
#  '03691_Animalia_Chordata_Aves_Passeriformes_Alaudidae_Alauda_arvensis',
#  '03692_Animalia_Chordata_Aves_Passeriformes_Alaudidae_Eremophila_alpestris',
#  '03693_Animalia_Chordata_Aves_Passeriformes_Alaudidae_Galerida_cristata',
#  '03694_Animalia_Chordata_Aves_Passeriformes_Alaudidae_Lullula_arborea',
#  '03695_Animalia_Chordata_Aves_Passeriformes_Artamidae_Artamus_cyanopterus',
#  '03696_Animalia_Chordata_Aves_Passeriformes_Artamidae_Artamus_leucorynchus',
#  '03697_Animalia_Chordata_Aves_Passeriformes_Artamidae_Cracticus_nigrogularis',
#  '03698_Animalia_Chordata_Aves_Passeriformes_Artamidae_Cracticus_torquatus',
#  '03699_Animalia_Chordata_Aves_Passeriformes_Artamidae_Gymnorhina_tibicen',
#  '03700_Animalia_Chordata_Aves_Passeriformes_Artamidae_Strepera_graculina',
#  '03701_Animalia_Chordata_Aves_Passeriformes_Bombycillidae_Bombycilla_cedrorum',
#  '03702_Animalia_Chordata_Aves_Passeriformes_Bombycillidae_Bombycilla_garrulus',
#  '03703_Animalia_Chordata_Aves_Passeriformes_Buphagidae_Buphagus_erythrorynchus',
#  '03704_Animalia_Chordata_Aves_Passeriformes_Calcariidae_Calcarius_lapponicus',
#  '03705_Animalia_Chordata_Aves_Passeriformes_Calcariidae_Plectrophenax_nivalis',
#  '03706_Animalia_Chordata_Aves_Passeriformes_Callaeidae_Philesturnus_rufusater',
#  '03707_Animalia_Chordata_Aves_Passeriformes_Campephagidae_Coracina_novaehollandiae',
#  '03708_Animalia_Chordata_Aves_Passeriformes_Campephagidae_Pericrocotus_speciosus',
#  '03709_Animalia_Chordata_Aves_Passeriformes_Cardinalidae_Cardinalis_cardinalis',
#  '03710_Animalia_Chordata_Aves_Passeriformes_Cardinalidae_Cardinalis_sinuatus',
#  '03711_Animalia_Chordata_Aves_Passeriformes_Cardinalidae_Cyanocompsa_parellina',
#  '03712_Animalia_Chordata_Aves_Passeriformes_Cardinalidae_Habia_fuscicauda',
#  '03713_Animalia_Chordata_Aves_Passeriformes_Cardinalidae_Passerina_amoena',
#  '03714_Animalia_Chordata_Aves_Passeriformes_Cardinalidae_Passerina_caerulea',
#  '03715_Animalia_Chordata_Aves_Passeriformes_Cardinalidae_Passerina_ciris',
#  '03716_Animalia_Chordata_Aves_Passeriformes_Cardinalidae_Passerina_cyanea',
#  '03717_Animalia_Chordata_Aves_Passeriformes_Cardinalidae_Passerina_leclancherii',
#  '03718_Animalia_Chordata_Aves_Passeriformes_Cardinalidae_Passerina_versicolor',
#  '03719_Animalia_Chordata_Aves_Passeriformes_Cardinalidae_Pheucticus_chrysopeplus',
#  '03720_Animalia_Chordata_Aves_Passeriformes_Cardinalidae_Pheucticus_ludovicianus',
#  '03721_Animalia_Chordata_Aves_Passeriformes_Cardinalidae_Pheucticus_melanocephalus',
#  '03722_Animalia_Chordata_Aves_Passeriformes_Cardinalidae_Piranga_bidentata',
#  '03723_Animalia_Chordata_Aves_Passeriformes_Cardinalidae_Piranga_flava',
#  '03724_Animalia_Chordata_Aves_Passeriformes_Cardinalidae_Piranga_ludoviciana',
#  '03725_Animalia_Chordata_Aves_Passeriformes_Cardinalidae_Piranga_olivacea',
#  '03726_Animalia_Chordata_Aves_Passeriformes_Cardinalidae_Piranga_rubra',
# ...
#  '03907_Animalia_Chordata_Aves_Passeriformes_Laniidae_Lanius_collaris',
#  '03908_Animalia_Chordata_Aves_Passeriformes_Laniidae_Lanius_collurio',
#  '03909_Animalia_Chordata_Aves_Passeriformes_Laniidae_Lanius_cristatus',
#  '03910_Animalia_Chordata_Aves_Passeriformes_Laniidae_Lanius_excubitor',
#  '03911_Animalia_Chordata_Aves_Passeriformes_Laniidae_Lanius_ludovicianus',
#  '03912_Animalia_Chordata_Aves_Passeriformes_Laniidae_Lanius_minor',
#  '03913_Animalia_Chordata_Aves_Passeriformes_Laniidae_Lanius_schach',
#  '03914_Animalia_Chordata_Aves_Passeriformes_Laniidae_Lanius_senator',
#  '03915_Animalia_Chordata_Aves_Passeriformes_Leiothrichidae_Garrulax_perspicillatus',
#  '03916_Animalia_Chordata_Aves_Passeriformes_Leiothrichidae_Turdoides_striata',
#  '03917_Animalia_Chordata_Aves_Passeriformes_Malaconotidae_Dryoscopus_cubla',
#  '03918_Animalia_Chordata_Aves_Passeriformes_Malaconotidae_Laniarius_ferrugineus',
#  '03919_Animalia_Chordata_Aves_Passeriformes_Malaconotidae_Telophorus_zeylonus',
#  '03920_Animalia_Chordata_Aves_Passeriformes_Maluridae_Malurus_cyaneus',
#  '03921_Animalia_Chordata_Aves_Passeriformes_Maluridae_Malurus_melanocephalus',
#  '03922_Animalia_Chordata_Aves_Passeriformes_Maluridae_Malurus_splendens',
#  '03923_Animalia_Chordata_Aves_Passeriformes_Meliphagidae_Acanthorhynchus_tenuirostris',
#  '03924_Animalia_Chordata_Aves_Passeriformes_Meliphagidae_Anthochaera_carunculata',
#  '03925_Animalia_Chordata_Aves_Passeriformes_Meliphagidae_Anthochaera_chrysoptera',
#  '03926_Animalia_Chordata_Aves_Passeriformes_Meliphagidae_Anthornis_melanura',
#  '03927_Animalia_Chordata_Aves_Passeriformes_Meliphagidae_Caligavis_chrysops',
#  '03928_Animalia_Chordata_Aves_Passeriformes_Meliphagidae_Entomyzon_cyanotis',
#  '03929_Animalia_Chordata_Aves_Passeriformes_Meliphagidae_Gavicalis_virescens',
#  '03930_Animalia_Chordata_Aves_Passeriformes_Meliphagidae_Lichmera_indistincta',
#  '03931_Animalia_Chordata_Aves_Passeriformes_Meliphagidae_Manorina_melanocephala',
#  '03932_Animalia_Chordata_Aves_Passeriformes_Meliphagidae_Meliphaga_lewinii',
#  '03933_Animalia_Chordata_Aves_Passeriformes_Meliphagidae_Myzomela_sanguinolenta',
#  '03934_Animalia_Chordata_Aves_Passeriformes_Meliphagidae_Philemon_corniculatus',
#  '03935_Animalia_Chordata_Aves_Passeriformes_Meliphagidae_Phylidonyris_niger',
#  '03936_Animalia_Chordata_Aves_Passeriformes_Meliphagidae_Phylidonyris_novaehollandiae',
#  '03937_Animalia_Chordata_Aves_Passeriformes_Meliphagidae_Prosthemadera_novaeseelandiae',
#  '03938_Animalia_Chordata_Aves_Passeriformes_Meliphagidae_Ptilotula_penicillata',
#  '03939_Animalia_Chordata_Aves_Passeriformes_Menuridae_Menura_novaehollandiae',
#  '03940_Animalia_Chordata_Aves_Passeriformes_Mimidae_Dumetella_carolinensis',
#  '03941_Animalia_Chordata_Aves_Passeriformes_Mimidae_Melanotis_caerulescens',
#  '03942_Animalia_Chordata_Aves_Passeriformes_Mimidae_Mimus_gilvus',
#  '03943_Animalia_Chordata_Aves_Passeriformes_Mimidae_Mimus_longicaudatus',
#  '03944_Animalia_Chordata_Aves_Passeriformes_Mimidae_Mimus_polyglottos',
#  '03945_Animalia_Chordata_Aves_Passeriformes_Mimidae_Mimus_saturninus',
#  '03946_Animalia_Chordata_Aves_Passeriformes_Mimidae_Oreoscoptes_montanus',
#  '03947_Animalia_Chordata_Aves_Passeriformes_Mimidae_Toxostoma_curvirostre',
#  '03948_Animalia_Chordata_Aves_Passeriformes_Mimidae_Toxostoma_longirostre',
#  '03949_Animalia_Chordata_Aves_Passeriformes_Mimidae_Toxostoma_redivivum',
#  '03950_Animalia_Chordata_Aves_Passeriformes_Mimidae_Toxostoma_rufum',
#  '03951_Animalia_Chordata_Aves_Passeriformes_Monarchidae_Grallina_cyanoleuca',
#  '03952_Animalia_Chordata_Aves_Passeriformes_Monarchidae_Hypothymis_azurea',
#  '03953_Animalia_Chordata_Aves_Passeriformes_Monarchidae_Terpsiphone_paradisi',
#  '03954_Animalia_Chordata_Aves_Passeriformes_Monarchidae_Terpsiphone_viridis',
#  '03955_Animalia_Chordata_Aves_Passeriformes_Motacillidae_Anthus_campestris',
#  '03956_Animalia_Chordata_Aves_Passeriformes_Motacillidae_Anthus_cervinus',
#  '03957_Animalia_Chordata_Aves_Passeriformes_Motacillidae_Anthus_cinnamomeus',
#  '03958_Animalia_Chordata_Aves_Passeriformes_Motacillidae_Anthus_hodgsoni',
#  '03959_Animalia_Chordata_Aves_Passeriformes_Motacillidae_Anthus_novaeseelandiae',
#  '03960_Animalia_Chordata_Aves_Passeriformes_Motacillidae_Anthus_petrosus',
#  '03961_Animalia_Chordata_Aves_Passeriformes_Motacillidae_Anthus_pratensis',
#  '03962_Animalia_Chordata_Aves_Passeriformes_Motacillidae_Anthus_rubescens',
#  '03963_Animalia_Chordata_Aves_Passeriformes_Motacillidae_Anthus_rufulus',
#  '03964_Animalia_Chordata_Aves_Passeriformes_Motacillidae_Anthus_spinoletta',
#  '03965_Animalia_Chordata_Aves_Passeriformes_Motacillidae_Anthus_trivialis',
#  '03966_Animalia_Chordata_Aves_Passeriformes_Motacillidae_Macronyx_croceus',
#  '03967_Animalia_Chordata_Aves_Passeriformes_Motacillidae_Motacilla_aguimp',
#  '03968_Animalia_Chordata_Aves_Passeriformes_Motacillidae_Motacilla_alba',
#  '03969_Animalia_Chordata_Aves_Passeriformes_Motacillidae_Motacilla_capensis',
#  '03970_Animalia_Chordata_Aves_Passeriformes_Motacillidae_Motacilla_cinerea',
#  '03971_Animalia_Chordata_Aves_Passeriformes_Motacillidae_Motacilla_citreola',
#  '03972_Animalia_Chordata_Aves_Passeriformes_Motacillidae_Motacilla_flava',
#  '03973_Animalia_Chordata_Aves_Passeriformes_Motacillidae_Motacilla_tschutschensis',
#  '03974_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Copsychus_fulicatus',
#  '03975_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Copsychus_malabaricus',
#  '03976_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Copsychus_saularis',
#  '03977_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Cossypha_caffra',
#  '03978_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Erithacus_rubecula',
#  '03979_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Eumyias_thalassinus',
#  '03980_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Ficedula_hypoleuca',
#  '03981_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Luscinia_luscinia',
#  '03982_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Luscinia_megarhynchos',
#  '03983_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Luscinia_svecica',
#  '03984_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Melaenornis_silens',
#  '03985_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Monticola_solitarius',
#  '03986_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Muscicapa_adusta',
#  '03987_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Muscicapa_dauurica',
#  '03988_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Muscicapa_striata',
#  '03989_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Myophonus_caeruleus',
#  '03990_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Oenanthe_familiaris',
#  '03991_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Oenanthe_oenanthe',
#  '03992_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Phoenicurus_auroreus',
#  '03993_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Phoenicurus_fuliginosus',
#  '03994_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Phoenicurus_ochruros',
#  '03995_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Phoenicurus_phoenicurus',
#  '03996_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Saxicola_caprata',
#  '03997_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Saxicola_maurus',
#  '03998_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Saxicola_rubetra',
#  '03999_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Saxicola_rubicola',
#  '04000_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Saxicola_torquatus',
#  '04001_Animalia_Chordata_Aves_Passeriformes_Muscicapidae_Tarsiger_cyanurus',
#  '04002_Animalia_Chordata_Aves_Passeriformes_Nectariniidae_Aethopyga_siparaja',
#  '04003_Animalia_Chordata_Aves_Passeriformes_Nectariniidae_Anthobaphes_violacea',
#  '04004_Animalia_Chordata_Aves_Passeriformes_Nectariniidae_Anthreptes_malacensis',
#  '04005_Animalia_Chordata_Aves_Passeriformes_Nectariniidae_Chalcomitra_amethystina',
#  '04006_Animalia_Chordata_Aves_Passeriformes_Nectariniidae_Chalcomitra_senegalensis',
#  '04007_Animalia_Chordata_Aves_Passeriformes_Nectariniidae_Cinnyris_afer',
#  '04008_Animalia_Chordata_Aves_Passeriformes_Nectariniidae_Cinnyris_asiaticus',
#  '04009_Animalia_Chordata_Aves_Passeriformes_Nectariniidae_Cinnyris_chalybeus',
#  '04010_Animalia_Chordata_Aves_Passeriformes_Nectariniidae_Cinnyris_jugularis',
#  '04011_Animalia_Chordata_Aves_Passeriformes_Nectariniidae_Hedydipna_collaris',
#  '04012_Animalia_Chordata_Aves_Passeriformes_Nectariniidae_Leptocoma_zeylonica',
#  '04013_Animalia_Chordata_Aves_Passeriformes_Nectariniidae_Nectarinia_famosa',
#  '04014_Animalia_Chordata_Aves_Passeriformes_Oriolidae_Oriolus_chinensis',
#  '04015_Animalia_Chordata_Aves_Passeriformes_Oriolidae_Oriolus_larvatus',
#  '04016_Animalia_Chordata_Aves_Passeriformes_Oriolidae_Oriolus_oriolus',
#  '04017_Animalia_Chordata_Aves_Passeriformes_Oriolidae_Oriolus_sagittatus',
#  '04018_Animalia_Chordata_Aves_Passeriformes_Oriolidae_Oriolus_xanthornus',
#  '04019_Animalia_Chordata_Aves_Passeriformes_Oriolidae_Sphecotheres_vieilloti',
#  '04020_Animalia_Chordata_Aves_Passeriformes_Pachycephalidae_Colluricincla_harmonica',
#  '04021_Animalia_Chordata_Aves_Passeriformes_Pachycephalidae_Pachycephala_pectoralis',
#  '04022_Animalia_Chordata_Aves_Passeriformes_Pachycephalidae_Pachycephala_rufiventris',
#  '04023_Animalia_Chordata_Aves_Passeriformes_Panuridae_Panurus_biarmicus',
#  '04024_Animalia_Chordata_Aves_Passeriformes_Pardalotidae_Pardalotus_punctatus',
#  '04025_Animalia_Chordata_Aves_Passeriformes_Pardalotidae_Pardalotus_striatus',
#  '04026_Animalia_Chordata_Aves_Passeriformes_Paridae_Baeolophus_atricristatus',
#  '04027_Animalia_Chordata_Aves_Passeriformes_Paridae_Baeolophus_bicolor',
#  '04028_Animalia_Chordata_Aves_Passeriformes_Paridae_Baeolophus_inornatus',
#  '04029_Animalia_Chordata_Aves_Passeriformes_Paridae_Baeolophus_ridgwayi',
#  '04030_Animalia_Chordata_Aves_Passeriformes_Paridae_Baeolophus_wollweberi',
#  '04031_Animalia_Chordata_Aves_Passeriformes_Paridae_Cyanistes_caeruleus',
#  '04032_Animalia_Chordata_Aves_Passeriformes_Paridae_Cyanistes_cyanus',
#  '04033_Animalia_Chordata_Aves_Passeriformes_Paridae_Lophophanes_cristatus',
#  '04034_Animalia_Chordata_Aves_Passeriformes_Paridae_Parus_major',
#  '04035_Animalia_Chordata_Aves_Passeriformes_Paridae_Parus_minor',
#  '04036_Animalia_Chordata_Aves_Passeriformes_Paridae_Periparus_ater',
#  '04037_Animalia_Chordata_Aves_Passeriformes_Paridae_Poecile_atricapillus',
#  '04038_Animalia_Chordata_Aves_Passeriformes_Paridae_Poecile_carolinensis',
#  '04039_Animalia_Chordata_Aves_Passeriformes_Paridae_Poecile_gambeli',
#  '04040_Animalia_Chordata_Aves_Passeriformes_Paridae_Poecile_hudsonicus',
#  '04041_Animalia_Chordata_Aves_Passeriformes_Paridae_Poecile_montanus',
#  '04042_Animalia_Chordata_Aves_Passeriformes_Paridae_Poecile_palustris',
#  '04043_Animalia_Chordata_Aves_Passeriformes_Paridae_Poecile_rufescens',
#  '04044_Animalia_Chordata_Aves_Passeriformes_Parulidae_Basileuterus_culicivorus',
#  '04045_Animalia_Chordata_Aves_Passeriformes_Parulidae_Basileuterus_rufifrons',
#  '04046_Animalia_Chordata_Aves_Passeriformes_Parulidae_Cardellina_canadensis',
#  '04047_Animalia_Chordata_Aves_Passeriformes_Parulidae_Cardellina_pusilla',
#  '04048_Animalia_Chordata_Aves_Passeriformes_Parulidae_Geothlypis_formosa',
#  '04049_Animalia_Chordata_Aves_Passeriformes_Parulidae_Geothlypis_philadelphia',
#  '04050_Animalia_Chordata_Aves_Passeriformes_Parulidae_Geothlypis_tolmiei',
#  '04051_Animalia_Chordata_Aves_Passeriformes_Parulidae_Geothlypis_trichas',
#  '04052_Animalia_Chordata_Aves_Passeriformes_Parulidae_Helmitheros_vermivorum',
#  '04053_Animalia_Chordata_Aves_Passeriformes_Parulidae_Leiothlypis_celata',
#  '04054_Animalia_Chordata_Aves_Passeriformes_Parulidae_Leiothlypis_luciae',
#  '04055_Animalia_Chordata_Aves_Passeriformes_Parulidae_Leiothlypis_peregrina',
#  '04056_Animalia_Chordata_Aves_Passeriformes_Parulidae_Leiothlypis_ruficapilla',
#  '04057_Animalia_Chordata_Aves_Passeriformes_Parulidae_Mniotilta_varia',
#  '04058_Animalia_Chordata_Aves_Passeriformes_Parulidae_Myioborus_miniatus',
#  '04059_Animalia_Chordata_Aves_Passeriformes_Parulidae_Myioborus_pictus',
#  '04060_Animalia_Chordata_Aves_Passeriformes_Parulidae_Oreothlypis_superciliosa',
#  '04061_Animalia_Chordata_Aves_Passeriformes_Parulidae_Parkesia_motacilla',
#  '04062_Animalia_Chordata_Aves_Passeriformes_Parulidae_Parkesia_noveboracensis',
#  '04063_Animalia_Chordata_Aves_Passeriformes_Parulidae_Protonotaria_citrea',
#  '04064_Animalia_Chordata_Aves_Passeriformes_Parulidae_Seiurus_aurocapilla',
#  '04065_Animalia_Chordata_Aves_Passeriformes_Parulidae_Setophaga_americana',
#  '04066_Animalia_Chordata_Aves_Passeriformes_Parulidae_Setophaga_caerulescens',
#  '04067_Animalia_Chordata_Aves_Passeriformes_Parulidae_Setophaga_castanea',
#  '04068_Animalia_Chordata_Aves_Passeriformes_Parulidae_Setophaga_cerulea',
#  '04069_Animalia_Chordata_Aves_Passeriformes_Parulidae_Setophaga_chrysoparia',
#  '04070_Animalia_Chordata_Aves_Passeriformes_Parulidae_Setophaga_citrina',
#  '04071_Animalia_Chordata_Aves_Passeriformes_Parulidae_Setophaga_coronata',
#  '04072_Animalia_Chordata_Aves_Passeriformes_Parulidae_Setophaga_discolor',
#  '04073_Animalia_Chordata_Aves_Passeriformes_Parulidae_Setophaga_dominica',
#  '04074_Animalia_Chordata_Aves_Passeriformes_Parulidae_Setophaga_fusca',
#  '04075_Animalia_Chordata_Aves_Passeriformes_Parulidae_Setophaga_graciae',
#  '04076_Animalia_Chordata_Aves_Passeriformes_Parulidae_Setophaga_magnolia',
#  '04077_Animalia_Chordata_Aves_Passeriformes_Parulidae_Setophaga_nigrescens',
#  '04078_Animalia_Chordata_Aves_Passeriformes_Parulidae_Setophaga_occidentalis',
#  '04079_Animalia_Chordata_Aves_Passeriformes_Parulidae_Setophaga_palmarum',
#  '04080_Animalia_Chordata_Aves_Passeriformes_Parulidae_Setophaga_pensylvanica',
#  '04081_Animalia_Chordata_Aves_Passeriformes_Parulidae_Setophaga_petechia',
#  '04082_Animalia_Chordata_Aves_Passeriformes_Parulidae_Setophaga_pinus',
#  '04083_Animalia_Chordata_Aves_Passeriformes_Parulidae_Setophaga_pitiayumi',
#  '04084_Animalia_Chordata_Aves_Passeriformes_Parulidae_Setophaga_ruticilla',
#  '04085_Animalia_Chordata_Aves_Passeriformes_Parulidae_Setophaga_striata',
#  '04086_Animalia_Chordata_Aves_Passeriformes_Parulidae_Setophaga_tigrina',
#  '04087_Animalia_Chordata_Aves_Passeriformes_Parulidae_Setophaga_townsendi',
#  '04088_Animalia_Chordata_Aves_Passeriformes_Parulidae_Setophaga_virens',
#  '04089_Animalia_Chordata_Aves_Passeriformes_Parulidae_Vermivora_chrysoptera',
#  '04090_Animalia_Chordata_Aves_Passeriformes_Parulidae_Vermivora_cyanoptera',
#  '04091_Animalia_Chordata_Aves_Passeriformes_Passerellidae_Aimophila_ruficeps',
#  '04092_Animalia_Chordata_Aves_Passeriformes_Passerellidae_Ammodramus_savannarum',
#  '04093_Animalia_Chordata_Aves_Passeriformes_Passerellidae_Ammospiza_leconteii',
#  '04094_Animalia_Chordata_Aves_Passeriformes_Passerellidae_Ammospiza_nelsoni',
#  '04095_Animalia_Chordata_Aves_Passeriformes_Passerellidae_Amphispiza_bilineata',
#  '04096_Animalia_Chordata_Aves_Passeriformes_Passerellidae_Arremonops_rufivirgatus',
#  '04097_Animalia_Chordata_Aves_Passeriformes_Passerellidae_Artemisiospiza_belli',
#  '04098_Animalia_Chordata_Aves_Passeriformes_Passerellidae_Artemisiospiza_nevadensis',
#  '04099_Animalia_Chordata_Aves_Passeriformes_Passerellidae_Calamospiza_melanocorys',
#  '04100_Animalia_Chordata_Aves_Passeriformes_Passerellidae_Centronyx_henslowii',
#  '04101_Animalia_Chordata_Aves_Passeriformes_Passerellidae_Chlorospingus_flavopectus',
#  '04102_Animalia_Chordata_Aves_Passeriformes_Passerellidae_Chondestes_grammacus',
#  '04103_Animalia_Chordata_Aves_Passeriformes_Passerellidae_Junco_hyemalis',
#  '04104_Animalia_Chordata_Aves_Passeriformes_Passerellidae_Junco_phaeonotus',
#  '04105_Animalia_Chordata_Aves_Passeriformes_Passerellidae_Melospiza_georgiana',
#  '04106_Animalia_Chordata_Aves_Passeriformes_Passerellidae_Melospiza_lincolnii',
#  '04107_Animalia_Chordata_Aves_Passeriformes_Passerellidae_Melospiza_melodia',
#  '04108_Animalia_Chordata_Aves_Passeriformes_Passerellidae_Melozone_aberti',
#  '04109_Animalia_Chordata_Aves_Passeriformes_Passerellidae_Melozone_crissalis',
#  '04110_Animalia_Chordata_Aves_Passeriformes_Passerellidae_Melozone_fusca',
#  ...]

# %%
# prepare to count predictions for each class
correct_pred = {classname: 0 for classname in bird_classes}
total_pred = {classname: 0 for classname in bird_classes}

# again no gradients needed
with torch.no_grad():
    for data in test_loader_birds:
        images, contextual_data, labels = data
        images, contextual_data, labels = images.to(device), contextual_data.to(device), labels.to(device)
        labels = remap_labels(labels).to(device)
        outputs = trained_model(images, contextual_data)
        _, predictions = torch.max(outputs, 1)
        # collect the correct predictions for each class
        for label, prediction in zip(labels, predictions):
            if label == prediction:
                correct_pred[bird_classes[label]] += 1
            total_pred[bird_classes[label]] += 1
# turn into dataframe and sort by smallest success classes
# then create confusion matrix for all classes - find the biggest misses


# print accuracy for each class
for classname, correct_count in correct_pred.items():
    accuracy = 100 * float(correct_count) / total_pred[classname]
    print(f'Accuracy for class: {classname:5s} is {accuracy:.1f} %')
# Out:
# Accuracy for class: 03111_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_badius is 50.0 %
# Accuracy for class: 03112_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_cooperii is 10.0 %
# Accuracy for class: 03113_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_gentilis is 0.0 %
# Accuracy for class: 03114_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_nisus is 40.0 %
# Accuracy for class: 03115_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_striatus is 10.0 %
# Accuracy for class: 03116_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_trivirgatus is 60.0 %
# Accuracy for class: 03117_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aegypius_monachus is 40.0 %
# Accuracy for class: 03118_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_audax is 30.0 %
# Accuracy for class: 03119_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_chrysaetos is 0.0 %
# Accuracy for class: 03120_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_heliaca is 0.0 %
# Accuracy for class: 03121_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_nipalensis is 40.0 %
# Accuracy for class: 03122_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Aquila_rapax is 50.0 %
# Accuracy for class: 03123_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Busarellus_nigricollis is 80.0 %
# Accuracy for class: 03124_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_albonotatus is 70.0 %
# Accuracy for class: 03125_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_brachyurus is 20.0 %
# Accuracy for class: 03126_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_buteo is 10.0 %
# Accuracy for class: 03127_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_jamaicensis is 40.0 %
# Accuracy for class: 03128_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_lagopus is 20.0 %
# Accuracy for class: 03129_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_lineatus is 20.0 %
# Accuracy for class: 03130_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_plagiatus is 60.0 %
# Accuracy for class: 03131_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_platypterus is 40.0 %
# Accuracy for class: 03132_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_regalis is 50.0 %
# Accuracy for class: 03133_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_rufinus is 20.0 %
# Accuracy for class: 03134_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_rufofuscus is 30.0 %
# Accuracy for class: 03135_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteo_swainsoni is 10.0 %
# Accuracy for class: 03136_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteogallus_anthracinus is 40.0 %
# Accuracy for class: 03137_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteogallus_meridionalis is 80.0 %
# Accuracy for class: 03138_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Buteogallus_urubitinga is 30.0 %
# Accuracy for class: 03139_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Chondrohierax_uncinatus is 40.0 %
# Accuracy for class: 03140_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circaetus_cinereus is 70.0 %
# Accuracy for class: 03141_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circaetus_gallicus is 50.0 %
# Accuracy for class: 03142_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circus_aeruginosus is 40.0 %
# Accuracy for class: 03143_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circus_approximans is 50.0 %
# Accuracy for class: 03144_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circus_cyaneus is 0.0 %
# Accuracy for class: 03145_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circus_hudsonius is 40.0 %
# Accuracy for class: 03146_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circus_macrourus is 20.0 %
# Accuracy for class: 03147_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Circus_pygargus is 20.0 %
# Accuracy for class: 03148_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Clanga_clanga is 20.0 %
# Accuracy for class: 03149_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Elanoides_forficatus is 80.0 %
# Accuracy for class: 03150_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Elanus_axillaris is 90.0 %
# Accuracy for class: 03151_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Elanus_caeruleus is 60.0 %
# Accuracy for class: 03152_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Elanus_leucurus is 50.0 %
# Accuracy for class: 03153_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Geranoaetus_albicaudatus is 10.0 %
# Accuracy for class: 03154_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Geranoaetus_melanoleucus is 40.0 %
# Accuracy for class: 03155_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Geranoaetus_polyosoma is 20.0 %
# Accuracy for class: 03156_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Geranospiza_caerulescens is 40.0 %
# Accuracy for class: 03157_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Gypaetus_barbatus is 30.0 %
# Accuracy for class: 03158_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Gyps_africanus is 70.0 %
# Accuracy for class: 03159_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Gyps_fulvus is 40.0 %
# Accuracy for class: 03160_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Haliaeetus_albicilla is 40.0 %
# Accuracy for class: 03161_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Haliaeetus_leucocephalus is 50.0 %
# Accuracy for class: 03162_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Haliaeetus_leucogaster is 50.0 %
# Accuracy for class: 03163_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Haliaeetus_vocifer is 60.0 %
# Accuracy for class: 03164_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Haliastur_indus is 100.0 %
# Accuracy for class: 03165_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Haliastur_sphenurus is 50.0 %
# Accuracy for class: 03166_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Hieraaetus_pennatus is 50.0 %
# Accuracy for class: 03167_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Ictinia_mississippiensis is 20.0 %
# Accuracy for class: 03168_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Ictinia_plumbea is 70.0 %
# Accuracy for class: 03169_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Lophaetus_occipitalis is 80.0 %
# Accuracy for class: 03170_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Melierax_canorus is 70.0 %
# Accuracy for class: 03171_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Milvus_migrans is 20.0 %
# Accuracy for class: 03172_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Milvus_milvus is 20.0 %
# Accuracy for class: 03173_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Necrosyrtes_monachus is 50.0 %
# Accuracy for class: 03174_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Neophron_percnopterus is 40.0 %
# Accuracy for class: 03175_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Nisaetus_cirrhatus is 70.0 %
# Accuracy for class: 03176_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Parabuteo_unicinctus is 30.0 %
# Accuracy for class: 03177_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Pernis_apivorus is 40.0 %
# Accuracy for class: 03178_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Pernis_ptilorhynchus is 30.0 %
# Accuracy for class: 03179_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Polemaetus_bellicosus is 60.0 %
# Accuracy for class: 03180_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Polyboroides_typus is 30.0 %
# Accuracy for class: 03181_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Rostrhamus_sociabilis is 0.0 %
# Accuracy for class: 03182_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Rupornis_magnirostris is 50.0 %
# Accuracy for class: 03183_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Spilornis_cheela is 40.0 %
# Accuracy for class: 03184_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Terathopius_ecaudatus is 60.0 %
# Accuracy for class: 03185_Animalia_Chordata_Aves_Accipitriformes_Pandionidae_Pandion_haliaetus is 50.0 %
# Accuracy for class: 03186_Animalia_Chordata_Aves_Accipitriformes_Sagittariidae_Sagittarius_serpentarius is 60.0 %
# Accuracy for class: 03187_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aix_galericulata is 40.0 %
# Accuracy for class: 03188_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aix_sponsa is 30.0 %
# Accuracy for class: 03189_Animalia_Chordata_Aves_Anseriformes_Anatidae_Alopochen_aegyptiaca is 40.0 %
# Accuracy for class: 03190_Animalia_Chordata_Aves_Anseriformes_Anatidae_Amazonetta_brasiliensis is 70.0 %
# Accuracy for class: 03191_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_acuta is 40.0 %
# Accuracy for class: 03192_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_bahamensis is 90.0 %
# Accuracy for class: 03193_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_castanea is 60.0 %
# Accuracy for class: 03194_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_crecca is 50.0 %
# Accuracy for class: 03195_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_diazi is 20.0 %
# Accuracy for class: 03196_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_erythrorhyncha is 70.0 %
# Accuracy for class: 03197_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_flavirostris is 80.0 %
# Accuracy for class: 03198_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_fulvigula is 60.0 %
# Accuracy for class: 03199_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_georgica is 70.0 %
# Accuracy for class: 03200_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_gracilis is 50.0 %
# Accuracy for class: 03201_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_platyrhynchos is 30.0 %
# Accuracy for class: 03202_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_poecilorhyncha is 40.0 %
# Accuracy for class: 03203_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_rubripes is 40.0 %
# Accuracy for class: 03204_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_superciliosa is 60.0 %
# Accuracy for class: 03205_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_undulata is 70.0 %
# Accuracy for class: 03206_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anas_zonorhyncha is 90.0 %
# Accuracy for class: 03207_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_albifrons is 40.0 %
# Accuracy for class: 03208_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_anser is 0.0 %
# Accuracy for class: 03209_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_brachyrhynchus is 50.0 %
# Accuracy for class: 03210_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_caerulescens is 20.0 %
# Accuracy for class: 03211_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_cygnoides is 60.0 %
# Accuracy for class: 03212_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_fabalis is 40.0 %
# Accuracy for class: 03213_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_indicus is 60.0 %
# Accuracy for class: 03214_Animalia_Chordata_Aves_Anseriformes_Anatidae_Anser_rossii is 60.0 %
# Accuracy for class: 03215_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_affinis is 70.0 %
# Accuracy for class: 03216_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_americana is 60.0 %
# Accuracy for class: 03217_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_australis is 80.0 %
# Accuracy for class: 03218_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_collaris is 40.0 %
# Accuracy for class: 03219_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_ferina is 60.0 %
# Accuracy for class: 03220_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_fuligula is 40.0 %
# Accuracy for class: 03221_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_marila is 10.0 %
# Accuracy for class: 03222_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_novaeseelandiae is 80.0 %
# Accuracy for class: 03223_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_nyroca is 70.0 %
# Accuracy for class: 03224_Animalia_Chordata_Aves_Anseriformes_Anatidae_Aythya_valisineria is 70.0 %
# Accuracy for class: 03225_Animalia_Chordata_Aves_Anseriformes_Anatidae_Branta_bernicla is 40.0 %
# Accuracy for class: 03226_Animalia_Chordata_Aves_Anseriformes_Anatidae_Branta_canadensis is 30.0 %
# Accuracy for class: 03227_Animalia_Chordata_Aves_Anseriformes_Anatidae_Branta_hutchinsii is 80.0 %
# Accuracy for class: 03228_Animalia_Chordata_Aves_Anseriformes_Anatidae_Branta_leucopsis is 70.0 %
# Accuracy for class: 03229_Animalia_Chordata_Aves_Anseriformes_Anatidae_Branta_sandvicensis is 80.0 %
# Accuracy for class: 03230_Animalia_Chordata_Aves_Anseriformes_Anatidae_Bucephala_albeola is 70.0 %
# Accuracy for class: 03231_Animalia_Chordata_Aves_Anseriformes_Anatidae_Bucephala_clangula is 0.0 %
# Accuracy for class: 03232_Animalia_Chordata_Aves_Anseriformes_Anatidae_Bucephala_islandica is 70.0 %
# Accuracy for class: 03233_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cairina_moschata is 30.0 %
# Accuracy for class: 03234_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cereopsis_novaehollandiae is 60.0 %
# Accuracy for class: 03235_Animalia_Chordata_Aves_Anseriformes_Anatidae_Chenonetta_jubata is 90.0 %
# Accuracy for class: 03236_Animalia_Chordata_Aves_Anseriformes_Anatidae_Chloephaga_picta is 80.0 %
# Accuracy for class: 03237_Animalia_Chordata_Aves_Anseriformes_Anatidae_Clangula_hyemalis is 50.0 %
# Accuracy for class: 03238_Animalia_Chordata_Aves_Anseriformes_Anatidae_Coscoroba_coscoroba is 100.0 %
# Accuracy for class: 03239_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cygnus_atratus is 70.0 %
# Accuracy for class: 03240_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cygnus_buccinator is 50.0 %
# Accuracy for class: 03241_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cygnus_columbianus is 40.0 %
# Accuracy for class: 03242_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cygnus_cygnus is 60.0 %
# Accuracy for class: 03243_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cygnus_melancoryphus is 100.0 %
# Accuracy for class: 03244_Animalia_Chordata_Aves_Anseriformes_Anatidae_Cygnus_olor is 70.0 %
# Accuracy for class: 03245_Animalia_Chordata_Aves_Anseriformes_Anatidae_Dendrocygna_autumnalis is 70.0 %
# Accuracy for class: 03246_Animalia_Chordata_Aves_Anseriformes_Anatidae_Dendrocygna_bicolor is 60.0 %
# Accuracy for class: 03247_Animalia_Chordata_Aves_Anseriformes_Anatidae_Dendrocygna_javanica is 80.0 %
# Accuracy for class: 03248_Animalia_Chordata_Aves_Anseriformes_Anatidae_Dendrocygna_viduata is 80.0 %
# Accuracy for class: 03249_Animalia_Chordata_Aves_Anseriformes_Anatidae_Histrionicus_histrionicus is 50.0 %
# Accuracy for class: 03250_Animalia_Chordata_Aves_Anseriformes_Anatidae_Lophodytes_cucullatus is 40.0 %
# Accuracy for class: 03251_Animalia_Chordata_Aves_Anseriformes_Anatidae_Lophonetta_specularioides is 90.0 %
# Accuracy for class: 03252_Animalia_Chordata_Aves_Anseriformes_Anatidae_Malacorhynchus_membranaceus is 70.0 %
# Accuracy for class: 03253_Animalia_Chordata_Aves_Anseriformes_Anatidae_Mareca_americana is 50.0 %
# Accuracy for class: 03254_Animalia_Chordata_Aves_Anseriformes_Anatidae_Mareca_penelope is 60.0 %
# Accuracy for class: 03255_Animalia_Chordata_Aves_Anseriformes_Anatidae_Mareca_strepera is 40.0 %
# Accuracy for class: 03256_Animalia_Chordata_Aves_Anseriformes_Anatidae_Melanitta_americana is 10.0 %
# Accuracy for class: 03257_Animalia_Chordata_Aves_Anseriformes_Anatidae_Melanitta_deglandi is 30.0 %
# Accuracy for class: 03258_Animalia_Chordata_Aves_Anseriformes_Anatidae_Melanitta_perspicillata is 70.0 %
# Accuracy for class: 03259_Animalia_Chordata_Aves_Anseriformes_Anatidae_Mergellus_albellus is 40.0 %
# Accuracy for class: 03260_Animalia_Chordata_Aves_Anseriformes_Anatidae_Mergus_merganser is 60.0 %
# Accuracy for class: 03261_Animalia_Chordata_Aves_Anseriformes_Anatidae_Mergus_serrator is 20.0 %
# Accuracy for class: 03262_Animalia_Chordata_Aves_Anseriformes_Anatidae_Netta_peposaca is 70.0 %
# Accuracy for class: 03263_Animalia_Chordata_Aves_Anseriformes_Anatidae_Netta_rufina is 30.0 %
# Accuracy for class: 03264_Animalia_Chordata_Aves_Anseriformes_Anatidae_Oxyura_jamaicensis is 80.0 %
# Accuracy for class: 03265_Animalia_Chordata_Aves_Anseriformes_Anatidae_Plectropterus_gambensis is 60.0 %
# Accuracy for class: 03266_Animalia_Chordata_Aves_Anseriformes_Anatidae_Sarkidiornis_melanotos is 60.0 %
# Accuracy for class: 03267_Animalia_Chordata_Aves_Anseriformes_Anatidae_Somateria_mollissima is 40.0 %
# Accuracy for class: 03268_Animalia_Chordata_Aves_Anseriformes_Anatidae_Spatula_clypeata is 80.0 %
# Accuracy for class: 03269_Animalia_Chordata_Aves_Anseriformes_Anatidae_Spatula_cyanoptera is 80.0 %
# Accuracy for class: 03270_Animalia_Chordata_Aves_Anseriformes_Anatidae_Spatula_discors is 30.0 %
# Accuracy for class: 03271_Animalia_Chordata_Aves_Anseriformes_Anatidae_Spatula_querquedula is 50.0 %
# Accuracy for class: 03272_Animalia_Chordata_Aves_Anseriformes_Anatidae_Spatula_rhynchotis is 90.0 %
# Accuracy for class: 03273_Animalia_Chordata_Aves_Anseriformes_Anatidae_Tadorna_ferruginea is 70.0 %
# Accuracy for class: 03274_Animalia_Chordata_Aves_Anseriformes_Anatidae_Tadorna_tadorna is 20.0 %
# Accuracy for class: 03275_Animalia_Chordata_Aves_Anseriformes_Anatidae_Tadorna_tadornoides is 70.0 %
# Accuracy for class: 03276_Animalia_Chordata_Aves_Anseriformes_Anatidae_Tadorna_variegata is 60.0 %
# Accuracy for class: 03277_Animalia_Chordata_Aves_Anseriformes_Anhimidae_Chauna_torquata is 40.0 %
# Accuracy for class: 03278_Animalia_Chordata_Aves_Anseriformes_Anseranatidae_Anseranas_semipalmata is 60.0 %
# Accuracy for class: 03279_Animalia_Chordata_Aves_Bucerotiformes_Bucerotidae_Anthracoceros_albirostris is 80.0 %
# Accuracy for class: 03280_Animalia_Chordata_Aves_Bucerotiformes_Bucerotidae_Lophoceros_alboterminatus is 80.0 %
# Accuracy for class: 03281_Animalia_Chordata_Aves_Bucerotiformes_Bucerotidae_Lophoceros_nasutus is 50.0 %
# Accuracy for class: 03282_Animalia_Chordata_Aves_Bucerotiformes_Bucerotidae_Tockus_leucomelas is 80.0 %
# Accuracy for class: 03283_Animalia_Chordata_Aves_Bucerotiformes_Bucorvidae_Bucorvus_leadbeateri is 80.0 %
# Accuracy for class: 03284_Animalia_Chordata_Aves_Bucerotiformes_Phoeniculidae_Phoeniculus_purpureus is 90.0 %
# Accuracy for class: 03285_Animalia_Chordata_Aves_Bucerotiformes_Upupidae_Upupa_epops is 60.0 %
# Accuracy for class: 03286_Animalia_Chordata_Aves_Caprimulgiformes_Apodidae_Aeronautes_saxatalis is 50.0 %
# Accuracy for class: 03287_Animalia_Chordata_Aves_Caprimulgiformes_Apodidae_Apus_apus is 40.0 %
# Accuracy for class: 03288_Animalia_Chordata_Aves_Caprimulgiformes_Apodidae_Chaetura_pelagica is 50.0 %
# Accuracy for class: 03289_Animalia_Chordata_Aves_Caprimulgiformes_Apodidae_Chaetura_vauxi is 30.0 %
# Accuracy for class: 03290_Animalia_Chordata_Aves_Caprimulgiformes_Caprimulgidae_Caprimulgus_europaeus is 30.0 %
# Accuracy for class: 03291_Animalia_Chordata_Aves_Caprimulgiformes_Caprimulgidae_Chordeiles_acutipennis is 30.0 %
# Accuracy for class: 03292_Animalia_Chordata_Aves_Caprimulgiformes_Caprimulgidae_Chordeiles_minor is 40.0 %
# Accuracy for class: 03293_Animalia_Chordata_Aves_Caprimulgiformes_Caprimulgidae_Nyctidromus_albicollis is 80.0 %
# Accuracy for class: 03294_Animalia_Chordata_Aves_Caprimulgiformes_Caprimulgidae_Phalaenoptilus_nuttallii is 80.0 %
# Accuracy for class: 03295_Animalia_Chordata_Aves_Caprimulgiformes_Nyctibiidae_Nyctibius_griseus is 60.0 %
# Accuracy for class: 03296_Animalia_Chordata_Aves_Caprimulgiformes_Nyctibiidae_Nyctibius_jamaicensis is 60.0 %
# Accuracy for class: 03297_Animalia_Chordata_Aves_Caprimulgiformes_Podargidae_Podargus_strigoides is 60.0 %
# Accuracy for class: 03298_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Amazilia_beryllina is 40.0 %
# Accuracy for class: 03299_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Amazilia_cyanocephala is 50.0 %
# Accuracy for class: 03300_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Amazilia_rutila is 60.0 %
# Accuracy for class: 03301_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Amazilia_tzacatl is 40.0 %
# Accuracy for class: 03302_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Amazilia_violiceps is 60.0 %
# Accuracy for class: 03303_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Amazilia_yucatanensis is 50.0 %
# Accuracy for class: 03304_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Anthracothorax_nigricollis is 40.0 %
# Accuracy for class: 03305_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Anthracothorax_prevostii is 20.0 %
# Accuracy for class: 03306_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Archilochus_alexandri is 50.0 %
# Accuracy for class: 03307_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Archilochus_colubris is 10.0 %
# Accuracy for class: 03308_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Boissonneaua_flavescens is 70.0 %
# Accuracy for class: 03309_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Calothorax_lucifer is 70.0 %
# Accuracy for class: 03310_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Calypte_anna is 10.0 %
# Accuracy for class: 03311_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Calypte_costae is 20.0 %
# Accuracy for class: 03312_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Campylopterus_hemileucurus is 80.0 %
# Accuracy for class: 03313_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Chlorostilbon_canivetii is 20.0 %
# Accuracy for class: 03314_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Chlorostilbon_lucidus is 50.0 %
# Accuracy for class: 03315_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Colibri_coruscans is 20.0 %
# Accuracy for class: 03316_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Colibri_cyanotus is 50.0 %
# Accuracy for class: 03317_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Cynanthus_latirostris is 40.0 %
# Accuracy for class: 03318_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Eugenes_fulgens is 40.0 %
# Accuracy for class: 03319_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Eupetomena_macroura is 30.0 %
# Accuracy for class: 03320_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Florisuga_mellivora is 70.0 %
# Accuracy for class: 03321_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Heliodoxa_jacula is 40.0 %
# Accuracy for class: 03322_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Hylocharis_leucotis is 10.0 %
# Accuracy for class: 03323_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Lampornis_clemenciae is 50.0 %
# Accuracy for class: 03324_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Ocreatus_underwoodii is 50.0 %
# Accuracy for class: 03325_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Selasphorus_calliope is 20.0 %
# Accuracy for class: 03326_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Selasphorus_platycercus is 20.0 %
# Accuracy for class: 03327_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Selasphorus_rufus is 40.0 %
# Accuracy for class: 03328_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Selasphorus_sasin is 30.0 %
# Accuracy for class: 03329_Animalia_Chordata_Aves_Caprimulgiformes_Trochilidae_Thalurania_colombica is 30.0 %
# Accuracy for class: 03330_Animalia_Chordata_Aves_Casuariiformes_Casuariidae_Dromaius_novaehollandiae is 80.0 %
# Accuracy for class: 03331_Animalia_Chordata_Aves_Cathartiformes_Cathartidae_Cathartes_aura is 30.0 %
# Accuracy for class: 03332_Animalia_Chordata_Aves_Cathartiformes_Cathartidae_Cathartes_burrovianus is 60.0 %
# Accuracy for class: 03333_Animalia_Chordata_Aves_Cathartiformes_Cathartidae_Coragyps_atratus is 40.0 %
# Accuracy for class: 03334_Animalia_Chordata_Aves_Cathartiformes_Cathartidae_Gymnogyps_californianus is 30.0 %
# Accuracy for class: 03335_Animalia_Chordata_Aves_Cathartiformes_Cathartidae_Sarcoramphus_papa is 70.0 %
# Accuracy for class: 03336_Animalia_Chordata_Aves_Cathartiformes_Cathartidae_Vultur_gryphus is 70.0 %
# Accuracy for class: 03337_Animalia_Chordata_Aves_Charadriiformes_Alcidae_Alca_torda is 40.0 %
# Accuracy for class: 03338_Animalia_Chordata_Aves_Charadriiformes_Alcidae_Brachyramphus_marmoratus is 80.0 %
# Accuracy for class: 03339_Animalia_Chordata_Aves_Charadriiformes_Alcidae_Cepphus_columba is 40.0 %
# Accuracy for class: 03340_Animalia_Chordata_Aves_Charadriiformes_Alcidae_Cepphus_grylle is 40.0 %
# Accuracy for class: 03341_Animalia_Chordata_Aves_Charadriiformes_Alcidae_Cerorhinca_monocerata is 40.0 %
# Accuracy for class: 03342_Animalia_Chordata_Aves_Charadriiformes_Alcidae_Fratercula_arctica is 80.0 %
# Accuracy for class: 03343_Animalia_Chordata_Aves_Charadriiformes_Alcidae_Uria_aalge is 40.0 %
# Accuracy for class: 03344_Animalia_Chordata_Aves_Charadriiformes_Burhinidae_Burhinus_bistriatus is 80.0 %
# Accuracy for class: 03345_Animalia_Chordata_Aves_Charadriiformes_Burhinidae_Burhinus_capensis is 80.0 %
# Accuracy for class: 03346_Animalia_Chordata_Aves_Charadriiformes_Burhinidae_Burhinus_grallarius is 70.0 %
# Accuracy for class: 03347_Animalia_Chordata_Aves_Charadriiformes_Burhinidae_Burhinus_vermiculatus is 90.0 %
# Accuracy for class: 03348_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_alexandrinus is 60.0 %
# Accuracy for class: 03349_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_bicinctus is 30.0 %
# Accuracy for class: 03350_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_collaris is 40.0 %
# Accuracy for class: 03351_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_dubius is 70.0 %
# Accuracy for class: 03352_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_hiaticula is 60.0 %
# Accuracy for class: 03353_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_leschenaultii is 40.0 %
# Accuracy for class: 03354_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_marginatus is 70.0 %
# Accuracy for class: 03355_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_melodus is 50.0 %
# Accuracy for class: 03356_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_mongolus is 20.0 %
# Accuracy for class: 03357_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_nivosus is 50.0 %
# Accuracy for class: 03358_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_obscurus is 70.0 %
# Accuracy for class: 03359_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_pecuarius is 90.0 %
# Accuracy for class: 03360_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_ruficapillus is 90.0 %
# Accuracy for class: 03361_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_semipalmatus is 30.0 %
# Accuracy for class: 03362_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_tricollaris is 70.0 %
# Accuracy for class: 03363_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_vociferus is 50.0 %
# Accuracy for class: 03364_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Charadrius_wilsonia is 60.0 %
# Accuracy for class: 03365_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Elseyornis_melanops is 90.0 %
# Accuracy for class: 03366_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Pluvialis_apricaria is 40.0 %
# Accuracy for class: 03367_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Pluvialis_dominica is 60.0 %
# Accuracy for class: 03368_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Pluvialis_fulva is 0.0 %
# Accuracy for class: 03369_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Pluvialis_squatarola is 20.0 %
# Accuracy for class: 03370_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_armatus is 60.0 %
# Accuracy for class: 03371_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_chilensis is 80.0 %
# Accuracy for class: 03372_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_coronatus is 80.0 %
# Accuracy for class: 03373_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_indicus is 70.0 %
# Accuracy for class: 03374_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_miles is 60.0 %
# Accuracy for class: 03375_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_senegallus is 70.0 %
# Accuracy for class: 03376_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_spinosus is 70.0 %
# Accuracy for class: 03377_Animalia_Chordata_Aves_Charadriiformes_Charadriidae_Vanellus_vanellus is 30.0 %
# Accuracy for class: 03378_Animalia_Chordata_Aves_Charadriiformes_Glareolidae_Glareola_pratincola is 80.0 %
# Accuracy for class: 03379_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_bachmani is 90.0 %
# Accuracy for class: 03380_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_finschi is 10.0 %
# Accuracy for class: 03381_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_fuliginosus is 90.0 %
# Accuracy for class: 03382_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_longirostris is 90.0 %
# Accuracy for class: 03383_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_moquini is 100.0 %
# Accuracy for class: 03384_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_ostralegus is 40.0 %
# Accuracy for class: 03385_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_palliatus is 40.0 %
# Accuracy for class: 03386_Animalia_Chordata_Aves_Charadriiformes_Haematopodidae_Haematopus_unicolor is 10.0 %
# Accuracy for class: 03387_Animalia_Chordata_Aves_Charadriiformes_Jacanidae_Actophilornis_africanus is 90.0 %
# Accuracy for class: 03388_Animalia_Chordata_Aves_Charadriiformes_Jacanidae_Hydrophasianus_chirurgus is 80.0 %
# Accuracy for class: 03389_Animalia_Chordata_Aves_Charadriiformes_Jacanidae_Irediparra_gallinacea is 90.0 %
# Accuracy for class: 03390_Animalia_Chordata_Aves_Charadriiformes_Jacanidae_Jacana_jacana is 80.0 %
# Accuracy for class: 03391_Animalia_Chordata_Aves_Charadriiformes_Jacanidae_Jacana_spinosa is 90.0 %
# Accuracy for class: 03392_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chlidonias_hybrida is 60.0 %
# Accuracy for class: 03393_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chlidonias_leucopterus is 0.0 %
# Accuracy for class: 03394_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chlidonias_niger is 20.0 %
# Accuracy for class: 03395_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_bulleri is 80.0 %
# Accuracy for class: 03396_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_cirrocephalus is 60.0 %
# Accuracy for class: 03397_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_genei is 40.0 %
# Accuracy for class: 03398_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_hartlaubii is 70.0 %
# Accuracy for class: 03399_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_maculipennis is 80.0 %
# Accuracy for class: 03400_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_novaehollandiae is 60.0 %
# Accuracy for class: 03401_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_philadelphia is 50.0 %
# Accuracy for class: 03402_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_ridibundus is 0.0 %
# Accuracy for class: 03403_Animalia_Chordata_Aves_Charadriiformes_Laridae_Chroicocephalus_serranus is 60.0 %
# Accuracy for class: 03404_Animalia_Chordata_Aves_Charadriiformes_Laridae_Gelochelidon_nilotica is 20.0 %
# Accuracy for class: 03405_Animalia_Chordata_Aves_Charadriiformes_Laridae_Hydrocoloeus_minutus is 0.0 %
# Accuracy for class: 03406_Animalia_Chordata_Aves_Charadriiformes_Laridae_Hydroprogne_caspia is 30.0 %
# Accuracy for class: 03407_Animalia_Chordata_Aves_Charadriiformes_Laridae_Ichthyaetus_ichthyaetus is 50.0 %
# Accuracy for class: 03408_Animalia_Chordata_Aves_Charadriiformes_Laridae_Ichthyaetus_melanocephalus is 30.0 %
# Accuracy for class: 03409_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_argentatus is 0.0 %
# Accuracy for class: 03410_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_cachinnans is 10.0 %
# Accuracy for class: 03411_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_californicus is 30.0 %
# Accuracy for class: 03412_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_canus is 50.0 %
# Accuracy for class: 03413_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_crassirostris is 50.0 %
# Accuracy for class: 03414_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_delawarensis is 20.0 %
# Accuracy for class: 03415_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_dominicanus is 10.0 %
# Accuracy for class: 03416_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_fuscus is 30.0 %
# Accuracy for class: 03417_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_glaucescens is 50.0 %
# Accuracy for class: 03418_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_glaucoides is 0.0 %
# Accuracy for class: 03419_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_heermanni is 80.0 %
# Accuracy for class: 03420_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_hyperboreus is 30.0 %
# Accuracy for class: 03421_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_livens is 60.0 %
# Accuracy for class: 03422_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_marinus is 10.0 %
# Accuracy for class: 03423_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_michahellis is 50.0 %
# Accuracy for class: 03424_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_occidentalis is 50.0 %
# Accuracy for class: 03425_Animalia_Chordata_Aves_Charadriiformes_Laridae_Larus_pacificus is 70.0 %
# Accuracy for class: 03426_Animalia_Chordata_Aves_Charadriiformes_Laridae_Leucophaeus_atricilla is 30.0 %
# Accuracy for class: 03427_Animalia_Chordata_Aves_Charadriiformes_Laridae_Leucophaeus_pipixcan is 60.0 %
# Accuracy for class: 03428_Animalia_Chordata_Aves_Charadriiformes_Laridae_Phaetusa_simplex is 90.0 %
# Accuracy for class: 03429_Animalia_Chordata_Aves_Charadriiformes_Laridae_Rissa_tridactyla is 10.0 %
# Accuracy for class: 03430_Animalia_Chordata_Aves_Charadriiformes_Laridae_Rynchops_niger is 60.0 %
# Accuracy for class: 03431_Animalia_Chordata_Aves_Charadriiformes_Laridae_Sterna_forsteri is 50.0 %
# Accuracy for class: 03432_Animalia_Chordata_Aves_Charadriiformes_Laridae_Sterna_hirundo is 30.0 %
# Accuracy for class: 03433_Animalia_Chordata_Aves_Charadriiformes_Laridae_Sterna_paradisaea is 70.0 %
# Accuracy for class: 03434_Animalia_Chordata_Aves_Charadriiformes_Laridae_Sterna_striata is 80.0 %
# Accuracy for class: 03435_Animalia_Chordata_Aves_Charadriiformes_Laridae_Sternula_albifrons is 40.0 %
# Accuracy for class: 03436_Animalia_Chordata_Aves_Charadriiformes_Laridae_Sternula_antillarum is 40.0 %
# Accuracy for class: 03437_Animalia_Chordata_Aves_Charadriiformes_Laridae_Thalasseus_bergii is 50.0 %
# Accuracy for class: 03438_Animalia_Chordata_Aves_Charadriiformes_Laridae_Thalasseus_elegans is 20.0 %
# Accuracy for class: 03439_Animalia_Chordata_Aves_Charadriiformes_Laridae_Thalasseus_maximus is 40.0 %
# Accuracy for class: 03440_Animalia_Chordata_Aves_Charadriiformes_Laridae_Thalasseus_sandvicensis is 0.0 %
# Accuracy for class: 03441_Animalia_Chordata_Aves_Charadriiformes_Recurvirostridae_Himantopus_himantopus is 40.0 %
# Accuracy for class: 03442_Animalia_Chordata_Aves_Charadriiformes_Recurvirostridae_Himantopus_leucocephalus is 70.0 %
# Accuracy for class: 03443_Animalia_Chordata_Aves_Charadriiformes_Recurvirostridae_Himantopus_mexicanus is 60.0 %
# Accuracy for class: 03444_Animalia_Chordata_Aves_Charadriiformes_Recurvirostridae_Recurvirostra_americana is 50.0 %
# Accuracy for class: 03445_Animalia_Chordata_Aves_Charadriiformes_Recurvirostridae_Recurvirostra_avosetta is 70.0 %
# Accuracy for class: 03446_Animalia_Chordata_Aves_Charadriiformes_Rostratulidae_Rostratula_benghalensis is 60.0 %
# Accuracy for class: 03447_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Actitis_hypoleucos is 40.0 %
# Accuracy for class: 03448_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Actitis_macularius is 30.0 %
# Accuracy for class: 03449_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Arenaria_interpres is 60.0 %
# Accuracy for class: 03450_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Arenaria_melanocephala is 50.0 %
# Accuracy for class: 03451_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Bartramia_longicauda is 50.0 %
# Accuracy for class: 03452_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_acuminata is 50.0 %
# Accuracy for class: 03453_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_alba is 40.0 %
# Accuracy for class: 03454_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_alpina is 20.0 %
# Accuracy for class: 03455_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_bairdii is 30.0 %
# Accuracy for class: 03456_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_canutus is 40.0 %
# Accuracy for class: 03457_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_ferruginea is 30.0 %
# Accuracy for class: 03458_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_fuscicollis is 40.0 %
# Accuracy for class: 03459_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_himantopus is 20.0 %
# Accuracy for class: 03460_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_maritima is 70.0 %
# Accuracy for class: 03461_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_mauri is 20.0 %
# Accuracy for class: 03462_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_melanotos is 60.0 %
# Accuracy for class: 03463_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_minuta is 70.0 %
# Accuracy for class: 03464_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_minutilla is 70.0 %
# Accuracy for class: 03465_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_pugnax is 40.0 %
# Accuracy for class: 03466_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_pusilla is 40.0 %
# Accuracy for class: 03467_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_ruficollis is 30.0 %
# Accuracy for class: 03468_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_subruficollis is 50.0 %
# Accuracy for class: 03469_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_temminckii is 40.0 %
# Accuracy for class: 03470_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Calidris_virgata is 60.0 %
# Accuracy for class: 03471_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Gallinago_delicata is 70.0 %
# Accuracy for class: 03472_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Gallinago_gallinago is 60.0 %
# Accuracy for class: 03473_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Limnodromus_griseus is 40.0 %
# Accuracy for class: 03474_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Limnodromus_scolopaceus is 10.0 %
# Accuracy for class: 03475_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Limosa_fedoa is 40.0 %
# Accuracy for class: 03476_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Limosa_haemastica is 40.0 %
# Accuracy for class: 03477_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Limosa_lapponica is 10.0 %
# Accuracy for class: 03478_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Limosa_limosa is 50.0 %
# Accuracy for class: 03479_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Numenius_americanus is 50.0 %
# Accuracy for class: 03480_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Numenius_arquata is 40.0 %
# Accuracy for class: 03481_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Numenius_madagascariensis is 80.0 %
# Accuracy for class: 03482_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Numenius_phaeopus is 50.0 %
# Accuracy for class: 03483_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Phalaropus_fulicarius is 30.0 %
# Accuracy for class: 03484_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Phalaropus_lobatus is 40.0 %
# Accuracy for class: 03485_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Phalaropus_tricolor is 20.0 %
# Accuracy for class: 03486_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Scolopax_minor is 70.0 %
# Accuracy for class: 03487_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_brevipes is 70.0 %
# Accuracy for class: 03488_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_erythropus is 40.0 %
# Accuracy for class: 03489_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_flavipes is 10.0 %
# Accuracy for class: 03490_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_glareola is 70.0 %
# Accuracy for class: 03491_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_incana is 80.0 %
# Accuracy for class: 03492_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_melanoleuca is 40.0 %
# Accuracy for class: 03493_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_nebularia is 40.0 %
# Accuracy for class: 03494_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_ochropus is 50.0 %
# Accuracy for class: 03495_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_semipalmata is 20.0 %
# Accuracy for class: 03496_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_solitaria is 90.0 %
# Accuracy for class: 03497_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_stagnatilis is 50.0 %
# Accuracy for class: 03498_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Tringa_totanus is 50.0 %
# Accuracy for class: 03499_Animalia_Chordata_Aves_Charadriiformes_Scolopacidae_Xenus_cinereus is 30.0 %
# Accuracy for class: 03500_Animalia_Chordata_Aves_Charadriiformes_Stercorariidae_Stercorarius_parasiticus is 20.0 %
# Accuracy for class: 03501_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Anastomus_oscitans is 20.0 %
# Accuracy for class: 03502_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Ciconia_ciconia is 40.0 %
# Accuracy for class: 03503_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Ciconia_episcopus is 60.0 %
# Accuracy for class: 03504_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Ciconia_maguari is 80.0 %
# Accuracy for class: 03505_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Ciconia_nigra is 20.0 %
# Accuracy for class: 03506_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Jabiru_mycteria is 80.0 %
# Accuracy for class: 03507_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Leptoptilos_crumenifer is 60.0 %
# Accuracy for class: 03508_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Mycteria_americana is 80.0 %
# Accuracy for class: 03509_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Mycteria_ibis is 90.0 %
# Accuracy for class: 03510_Animalia_Chordata_Aves_Ciconiiformes_Ciconiidae_Mycteria_leucocephala is 50.0 %
# Accuracy for class: 03511_Animalia_Chordata_Aves_Coliiformes_Coliidae_Colius_striatus is 80.0 %
# Accuracy for class: 03512_Animalia_Chordata_Aves_Columbiformes_Columbidae_Chalcophaps_indica is 90.0 %
# Accuracy for class: 03513_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columba_guinea is 70.0 %
# Accuracy for class: 03514_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columba_livia is 40.0 %
# Accuracy for class: 03515_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columba_oenas is 50.0 %
# Accuracy for class: 03516_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columba_palumbus is 90.0 %
# Accuracy for class: 03517_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columbina_inca is 40.0 %
# Accuracy for class: 03518_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columbina_passerina is 70.0 %
# Accuracy for class: 03519_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columbina_picui is 40.0 %
# Accuracy for class: 03520_Animalia_Chordata_Aves_Columbiformes_Columbidae_Columbina_talpacoti is 60.0 %
# Accuracy for class: 03521_Animalia_Chordata_Aves_Columbiformes_Columbidae_Geopelia_humeralis is 70.0 %
# Accuracy for class: 03522_Animalia_Chordata_Aves_Columbiformes_Columbidae_Geopelia_placida is 90.0 %
# Accuracy for class: 03523_Animalia_Chordata_Aves_Columbiformes_Columbidae_Geopelia_striata is 60.0 %
# Accuracy for class: 03524_Animalia_Chordata_Aves_Columbiformes_Columbidae_Hemiphaga_novaeseelandiae is 60.0 %
# Accuracy for class: 03525_Animalia_Chordata_Aves_Columbiformes_Columbidae_Leptotila_verreauxi is 80.0 %
# Accuracy for class: 03526_Animalia_Chordata_Aves_Columbiformes_Columbidae_Ocyphaps_lophotes is 80.0 %
# Accuracy for class: 03527_Animalia_Chordata_Aves_Columbiformes_Columbidae_Patagioenas_cayennensis is 60.0 %
# Accuracy for class: 03528_Animalia_Chordata_Aves_Columbiformes_Columbidae_Patagioenas_fasciata is 30.0 %
# Accuracy for class: 03529_Animalia_Chordata_Aves_Columbiformes_Columbidae_Patagioenas_flavirostris is 80.0 %
# Accuracy for class: 03530_Animalia_Chordata_Aves_Columbiformes_Columbidae_Patagioenas_leucocephala is 60.0 %
# Accuracy for class: 03531_Animalia_Chordata_Aves_Columbiformes_Columbidae_Patagioenas_maculosa is 70.0 %
# Accuracy for class: 03532_Animalia_Chordata_Aves_Columbiformes_Columbidae_Patagioenas_picazuro is 70.0 %
# Accuracy for class: 03533_Animalia_Chordata_Aves_Columbiformes_Columbidae_Phaps_chalcoptera is 60.0 %
# Accuracy for class: 03534_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_capicola is 60.0 %
# Accuracy for class: 03535_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_chinensis is 30.0 %
# Accuracy for class: 03536_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_decaocto is 60.0 %
# Accuracy for class: 03537_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_orientalis is 80.0 %
# Accuracy for class: 03538_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_semitorquata is 80.0 %
# Accuracy for class: 03539_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_senegalensis is 70.0 %
# Accuracy for class: 03540_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_tranquebarica is 90.0 %
# Accuracy for class: 03541_Animalia_Chordata_Aves_Columbiformes_Columbidae_Streptopelia_turtur is 60.0 %
# Accuracy for class: 03542_Animalia_Chordata_Aves_Columbiformes_Columbidae_Treron_calvus is 40.0 %
# Accuracy for class: 03543_Animalia_Chordata_Aves_Columbiformes_Columbidae_Treron_vernans is 50.0 %
# Accuracy for class: 03544_Animalia_Chordata_Aves_Columbiformes_Columbidae_Zenaida_asiatica is 30.0 %
# Accuracy for class: 03545_Animalia_Chordata_Aves_Columbiformes_Columbidae_Zenaida_auriculata is 30.0 %
# Accuracy for class: 03546_Animalia_Chordata_Aves_Columbiformes_Columbidae_Zenaida_aurita is 60.0 %
# Accuracy for class: 03547_Animalia_Chordata_Aves_Columbiformes_Columbidae_Zenaida_macroura is 40.0 %
# Accuracy for class: 03548_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Alcedo_atthis is 90.0 %
# Accuracy for class: 03549_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Ceryle_rudis is 80.0 %
# Accuracy for class: 03550_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Chloroceryle_amazona is 50.0 %
# Accuracy for class: 03551_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Chloroceryle_americana is 40.0 %
# Accuracy for class: 03552_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Corythornis_cristatus is 90.0 %
# Accuracy for class: 03553_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Dacelo_novaeguineae is 70.0 %
# Accuracy for class: 03554_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Halcyon_albiventris is 90.0 %
# Accuracy for class: 03555_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Halcyon_senegalensis is 90.0 %
# Accuracy for class: 03556_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Halcyon_smyrnensis is 60.0 %
# Accuracy for class: 03557_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Megaceryle_alcyon is 20.0 %
# Accuracy for class: 03558_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Megaceryle_maxima is 70.0 %
# Accuracy for class: 03559_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Megaceryle_torquata is 60.0 %
# Accuracy for class: 03560_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Pelargopsis_capensis is 70.0 %
# Accuracy for class: 03561_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Todiramphus_chloris is 80.0 %
# Accuracy for class: 03562_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Todiramphus_macleayii is 80.0 %
# Accuracy for class: 03563_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Todiramphus_sanctus is 40.0 %
# Accuracy for class: 03564_Animalia_Chordata_Aves_Coraciiformes_Coraciidae_Coracias_benghalensis is 100.0 %
# Accuracy for class: 03565_Animalia_Chordata_Aves_Coraciiformes_Coraciidae_Coracias_caudatus is 70.0 %
# Accuracy for class: 03566_Animalia_Chordata_Aves_Coraciiformes_Coraciidae_Coracias_garrulus is 40.0 %
# Accuracy for class: 03567_Animalia_Chordata_Aves_Coraciiformes_Coraciidae_Eurystomus_orientalis is 70.0 %
# Accuracy for class: 03568_Animalia_Chordata_Aves_Coraciiformes_Meropidae_Merops_apiaster is 50.0 %
# Accuracy for class: 03569_Animalia_Chordata_Aves_Coraciiformes_Meropidae_Merops_bullockoides is 80.0 %
# ...
# Accuracy for class: 04444_Animalia_Chordata_Aves_Piciformes_Picidae_Dryobates_villosus is 10.0 %
# Accuracy for class: 04445_Animalia_Chordata_Aves_Piciformes_Picidae_Dryocopus_lineatus is 60.0 %
# Accuracy for class: 04446_Animalia_Chordata_Aves_Piciformes_Picidae_Dryocopus_martius is 60.0 %
# Accuracy for class: 04447_Animalia_Chordata_Aves_Piciformes_Picidae_Dryocopus_pileatus is 30.0 %
# Accuracy for class: 04448_Animalia_Chordata_Aves_Piciformes_Picidae_Jynx_torquilla is 30.0 %
# Accuracy for class: 04449_Animalia_Chordata_Aves_Piciformes_Picidae_Melanerpes_aurifrons is 30.0 %
# Accuracy for class: 04450_Animalia_Chordata_Aves_Piciformes_Picidae_Melanerpes_carolinus is 50.0 %
# Accuracy for class: 04451_Animalia_Chordata_Aves_Piciformes_Picidae_Melanerpes_chrysogenys is 70.0 %
# Accuracy for class: 04452_Animalia_Chordata_Aves_Piciformes_Picidae_Melanerpes_erythrocephalus is 40.0 %
# Accuracy for class: 04453_Animalia_Chordata_Aves_Piciformes_Picidae_Melanerpes_formicivorus is 50.0 %
# Accuracy for class: 04454_Animalia_Chordata_Aves_Piciformes_Picidae_Melanerpes_hoffmannii is 0.0 %
# Accuracy for class: 04455_Animalia_Chordata_Aves_Piciformes_Picidae_Melanerpes_lewis is 30.0 %
# Accuracy for class: 04456_Animalia_Chordata_Aves_Piciformes_Picidae_Melanerpes_pucherani is 50.0 %
# Accuracy for class: 04457_Animalia_Chordata_Aves_Piciformes_Picidae_Melanerpes_rubricapillus is 50.0 %
# Accuracy for class: 04458_Animalia_Chordata_Aves_Piciformes_Picidae_Melanerpes_uropygialis is 80.0 %
# Accuracy for class: 04459_Animalia_Chordata_Aves_Piciformes_Picidae_Picoides_arcticus is 40.0 %
# Accuracy for class: 04460_Animalia_Chordata_Aves_Piciformes_Picidae_Picoides_dorsalis is 80.0 %
# Accuracy for class: 04461_Animalia_Chordata_Aves_Piciformes_Picidae_Picus_canus is 80.0 %
# Accuracy for class: 04462_Animalia_Chordata_Aves_Piciformes_Picidae_Picus_viridis is 60.0 %
# Accuracy for class: 04463_Animalia_Chordata_Aves_Piciformes_Picidae_Sphyrapicus_nuchalis is 60.0 %
# Accuracy for class: 04464_Animalia_Chordata_Aves_Piciformes_Picidae_Sphyrapicus_ruber is 60.0 %
# Accuracy for class: 04465_Animalia_Chordata_Aves_Piciformes_Picidae_Sphyrapicus_thyroideus is 50.0 %
# Accuracy for class: 04466_Animalia_Chordata_Aves_Piciformes_Picidae_Sphyrapicus_varius is 20.0 %
# Accuracy for class: 04467_Animalia_Chordata_Aves_Piciformes_Ramphastidae_Aulacorhynchus_prasinus is 70.0 %
# Accuracy for class: 04468_Animalia_Chordata_Aves_Piciformes_Ramphastidae_Pteroglossus_castanotis is 80.0 %
# Accuracy for class: 04469_Animalia_Chordata_Aves_Piciformes_Ramphastidae_Pteroglossus_torquatus is 60.0 %
# Accuracy for class: 04470_Animalia_Chordata_Aves_Piciformes_Ramphastidae_Ramphastos_ambiguus is 70.0 %
# Accuracy for class: 04471_Animalia_Chordata_Aves_Piciformes_Ramphastidae_Ramphastos_sulfuratus is 90.0 %
# Accuracy for class: 04472_Animalia_Chordata_Aves_Piciformes_Ramphastidae_Ramphastos_toco is 80.0 %
# Accuracy for class: 04473_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Aechmophorus_clarkii is 40.0 %
# Accuracy for class: 04474_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Aechmophorus_occidentalis is 60.0 %
# Accuracy for class: 04475_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Podiceps_auritus is 30.0 %
# Accuracy for class: 04476_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Podiceps_cristatus is 80.0 %
# Accuracy for class: 04477_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Podiceps_grisegena is 10.0 %
# Accuracy for class: 04478_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Podiceps_major is 70.0 %
# Accuracy for class: 04479_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Podiceps_nigricollis is 10.0 %
# Accuracy for class: 04480_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Podilymbus_podiceps is 50.0 %
# Accuracy for class: 04481_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Poliocephalus_poliocephalus is 70.0 %
# Accuracy for class: 04482_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Rollandia_rolland is 90.0 %
# Accuracy for class: 04483_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Tachybaptus_dominicus is 70.0 %
# Accuracy for class: 04484_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Tachybaptus_novaehollandiae is 80.0 %
# Accuracy for class: 04485_Animalia_Chordata_Aves_Podicipediformes_Podicipedidae_Tachybaptus_ruficollis is 30.0 %
# Accuracy for class: 04486_Animalia_Chordata_Aves_Procellariiformes_Diomedeidae_Phoebastria_immutabilis is 50.0 %
# Accuracy for class: 04487_Animalia_Chordata_Aves_Procellariiformes_Diomedeidae_Phoebastria_nigripes is 50.0 %
# Accuracy for class: 04488_Animalia_Chordata_Aves_Procellariiformes_Diomedeidae_Thalassarche_melanophris is 90.0 %
# Accuracy for class: 04489_Animalia_Chordata_Aves_Procellariiformes_Procellariidae_Ardenna_creatopus is 80.0 %
# Accuracy for class: 04490_Animalia_Chordata_Aves_Procellariiformes_Procellariidae_Ardenna_grisea is 10.0 %
# Accuracy for class: 04491_Animalia_Chordata_Aves_Procellariiformes_Procellariidae_Ardenna_pacifica is 50.0 %
# Accuracy for class: 04492_Animalia_Chordata_Aves_Procellariiformes_Procellariidae_Calonectris_diomedea is 60.0 %
# Accuracy for class: 04493_Animalia_Chordata_Aves_Procellariiformes_Procellariidae_Fulmarus_glacialis is 20.0 %
# Accuracy for class: 04494_Animalia_Chordata_Aves_Procellariiformes_Procellariidae_Macronectes_giganteus is 90.0 %
# Accuracy for class: 04495_Animalia_Chordata_Aves_Psittaciformes_Cacatuidae_Cacatua_galerita is 60.0 %
# Accuracy for class: 04496_Animalia_Chordata_Aves_Psittaciformes_Cacatuidae_Cacatua_sanguinea is 70.0 %
# Accuracy for class: 04497_Animalia_Chordata_Aves_Psittaciformes_Cacatuidae_Cacatua_tenuirostris is 80.0 %
# Accuracy for class: 04498_Animalia_Chordata_Aves_Psittaciformes_Cacatuidae_Callocephalon_fimbriatum is 80.0 %
# Accuracy for class: 04499_Animalia_Chordata_Aves_Psittaciformes_Cacatuidae_Calyptorhynchus_banksii is 40.0 %
# Accuracy for class: 04500_Animalia_Chordata_Aves_Psittaciformes_Cacatuidae_Calyptorhynchus_funereus is 70.0 %
# Accuracy for class: 04501_Animalia_Chordata_Aves_Psittaciformes_Cacatuidae_Eolophus_roseicapilla is 100.0 %
# Accuracy for class: 04502_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Amazona_albifrons is 50.0 %
# Accuracy for class: 04503_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Amazona_autumnalis is 70.0 %
# Accuracy for class: 04504_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Amazona_finschi is 20.0 %
# Accuracy for class: 04505_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Amazona_viridigenalis is 10.0 %
# Accuracy for class: 04506_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Ara_ararauna is 60.0 %
# Accuracy for class: 04507_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Ara_macao is 20.0 %
# Accuracy for class: 04508_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Aratinga_nenday is 60.0 %
# Accuracy for class: 04509_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Brotogeris_chiriri is 0.0 %
# Accuracy for class: 04510_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Brotogeris_jugularis is 60.0 %
# Accuracy for class: 04511_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Eupsittula_canicularis is 40.0 %
# Accuracy for class: 04512_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Eupsittula_nana is 40.0 %
# Accuracy for class: 04513_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Eupsittula_pertinax is 50.0 %
# Accuracy for class: 04514_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Forpus_conspicillatus is 50.0 %
# Accuracy for class: 04515_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Myiopsitta_monachus is 40.0 %
# Accuracy for class: 04516_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Pionus_menstruus is 60.0 %
# Accuracy for class: 04517_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Psittacara_erythrogenys is 20.0 %
# Accuracy for class: 04518_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Psittacara_holochlorus is 40.0 %
# Accuracy for class: 04519_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Psittacara_leucophthalmus is 50.0 %
# Accuracy for class: 04520_Animalia_Chordata_Aves_Psittaciformes_Psittacidae_Psittacara_mitratus is 0.0 %
# Accuracy for class: 04521_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Agapornis_roseicollis is 60.0 %
# Accuracy for class: 04522_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Alisterus_scapularis is 80.0 %
# Accuracy for class: 04523_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Barnardius_zonarius is 80.0 %
# Accuracy for class: 04524_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Cyanoramphus_novaezelandiae is 50.0 %
# Accuracy for class: 04525_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Glossopsitta_concinna is 60.0 %
# Accuracy for class: 04526_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Melopsittacus_undulatus is 50.0 %
# Accuracy for class: 04527_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Platycercus_adscitus is 80.0 %
# Accuracy for class: 04528_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Platycercus_elegans is 50.0 %
# Accuracy for class: 04529_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Platycercus_eximius is 70.0 %
# Accuracy for class: 04530_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Psephotus_haematonotus is 70.0 %
# Accuracy for class: 04531_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Psittacula_krameri is 30.0 %
# Accuracy for class: 04532_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Trichoglossus_chlorolepidotus is 50.0 %
# Accuracy for class: 04533_Animalia_Chordata_Aves_Psittaciformes_Psittaculidae_Trichoglossus_moluccanus is 90.0 %
# Accuracy for class: 04534_Animalia_Chordata_Aves_Psittaciformes_Strigopidae_Nestor_meridionalis is 40.0 %
# Accuracy for class: 04535_Animalia_Chordata_Aves_Psittaciformes_Strigopidae_Nestor_notabilis is 60.0 %
# Accuracy for class: 04536_Animalia_Chordata_Aves_Sphenisciformes_Spheniscidae_Eudyptula_minor is 50.0 %
# Accuracy for class: 04537_Animalia_Chordata_Aves_Sphenisciformes_Spheniscidae_Pygoscelis_papua is 100.0 %
# Accuracy for class: 04538_Animalia_Chordata_Aves_Sphenisciformes_Spheniscidae_Spheniscus_demersus is 90.0 %
# Accuracy for class: 04539_Animalia_Chordata_Aves_Sphenisciformes_Spheniscidae_Spheniscus_magellanicus is 60.0 %
# Accuracy for class: 04540_Animalia_Chordata_Aves_Strigiformes_Strigidae_Aegolius_acadicus is 10.0 %
# Accuracy for class: 04541_Animalia_Chordata_Aves_Strigiformes_Strigidae_Asio_flammeus is 0.0 %
# Accuracy for class: 04542_Animalia_Chordata_Aves_Strigiformes_Strigidae_Asio_otus is 50.0 %
# Accuracy for class: 04543_Animalia_Chordata_Aves_Strigiformes_Strigidae_Athene_brama is 30.0 %
# Accuracy for class: 04544_Animalia_Chordata_Aves_Strigiformes_Strigidae_Athene_cunicularia is 60.0 %
# Accuracy for class: 04545_Animalia_Chordata_Aves_Strigiformes_Strigidae_Athene_noctua is 60.0 %
# Accuracy for class: 04546_Animalia_Chordata_Aves_Strigiformes_Strigidae_Bubo_africanus is 50.0 %
# Accuracy for class: 04547_Animalia_Chordata_Aves_Strigiformes_Strigidae_Bubo_bubo is 20.0 %
# Accuracy for class: 04548_Animalia_Chordata_Aves_Strigiformes_Strigidae_Bubo_scandiacus is 80.0 %
# Accuracy for class: 04549_Animalia_Chordata_Aves_Strigiformes_Strigidae_Bubo_virginianus is 20.0 %
# Accuracy for class: 04550_Animalia_Chordata_Aves_Strigiformes_Strigidae_Ciccaba_virgata is 70.0 %
# Accuracy for class: 04551_Animalia_Chordata_Aves_Strigiformes_Strigidae_Glaucidium_brasilianum is 80.0 %
# Accuracy for class: 04552_Animalia_Chordata_Aves_Strigiformes_Strigidae_Glaucidium_gnoma is 50.0 %
# Accuracy for class: 04553_Animalia_Chordata_Aves_Strigiformes_Strigidae_Megascops_asio is 30.0 %
# Accuracy for class: 04554_Animalia_Chordata_Aves_Strigiformes_Strigidae_Megascops_choliba is 70.0 %
# Accuracy for class: 04555_Animalia_Chordata_Aves_Strigiformes_Strigidae_Megascops_kennicottii is 30.0 %
# Accuracy for class: 04556_Animalia_Chordata_Aves_Strigiformes_Strigidae_Ninox_novaeseelandiae is 40.0 %
# Accuracy for class: 04557_Animalia_Chordata_Aves_Strigiformes_Strigidae_Strix_aluco is 30.0 %
# Accuracy for class: 04558_Animalia_Chordata_Aves_Strigiformes_Strigidae_Strix_nebulosa is 30.0 %
# Accuracy for class: 04559_Animalia_Chordata_Aves_Strigiformes_Strigidae_Strix_uralensis is 60.0 %
# Accuracy for class: 04560_Animalia_Chordata_Aves_Strigiformes_Strigidae_Strix_varia is 30.0 %
# Accuracy for class: 04561_Animalia_Chordata_Aves_Strigiformes_Strigidae_Surnia_ulula is 70.0 %
# Accuracy for class: 04562_Animalia_Chordata_Aves_Strigiformes_Tytonidae_Tyto_alba is 10.0 %
# Accuracy for class: 04563_Animalia_Chordata_Aves_Struthioniformes_Struthionidae_Struthio_camelus is 70.0 %
# Accuracy for class: 04564_Animalia_Chordata_Aves_Suliformes_Anhingidae_Anhinga_anhinga is 40.0 %
# Accuracy for class: 04565_Animalia_Chordata_Aves_Suliformes_Anhingidae_Anhinga_melanogaster is 50.0 %
# Accuracy for class: 04566_Animalia_Chordata_Aves_Suliformes_Anhingidae_Anhinga_novaehollandiae is 60.0 %
# Accuracy for class: 04567_Animalia_Chordata_Aves_Suliformes_Anhingidae_Anhinga_rufa is 60.0 %
# Accuracy for class: 04568_Animalia_Chordata_Aves_Suliformes_Fregatidae_Fregata_magnificens is 70.0 %
# Accuracy for class: 04569_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Microcarbo_africanus is 50.0 %
# Accuracy for class: 04570_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Microcarbo_melanoleucos is 70.0 %
# Accuracy for class: 04571_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Microcarbo_niger is 40.0 %
# Accuracy for class: 04572_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Microcarbo_pygmaeus is 30.0 %
# Accuracy for class: 04573_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Phalacrocorax_aristotelis is 70.0 %
# Accuracy for class: 04574_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Phalacrocorax_auritus is 10.0 %
# Accuracy for class: 04575_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Phalacrocorax_brasilianus is 60.0 %
# Accuracy for class: 04576_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Phalacrocorax_capensis is 50.0 %
# Accuracy for class: 04577_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Phalacrocorax_carbo is 30.0 %
# Accuracy for class: 04578_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Phalacrocorax_pelagicus is 10.0 %
# Accuracy for class: 04579_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Phalacrocorax_penicillatus is 80.0 %
# Accuracy for class: 04580_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Phalacrocorax_punctatus is 60.0 %
# Accuracy for class: 04581_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Phalacrocorax_sulcirostris is 40.0 %
# Accuracy for class: 04582_Animalia_Chordata_Aves_Suliformes_Phalacrocoracidae_Phalacrocorax_varius is 50.0 %
# Accuracy for class: 04583_Animalia_Chordata_Aves_Suliformes_Sulidae_Morus_bassanus is 30.0 %
# Accuracy for class: 04584_Animalia_Chordata_Aves_Suliformes_Sulidae_Morus_serrator is 90.0 %
# Accuracy for class: 04585_Animalia_Chordata_Aves_Suliformes_Sulidae_Sula_dactylatra is 30.0 %
# Accuracy for class: 04586_Animalia_Chordata_Aves_Suliformes_Sulidae_Sula_leucogaster is 30.0 %
# Accuracy for class: 04587_Animalia_Chordata_Aves_Suliformes_Sulidae_Sula_nebouxii is 90.0 %
# Accuracy for class: 04588_Animalia_Chordata_Aves_Suliformes_Sulidae_Sula_sula is 70.0 %
# Accuracy for class: 04589_Animalia_Chordata_Aves_Trogoniformes_Trogonidae_Pharomachrus_mocinno is 30.0 %
# Accuracy for class: 04590_Animalia_Chordata_Aves_Trogoniformes_Trogonidae_Trogon_caligatus is 40.0 %
# Accuracy for class: 04591_Animalia_Chordata_Aves_Trogoniformes_Trogonidae_Trogon_citreolus is 50.0 %
# Accuracy for class: 04592_Animalia_Chordata_Aves_Trogoniformes_Trogonidae_Trogon_collaris is 40.0 %
# Accuracy for class: 04593_Animalia_Chordata_Aves_Trogoniformes_Trogonidae_Trogon_elegans is 50.0 %
# Accuracy for class: 04594_Animalia_Chordata_Aves_Trogoniformes_Trogonidae_Trogon_massena is 80.0 %
# Accuracy for class: 04595_Animalia_Chordata_Aves_Trogoniformes_Trogonidae_Trogon_melanocephalus is 70.0 %
# Accuracy for class: 04596_Animalia_Chordata_Aves_Trogoniformes_Trogonidae_Trogon_rufus is 60.0 %
